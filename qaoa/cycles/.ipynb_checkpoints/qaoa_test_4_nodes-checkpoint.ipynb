# %% [markdown]
# ## Random Graphs
#
# ### Helper Functions
#
# Randomly generate an adjancency matrix...

# %%
import timeit
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations, groupby

# Size of NxN Matrix
n = 4

# Moved to global scopee to allow for timing
bf_bit_string, bf_cost = None, None

def random_row(row_num: int):
    row = list(np.random.choice((0, 1, 2, 3, 4, 5),size=n))
    
    row[row_num] = 0 
    
    # Make sure there's no isolated nodes
    if sum(row) == 0:
        row = random_row(row_num)
    return row

def random_matrix():
    rows = []
    for i in range(0, n):
        rows.append(random_row(i))
    numpy_matrix = np.matrix(rows)
    
    return numpy_matrix

def random_graph():
    np_matrix = random_matrix()
    g = nx.convert_matrix.from_numpy_matrix(
        np_matrix, 
        parallel_edges=False, 
        create_using=nx.Graph
    )
    
    # nx.draw(g, node_color='lightblue', 
    #     with_labels=True, 
    #     node_size=500)
    
    return g, np_matrix

# %% [markdown]
# ### Brute Force

# %%
def brute_force(graph, w):
    global bf_bit_string
    global bf_cost
    
    bf_bit_string = None
    bf_cost = None
    
    best_cost_brute = 0
    for b in range(2**n):
        x = [int(t) for t in reversed(list(bin(b)[2:].zfill(n)))]
        cost = 0
        for i in range(n):
            for j in range(n):
                cost = cost + w[i,j]*x[i]*(1-x[j])
        if best_cost_brute < cost:
            best_cost_brute = cost
            xbest_brute = x
    bf_bit_string = xbest_brute
    bf_cost = best_cost_brute
    return xbest_brute, best_cost_brute

# %% [markdown]
# ### Quantum Apporximation Optimization Algorithm

# %%
import networkx as nx
import numpy as np
import plotly.graph_objects as go
import matplotlib as mpl
import pandas as pd
from IPython.display import clear_output
from plotly.subplots import make_subplots
from matplotlib import pyplot as plt
from qiskit import Aer
from qiskit import QuantumCircuit
from qiskit.visualization import plot_state_city
from qiskit.algorithms.optimizers import COBYLA, SLSQP, ADAM
from time import time
from copy import copy
from typing import List
from qc_grader.graph_util import display_maxcut_widget, QAOA_widget, graphs
from qiskit.circuit import Parameter, ParameterVector
from qiskit_optimization import QuadraticProgram
from qiskit.algorithms import QAOA
from qiskit_optimization.algorithms import MinimumEigenOptimizer

def maxcut_cost_fn(graph: nx.Graph, bitstring: List[int]) -> float:
    """
    Computes the maxcut cost function value for a given graph and cut represented by some bitstring
    Args:
        graph: The graph to compute cut values for
        bitstring: A list of integer values '0' or '1' specifying a cut of the graph
    Returns:
        The value of the cut
    """
    #Get the weight matrix of the graph
    weight_matrix = nx.adjacency_matrix(graph).toarray()
    size = weight_matrix.shape[0]
    value = 0.
    for i in range(size):
        for j in range(size):
            value = value + weight_matrix[i][j] * bitstring[i] * (1-bitstring[j])

    return value

def quadratic_program_from_graph(graph: nx.Graph) -> QuadraticProgram:
    """Constructs a quadratic program from a given graph for a MaxCut problem instance.
    Args:
        graph: Underlying graph of the problem.
    Returns:
        QuadraticProgram
    """
    #Get weight matrix of graph
    weight_matrix = nx.adjacency_matrix(graph)
    shape = weight_matrix.shape
    size = shape[0]
    
    #Build qubo matrix Q from weight matrix W
    qubo_matrix = np.zeros((size, size))
    qubo_vector = np.zeros(size)
    for i in range(size):
        for j in range(size):
            qubo_matrix[i, j] -= weight_matrix[i, j]
    for i in range(size):
        for j in range(size):
            qubo_vector[i] += weight_matrix[i,j]

    quadratic_program = QuadraticProgram('MaxCut as QUBO')
    for i in range(size):
        quadratic_program.binary_var(name = f'x_{i}')

    quadratic_program.maximize(quadratic = qubo_matrix, linear = qubo_vector)
    
    return quadratic_program

def qaoa_circuit(qubo: QuadraticProgram, p: int = 1, params: dict = []) -> QuantumCircuit:
    """
    Given a QUBO instance and the number of layers p, constructs the corresponding parameterized QAOA circuit with p layers.
    Args:
        qubo: The quadratic program instance
        p: The number of layers in the QAOA circuit
    Returns:
        The parameterized QAOA circuit
    """
    size = len(qubo.variables)
    qubo_matrix = qubo.objective.quadratic.to_array(symmetric=True)
    qubo_linearity = qubo.objective.linear.to_array()

    #Prepare the quantum and classical registers
    qaoa_circuit = QuantumCircuit(size,size)
    #Apply the initial layer of Hadamard gates to all qubits
    qaoa_circuit.h(range(size))

    #Create the parameters to be used in the circuit
    if not params:
        gammas = ParameterVector('gamma', p)
        betas = ParameterVector('beta', p)
    else:
        gammas = [params[1]]
        betas = [params[0]]

    #Outer loop to create each layer
    for i in range(p):

        #Apply R_Z rotational gates from cost layer
        for qubit in range(size):
            sum =0
            for col in range(size):
                sum += qubo_matrix[qubit][col]
            theta = (qubo_linearity[qubit] + sum) * gammas[i]
            qaoa_circuit.rz(theta, qubit)

        #Apply R_ZZ rotational gates for entangled qubit rotations from cost layer
        for j in range(size):
            for k in range(size):
                if j != k:
                    theta = qubo_matrix[j][k] * gammas[i] / 2
                    qaoa_circuit.rzz(theta, j, k)

        # Apply single qubit X - rotations with angle 2*beta_i to all qubits
        for qubit in range(size):
            qaoa_circuit.rx(2 * betas[i], qubit)
    return qaoa_circuit

def plot_qaoa_energy_landscape(graph: nx.Graph, cvar: float = None, plot: bool = True):
    num_shots = 1000
    seed = 42
    simulator = Aer.get_backend('qasm_simulator')
    simulator.set_options(seed_simulator = 42)

    #Generate circuit
    circuit = qaoa_circuit(qubo = quadratic_program_from_graph(graph), p=1)
    circuit.measure(range(graph.number_of_nodes()),range(graph.number_of_nodes()))

    #Create dictionary with precomputed cut values for all bitstrings 
    cut_values = {}
    size = graph.number_of_nodes()
    for i in range(2**size):
        bitstr = '{:b}'.format(i).rjust(size, '0')[::-1]
        x = [int(bit) for bit in bitstr]
        cut_values[bitstr] = maxcut_cost_fn(graph, x)

    #Perform grid search over all parameters
    data_points = []
    max_energy = None
    for beta in np.linspace(0,np.pi, 50):
        for gamma in np.linspace(0, 4*np.pi, 50):
            bound_circuit = circuit.assign_parameters([beta, gamma])
            result = simulator.run(bound_circuit, shots = num_shots).result()
            statevector = result.get_counts(bound_circuit)
            energy = 0
            measured_cuts = []
            for bitstring, count in statevector.items():
                measured_cuts =  measured_cuts + [cut_values[bitstring]]*count

            if cvar is None:
                # Calculate the mean of all cut values
                energy = sum(measured_cuts)/num_shots
            else:
                alpha_n = cvar*num_shots
                measured_cuts.sort(reverse=True)
                energy = sum(measured_cuts[:int(alpha_n)])/alpha_n

            #Update optimal parameters
            if max_energy is None or energy > max_energy:
                max_energy = energy
                optimum = {'beta': beta, 'gamma': gamma, 'energy': energy}

            #Update data
            data_points.append({'beta': beta, 'gamma': gamma, 'energy': energy})

    if plot:
        #Create and display surface plot from data_points
        df = pd.DataFrame(data_points)
        df = df.pivot(index='beta', columns='gamma', values='energy')
        matrix = df.to_numpy()
        beta_values = df.index.tolist()
        gamma_values = df.columns.tolist()

        surface_plot = go.Surface(
            x=gamma_values, 
            y=beta_values,
            z=matrix,
            coloraxis = 'coloraxis'
        )
        fig = go.Figure(data = surface_plot)
        fig.show()

    #Return optimum
    return optimum

def qaoa(nx_g):
    """
    Outline of how to use the QAOA class
        problem = QuadraticProgram()
        # specify problem here
        # specify minimum eigen solver to be used, e.g., QAOA
        qaoa = QAOA(...)
        optimizer = MinimumEigenOptimizer(qaoa)
        result = optimizer.solve(problem)
    
    """
    backend = Aer.get_backend('statevector_simulator')
    qaoa = QAOA(optimizer = ADAM(), quantum_instance = backend, reps=1, initial_point = [0.1,0.1])
    eigen_optimizer = MinimumEigenOptimizer(min_eigen_solver = qaoa)
    quadratic_program = quadratic_program_from_graph(nx_g)
    result = eigen_optimizer.solve(quadratic_program)
    
    # print results
    bit_string = map(int, result.x)
    return bit_string, result.fval, result.min_eigen_solver_result.optimizer_time

# %% [markdown]
# ## Tests

# %%
# Generate 1,000 graphs
success = 0
failure = 0

# TODO: Change the number of tests, ad hoc
num_tests: int = 100

for graph_id in range(num_tests):
    global bf_bit_string
    global bf_cost
    
    # Generate Random Graph
    graph, matrix = random_graph()
    
    # Computing the weight matrix from the random graph
    w = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            temp = graph.get_edge_data(i,j,default=0)
            if temp != 0:
                w[i,j] = temp['weight']
    
    print(f'\nTest Case {graph_id}: ')
    print('------------' + '-' * (len(str(graph_id)) * 2))
    print()
    print(w)
    
    # Brute Force Approach
    #
    # Time brute force algorithm
    bf_time: float = timeit.timeit(lambda: brute_force(graph, w), number=1)
    
    # Parse the bit sting answer
    bf_x = ''.join(str(e) for e in bf_bit_string)
    bf_x_inverse = ''.join('1' if x == '0' else '0' for x in bf_x)
    
    # Print results
    print('\n\tBrute Force')
    print(f'\t\tSolution = {bf_x} [{bf_x_inverse}].')
    print(f'\t\tMaxcut = {str(bf_cost)}.')
    print(f'\t\tTime: {bf_time} seconds.')
    
    # QAOA Approach
    #
    # Run QAOA
    qaoa_bit_string, qaoa_cost, qaoa_optimizer_time = qaoa(graph)
    
    # Parse the bit sting answer
    qaoa_x = ''.join(str(e) for e in qaoa_bit_string)
    qaoa_x_inverse = ''.join('1' if x == '0' else '0' for x in qaoa_x)
    
    # Print results
    print('\n\tQuantum Approximation Optimization Algorithm (QAOA):')
    print(f'\t\tSolution = {qaoa_x} [{qaoa_x_inverse}].')
    print(f'\t\tMaxcut = {str(qaoa_cost)}.')
    print(f'\t\tOptimizer Time: {str(qaoa_optimizer_time)} seconds.')
    # print(f'\t\tCompmute Minimum Eigenvalue Time: {str(optimizer_time)} seconds.')
    print()
    
    # Check validity
    if bf_x == qaoa_x or bf_x == qaoa_x_inverse or qaoa_x == bf_x_inverse:
        success += 1
    else:
        failure += 1
# Out:
# Test Case 0:
# ------------
#
# [[5. 3. 2. 4.]
#  [3. 1. 1. 5.]
#  [2. 1. 1. 1.]
#  [4. 5. 1. 1.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Time: 0.0003797318786382675 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.728889465332031 seconds.
#
#
# Test Case 1:
# --------------
#
# [[5. 5. 4. 3.]
#  [5. 5. 2. 3.]
#  [4. 2. 4. 4.]
#  [3. 3. 4. 3.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Time: 0.00023121898993849754 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Optimizer Time: 4.724193096160889 seconds.
#
#
# Test Case 2:
# ----------------
#
# [[5. 2. 3. 5.]
#  [2. 3. 1. 2.]
#  [3. 1. 5. 3.]
#  [5. 2. 3. 1.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Time: 0.00036438298411667347 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Optimizer Time: 4.561630487442017 seconds.
#
#
# Test Case 3:
# ------------------
#
# [[1. 5. 1. 1.]
#  [5. 0. 1. 5.]
#  [1. 1. 1. 5.]
#  [1. 5. 5. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Time: 0.00022807600907981396 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Optimizer Time: 5.153693199157715 seconds.
#
#
# Test Case 4:
# --------------------
#
# [[4. 4. 3. 5.]
#  [4. 5. 1. 2.]
#  [3. 1. 2. 4.]
#  [5. 2. 4. 5.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Time: 0.00021472712978720665 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.753604888916016 seconds.
#
#
# Test Case 5:
# ----------------------
#
# [[3. 5. 3. 3.]
#  [5. 5. 1. 4.]
#  [3. 1. 1. 5.]
#  [3. 4. 5. 5.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 17.0.
# 		Time: 0.0002298019826412201 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 17.0.
# 		Optimizer Time: 4.714022874832153 seconds.
#
#
# Test Case 6:
# ------------------------
#
# [[4. 4. 1. 5.]
#  [4. 3. 1. 4.]
#  [1. 1. 2. 4.]
#  [5. 4. 4. 3.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Time: 0.0003272229805588722 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.747907638549805 seconds.
#
#
# Test Case 7:
# --------------------------
#
# [[1. 3. 3. 2.]
#  [3. 3. 1. 2.]
#  [3. 1. 0. 4.]
#  [2. 2. 4. 3.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Time: 0.0002704199869185686 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.681889772415161 seconds.
#
#
# Test Case 8:
# ----------------------------
#
# [[2. 2. 3. 2.]
#  [2. 3. 5. 1.]
#  [3. 5. 1. 2.]
#  [2. 1. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Time: 0.00022320379503071308 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Optimizer Time: 4.60122275352478 seconds.
#
#
# Test Case 9:
# ------------------------------
#
# [[1. 1. 1. 1.]
#  [1. 5. 3. 4.]
#  [1. 3. 1. 2.]
#  [1. 4. 2. 4.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 9.0.
# 		Time: 0.00022639683447778225 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 9.0.
# 		Optimizer Time: 4.835402965545654 seconds.
#
#
# Test Case 10:
# --------------------------------
#
# [[3. 0. 4. 3.]
#  [0. 3. 2. 1.]
#  [4. 2. 0. 2.]
#  [3. 1. 2. 5.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Time: 0.00022634491324424744 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Optimizer Time: 4.6532957553863525 seconds.
#
#
# Test Case 11:
# ----------------------------------
#
# [[4. 3. 0. 4.]
#  [3. 2. 0. 5.]
#  [0. 0. 5. 4.]
#  [4. 5. 4. 2.]]
#
# 	Brute Force
# 		Solution = 1110 [0001].
# 		Maxcut = 13.0.
# 		Time: 0.0002244019415229559 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1110 [0001].
# 		Maxcut = 13.0.
# 		Optimizer Time: 4.508698463439941 seconds.
#
#
# Test Case 12:
# ------------------------------------
#
# [[2. 4. 3. 2.]
#  [4. 0. 3. 1.]
#  [3. 3. 5. 4.]
#  [2. 1. 4. 4.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 13.0.
# 		Time: 0.000224048038944602 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 13.0.
# 		Optimizer Time: 4.624646425247192 seconds.
#
#
# Test Case 13:
# --------------------------------------
#
# [[2. 2. 0. 1.]
#  [2. 4. 4. 5.]
#  [0. 4. 4. 1.]
#  [1. 5. 1. 4.]]
#
# 	Brute Force
# 		Solution = 0100 [1011].
# 		Maxcut = 11.0.
# 		Time: 0.0005454050842672586 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0100 [1011].
# 		Maxcut = 11.0.
# 		Optimizer Time: 4.8039329051971436 seconds.
#
#
# Test Case 14:
# ----------------------------------------
#
# [[2. 1. 1. 5.]
#  [1. 3. 3. 5.]
#  [1. 3. 0. 4.]
#  [5. 5. 4. 1.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.0002245320938527584 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.7556068897247314 seconds.
#
#
# Test Case 15:
# ------------------------------------------
#
# [[0. 1. 5. 5.]
#  [1. 4. 2. 3.]
#  [5. 2. 4. 0.]
#  [5. 3. 0. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Time: 0.00022660684771835804 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.94101357460022 seconds.
#
#
# Test Case 16:
# --------------------------------------------
#
# [[4. 3. 5. 2.]
#  [3. 2. 2. 5.]
#  [5. 2. 1. 2.]
#  [2. 5. 2. 4.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.0002279970794916153 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.810020923614502 seconds.
#
#
# Test Case 17:
# ----------------------------------------------
#
# [[4. 1. 3. 3.]
#  [1. 3. 3. 5.]
#  [3. 3. 2. 4.]
#  [3. 5. 4. 3.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.00021850387565791607 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.703239917755127 seconds.
#
#
# Test Case 18:
# ------------------------------------------------
#
# [[0. 4. 4. 5.]
#  [4. 5. 4. 4.]
#  [4. 4. 4. 2.]
#  [5. 4. 2. 3.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Time: 0.00022346596233546734 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Optimizer Time: 4.623860836029053 seconds.
#
#
# Test Case 19:
# --------------------------------------------------
#
# [[4. 3. 2. 5.]
#  [3. 0. 5. 5.]
#  [2. 5. 0. 2.]
#  [5. 5. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Time: 0.00021877512335777283 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Optimizer Time: 4.663686275482178 seconds.
#
#
# Test Case 20:
# ----------------------------------------------------
#
# [[2. 3. 3. 3.]
#  [3. 3. 3. 1.]
#  [3. 3. 1. 3.]
#  [3. 1. 3. 3.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Time: 0.0002820948138833046 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.665420770645142 seconds.
#
#
# Test Case 21:
# ------------------------------------------------------
#
# [[4. 5. 4. 4.]
#  [5. 0. 3. 4.]
#  [4. 3. 4. 5.]
#  [4. 4. 5. 2.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 18.0.
# 		Time: 0.00023035705089569092 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 18.0.
# 		Optimizer Time: 4.561960697174072 seconds.
#
#
# Test Case 22:
# --------------------------------------------------------
#
# [[4. 4. 5. 4.]
#  [4. 0. 1. 1.]
#  [5. 1. 2. 5.]
#  [4. 1. 5. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.00026353495195508003 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.686906337738037 seconds.
#
#
# Test Case 23:
# ----------------------------------------------------------
#
# [[1. 1. 2. 1.]
#  [1. 0. 5. 2.]
#  [2. 5. 4. 2.]
#  [1. 2. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Time: 0.00023009791038930416 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Optimizer Time: 4.814896821975708 seconds.
#
#
# Test Case 24:
# ------------------------------------------------------------
#
# [[4. 4. 4. 1.]
#  [4. 4. 4. 1.]
#  [4. 4. 4. 2.]
#  [1. 1. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 11.0.
# 		Time: 0.0002965440507978201 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 11.0.
# 		Optimizer Time: 4.778829097747803 seconds.
#
#
# Test Case 25:
# --------------------------------------------------------------
#
# [[4. 5. 3. 1.]
#  [5. 2. 5. 3.]
#  [3. 5. 0. 1.]
#  [1. 3. 1. 1.]]
#
# 	Brute Force
# 		Solution = 0100 [1011].
# 		Maxcut = 13.0.
# 		Time: 0.00022990209981799126 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0100 [1011].
# 		Maxcut = 13.0.
# 		Optimizer Time: 4.759222507476807 seconds.
#
#
# Test Case 26:
# ----------------------------------------------------------------
#
# [[1. 2. 5. 5.]
#  [2. 1. 3. 2.]
#  [5. 3. 4. 5.]
#  [5. 2. 5. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Time: 0.00023076310753822327 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.598439931869507 seconds.
#
#
# Test Case 27:
# ------------------------------------------------------------------
#
# [[4. 2. 1. 1.]
#  [2. 2. 5. 5.]
#  [1. 5. 1. 2.]
#  [1. 5. 2. 2.]]
#
# 	Brute Force
# 		Solution = 0100 [1011].
# 		Maxcut = 12.0.
# 		Time: 0.00021963706240057945 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0100 [1011].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.8249335289001465 seconds.
#
#
# Test Case 28:
# --------------------------------------------------------------------
#
# [[1. 3. 2. 3.]
#  [3. 3. 5. 1.]
#  [2. 5. 4. 4.]
#  [3. 1. 4. 1.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Time: 0.00024772388860583305 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Optimizer Time: 5.015237331390381 seconds.
#
#
# Test Case 29:
# ----------------------------------------------------------------------
#
# [[0. 1. 4. 2.]
#  [1. 5. 5. 2.]
#  [4. 5. 2. 2.]
#  [2. 2. 2. 2.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Time: 0.00022099795751273632 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Optimizer Time: 4.752074241638184 seconds.
#
#
# Test Case 30:
# ------------------------------------------------------------------------
#
# [[5. 2. 1. 2.]
#  [2. 2. 4. 4.]
#  [1. 4. 1. 4.]
#  [2. 4. 4. 1.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Time: 0.00039194594137370586 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.652159929275513 seconds.
#
#
# Test Case 31:
# --------------------------------------------------------------------------
#
# [[3. 4. 4. 1.]
#  [4. 5. 3. 4.]
#  [4. 3. 1. 5.]
#  [1. 4. 5. 1.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 17.0.
# 		Time: 0.00025595095939934254 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 17.0.
# 		Optimizer Time: 4.691709041595459 seconds.
#
#
# Test Case 32:
# ----------------------------------------------------------------------------
#
# [[4. 2. 2. 3.]
#  [2. 0. 4. 5.]
#  [2. 4. 0. 1.]
#  [3. 5. 1. 2.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.0002236468717455864 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.847593069076538 seconds.
#
#
# Test Case 33:
# ------------------------------------------------------------------------------
#
# [[4. 1. 4. 2.]
#  [1. 3. 1. 2.]
#  [4. 1. 5. 5.]
#  [2. 2. 5. 2.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Time: 0.00023116311058402061 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.852342367172241 seconds.
#
#
# Test Case 34:
# --------------------------------------------------------------------------------
#
# [[3. 5. 4. 1.]
#  [5. 2. 3. 5.]
#  [4. 3. 1. 1.]
#  [1. 5. 1. 5.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.00022927997633814812 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.735414743423462 seconds.
#
#
# Test Case 35:
# ----------------------------------------------------------------------------------
#
# [[3. 3. 2. 3.]
#  [3. 0. 3. 5.]
#  [2. 3. 4. 1.]
#  [3. 5. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Time: 0.00022873305715620518 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Optimizer Time: 4.712137222290039 seconds.
#
#
# Test Case 36:
# ------------------------------------------------------------------------------------
#
# [[3. 4. 1. 5.]
#  [4. 5. 2. 4.]
#  [1. 2. 2. 4.]
#  [5. 4. 4. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Time: 0.0002280490007251501 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.799642086029053 seconds.
#
#
# Test Case 37:
# --------------------------------------------------------------------------------------
#
# [[4. 5. 5. 2.]
#  [5. 3. 5. 2.]
#  [5. 5. 5. 4.]
#  [2. 2. 4. 3.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Time: 0.00022270414046943188 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Optimizer Time: 4.583576202392578 seconds.
#
#
# Test Case 38:
# ----------------------------------------------------------------------------------------
#
# [[5. 2. 3. 5.]
#  [2. 3. 5. 5.]
#  [3. 5. 5. 1.]
#  [5. 5. 1. 2.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 18.0.
# 		Time: 0.00022430205717682838 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 18.0.
# 		Optimizer Time: 4.833069086074829 seconds.
#
#
# Test Case 39:
# ------------------------------------------------------------------------------------------
#
# [[1. 4. 3. 3.]
#  [4. 5. 2. 5.]
#  [3. 2. 3. 3.]
#  [3. 5. 3. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.00024285190738737583 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.659398317337036 seconds.
#
#
# Test Case 40:
# --------------------------------------------------------------------------------------------
#
# [[1. 5. 2. 1.]
#  [5. 2. 2. 1.]
#  [2. 2. 0. 4.]
#  [1. 1. 4. 1.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Time: 0.00022564595565199852 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.9095988273620605 seconds.
#
#
# Test Case 41:
# ----------------------------------------------------------------------------------------------
#
# [[3. 3. 4. 2.]
#  [3. 0. 4. 5.]
#  [4. 4. 2. 5.]
#  [2. 5. 5. 4.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 17.0.
# 		Time: 0.00029703998006880283 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 17.0.
# 		Optimizer Time: 4.606534242630005 seconds.
#
#
# Test Case 42:
# ------------------------------------------------------------------------------------------------
#
# [[5. 5. 1. 1.]
#  [5. 4. 3. 5.]
#  [1. 3. 2. 3.]
#  [1. 5. 3. 4.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Time: 0.00022000400349497795 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.786051988601685 seconds.
#
#
# Test Case 43:
# --------------------------------------------------------------------------------------------------
#
# [[2. 3. 4. 5.]
#  [3. 5. 4. 1.]
#  [4. 4. 2. 5.]
#  [5. 1. 5. 3.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 17.0.
# 		Time: 0.00022252299822866917 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 17.0.
# 		Optimizer Time: 4.716763973236084 seconds.
#
#
# Test Case 44:
# ----------------------------------------------------------------------------------------------------
#
# [[0. 1. 5. 0.]
#  [1. 5. 2. 4.]
#  [5. 2. 0. 1.]
#  [0. 4. 1. 5.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Time: 0.00031842198222875595 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Optimizer Time: 4.8571457862854 seconds.
#
#
# Test Case 45:
# ------------------------------------------------------------------------------------------------------
#
# [[4. 5. 3. 5.]
#  [5. 2. 4. 2.]
#  [3. 4. 0. 3.]
#  [5. 2. 3. 4.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 17.0.
# 		Time: 0.0002252322155982256 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 17.0.
# 		Optimizer Time: 4.598586797714233 seconds.
#
#
# Test Case 46:
# --------------------------------------------------------------------------------------------------------
#
# [[5. 4. 3. 4.]
#  [4. 2. 5. 2.]
#  [3. 5. 1. 1.]
#  [4. 2. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.00022325501777231693 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.766595363616943 seconds.
#
#
# Test Case 47:
# ----------------------------------------------------------------------------------------------------------
#
# [[5. 4. 4. 1.]
#  [4. 3. 3. 2.]
#  [4. 3. 3. 2.]
#  [1. 2. 2. 2.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Time: 0.00035064504481852055 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.718388795852661 seconds.
#
#
# Test Case 48:
# ------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 5. 1.]
#  [2. 4. 1. 5.]
#  [5. 1. 5. 2.]
#  [1. 5. 2. 3.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Time: 0.00021958118304610252 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.877135515213013 seconds.
#
#
# Test Case 49:
# --------------------------------------------------------------------------------------------------------------
#
# [[1. 4. 3. 4.]
#  [4. 0. 3. 4.]
#  [3. 3. 3. 1.]
#  [4. 4. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.00022606411948800087 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.621869802474976 seconds.
#
#
# Test Case 50:
# ----------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 5. 4.]
#  [2. 4. 2. 4.]
#  [5. 2. 0. 1.]
#  [4. 4. 1. 5.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Time: 0.00022996705956757069 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.862668514251709 seconds.
#
#
# Test Case 51:
# ------------------------------------------------------------------------------------------------------------------
#
# [[3. 5. 4. 0.]
#  [5. 2. 4. 4.]
#  [4. 4. 1. 1.]
#  [0. 4. 1. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Time: 0.0002672418486326933 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.663467645645142 seconds.
#
#
# Test Case 52:
# --------------------------------------------------------------------------------------------------------------------
#
# [[2. 2. 2. 2.]
#  [2. 5. 1. 2.]
#  [2. 1. 2. 3.]
#  [2. 2. 3. 2.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 9.0.
# 		Time: 0.00022475002333521843 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 9.0.
# 		Optimizer Time: 4.832076549530029 seconds.
#
#
# Test Case 53:
# ----------------------------------------------------------------------------------------------------------------------
#
# [[2. 5. 4. 3.]
#  [5. 4. 2. 1.]
#  [4. 2. 5. 4.]
#  [3. 1. 4. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Time: 0.00022434396669268608 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.794809579849243 seconds.
#
#
# Test Case 54:
# ------------------------------------------------------------------------------------------------------------------------
#
# [[0. 3. 4. 5.]
#  [3. 5. 5. 2.]
#  [4. 5. 0. 2.]
#  [5. 2. 2. 2.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 16.0.
# 		Time: 0.00022615608759224415 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 16.0.
# 		Optimizer Time: 4.572734117507935 seconds.
#
#
# Test Case 55:
# --------------------------------------------------------------------------------------------------------------------------
#
# [[5. 4. 1. 1.]
#  [4. 4. 5. 1.]
#  [1. 5. 5. 5.]
#  [1. 1. 5. 3.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Time: 0.00026648608036339283 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.972393989562988 seconds.
#
#
# Test Case 56:
# ----------------------------------------------------------------------------------------------------------------------------
#
# [[0. 2. 2. 5.]
#  [2. 3. 1. 1.]
#  [2. 1. 1. 3.]
#  [5. 1. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 11.0.
# 		Time: 0.00022235698997974396 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 11.0.
# 		Optimizer Time: 4.869774341583252 seconds.
#
#
# Test Case 57:
# ------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 1. 5. 2.]
#  [1. 2. 2. 4.]
#  [5. 2. 4. 3.]
#  [2. 4. 3. 1.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Time: 0.00022410182282328606 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Optimizer Time: 4.7655065059661865 seconds.
#
#
# Test Case 58:
# --------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 3. 4. 2.]
#  [3. 3. 5. 4.]
#  [4. 5. 1. 2.]
#  [2. 4. 2. 4.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Time: 0.00021981005556881428 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.67135763168335 seconds.
#
#
# Test Case 59:
# ----------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 3. 2.]
#  [1. 1. 2. 3.]
#  [3. 2. 1. 3.]
#  [2. 3. 3. 4.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Time: 0.00023586396127939224 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Optimizer Time: 4.627493858337402 seconds.
#
#
# Test Case 60:
# ------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 3. 0.]
#  [1. 4. 1. 1.]
#  [3. 1. 5. 5.]
#  [0. 1. 5. 2.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 10.0.
# 		Time: 0.0002256350126117468 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 10.0.
# 		Optimizer Time: 5.07121205329895 seconds.
#
#
# Test Case 61:
# --------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 0. 4. 5.]
#  [0. 5. 0. 2.]
#  [4. 0. 0. 5.]
#  [5. 2. 5. 3.]]
#
# 	Brute Force
# 		Solution = 1110 [0001].
# 		Maxcut = 12.0.
# 		Time: 0.00026059290394186974 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1110 [0001].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.404959201812744 seconds.
#
#
# Test Case 62:
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 1. 1. 4.]
#  [1. 4. 4. 5.]
#  [1. 4. 1. 1.]
#  [4. 5. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.00027176598086953163 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.8296003341674805 seconds.
#
#
# Test Case 63:
# ------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 3. 4. 2.]
#  [3. 4. 2. 1.]
#  [4. 2. 0. 3.]
#  [2. 1. 3. 4.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 11.0.
# 		Time: 0.0002253199927508831 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 11.0.
# 		Optimizer Time: 4.591571569442749 seconds.
#
#
# Test Case 64:
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 4. 5. 3.]
#  [4. 1. 1. 5.]
#  [5. 1. 5. 2.]
#  [3. 5. 2. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Time: 0.00022855796851217747 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Optimizer Time: 4.715734958648682 seconds.
#
#
# Test Case 65:
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 2. 2.]
#  [1. 4. 3. 5.]
#  [2. 3. 0. 1.]
#  [2. 5. 1. 5.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Time: 0.00022577191703021526 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Optimizer Time: 5.089776992797852 seconds.
#
#
# Test Case 66:
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 3. 3. 2.]
#  [3. 3. 2. 4.]
#  [3. 2. 0. 2.]
#  [2. 4. 2. 1.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Time: 0.00022542616352438927 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.518795490264893 seconds.
#
#
# Test Case 67:
# --------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 1. 1. 4.]
#  [1. 4. 2. 3.]
#  [1. 2. 2. 3.]
#  [4. 3. 3. 2.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Time: 0.00022404687479138374 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Optimizer Time: 4.789011478424072 seconds.
#
#
# Test Case 68:
# ----------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 2. 2. 1.]
#  [2. 4. 3. 2.]
#  [2. 3. 4. 0.]
#  [1. 2. 0. 3.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 8.0.
# 		Time: 0.00023251608945429325 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 8.0.
# 		Optimizer Time: 4.506945610046387 seconds.
#
#
# Test Case 69:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 4. 1. 1.]
#  [4. 5. 5. 0.]
#  [1. 5. 3. 4.]
#  [1. 0. 4. 1.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Time: 0.00025067501701414585 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.853241682052612 seconds.
#
#
# Test Case 70:
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 5. 1. 4.]
#  [5. 1. 2. 1.]
#  [1. 2. 1. 5.]
#  [4. 1. 5. 3.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Time: 0.0002268180251121521 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Optimizer Time: 4.8869733810424805 seconds.
#
#
# Test Case 71:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 3. 4.]
#  [1. 5. 4. 2.]
#  [3. 4. 1. 1.]
#  [4. 2. 1. 3.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Time: 0.0003818008117377758 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Optimizer Time: 4.801348447799683 seconds.
#
#
# Test Case 72:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 3. 4. 1.]
#  [3. 4. 1. 2.]
#  [4. 1. 3. 1.]
#  [1. 2. 1. 1.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 10.0.
# 		Time: 0.00028118095360696316 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 10.0.
# 		Optimizer Time: 4.844598770141602 seconds.
#
#
# Test Case 73:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 1. 3. 4.]
#  [1. 2. 4. 5.]
#  [3. 4. 5. 4.]
#  [4. 5. 4. 3.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 16.0.
# 		Time: 0.0002234429121017456 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 16.0.
# 		Optimizer Time: 4.722171306610107 seconds.
#
#
# Test Case 74:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 5. 0. 4.]
#  [5. 0. 5. 5.]
#  [0. 5. 0. 5.]
#  [4. 5. 5. 1.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 19.0.
# 		Time: 0.00022592884488403797 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 19.0.
# 		Optimizer Time: 4.508012771606445 seconds.
#
#
# Test Case 75:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 1. 5. 3.]
#  [1. 0. 4. 2.]
#  [5. 4. 0. 1.]
#  [3. 2. 1. 4.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.00022572302259504795 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.860702991485596 seconds.
#
#
# Test Case 76:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 4. 3.]
#  [5. 5. 1. 2.]
#  [4. 1. 0. 3.]
#  [3. 2. 3. 4.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Time: 0.0002252780832350254 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.721902847290039 seconds.
#
#
# Test Case 77:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 5. 2. 1.]
#  [5. 1. 1. 2.]
#  [2. 1. 0. 5.]
#  [1. 2. 5. 4.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Time: 0.000267640920355916 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.957250595092773 seconds.
#
#
# Test Case 78:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 2. 4. 1.]
#  [2. 3. 2. 1.]
#  [4. 2. 1. 5.]
#  [1. 1. 5. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Time: 0.00022331788204610348 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.8895838260650635 seconds.
#
#
# Test Case 79:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 4. 5. 4.]
#  [4. 0. 4. 2.]
#  [5. 4. 1. 2.]
#  [4. 2. 2. 3.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Time: 0.0003495989367365837 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.6261091232299805 seconds.
#
#
# Test Case 80:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 2. 1.]
#  [1. 3. 4. 3.]
#  [2. 4. 2. 5.]
#  [1. 3. 5. 2.]]
#
# 	Brute Force
# 		Solution = 0010 [1101].
# 		Maxcut = 11.0.
# 		Time: 0.0002158998977392912 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0010 [1101].
# 		Maxcut = 11.0.
# 		Optimizer Time: 4.671949863433838 seconds.
#
#
# Test Case 81:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 4. 4. 4.]
#  [4. 3. 4. 5.]
#  [4. 4. 0. 4.]
#  [4. 5. 4. 2.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Time: 0.00021772203035652637 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Optimizer Time: 4.542670726776123 seconds.
#
#
# Test Case 82:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 4. 2. 2.]
#  [4. 4. 3. 5.]
#  [2. 3. 0. 4.]
#  [2. 5. 4. 2.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.00022106687538325787 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.585503101348877 seconds.
#
#
# Test Case 83:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 3. 4. 1.]
#  [3. 2. 2. 2.]
#  [4. 2. 4. 1.]
#  [1. 2. 1. 1.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 10.0.
# 		Time: 0.00022242101840674877 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 10.0.
# 		Optimizer Time: 4.769792795181274 seconds.
#
#
# Test Case 84:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 3. 4. 5.]
#  [3. 1. 3. 2.]
#  [4. 3. 1. 4.]
#  [5. 2. 4. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Time: 0.000221210066229105 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.605660438537598 seconds.
#
#
# Test Case 85:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 2. 1. 3.]
#  [2. 5. 2. 5.]
#  [1. 2. 1. 4.]
#  [3. 5. 4. 4.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Time: 0.00022826297208666801 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.740865230560303 seconds.
#
#
# Test Case 86:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 1. 3. 5.]
#  [1. 3. 5. 0.]
#  [3. 5. 0. 5.]
#  [5. 0. 5. 1.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Time: 0.00022892188280820847 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Optimizer Time: 4.705379009246826 seconds.
#
#
# Test Case 87:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 4. 2. 4.]
#  [4. 3. 3. 2.]
#  [2. 3. 4. 3.]
#  [4. 2. 3. 5.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Time: 0.00022123800590634346 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.5198400020599365 seconds.
#
#
# Test Case 88:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 3. 1.]
#  [1. 5. 1. 4.]
#  [3. 1. 2. 4.]
#  [1. 4. 4. 2.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Time: 0.00022615399211645126 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.819371461868286 seconds.
#
#
# Test Case 89:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 5. 5. 4.]
#  [5. 2. 5. 4.]
#  [5. 5. 3. 4.]
#  [4. 4. 4. 2.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 18.0.
# 		Time: 0.00022176490165293217 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 18.0.
# 		Optimizer Time: 4.582793235778809 seconds.
#
#
# Test Case 90:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 4. 1. 4.]
#  [4. 2. 3. 2.]
#  [1. 3. 5. 1.]
#  [4. 2. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Time: 0.0006312120240181684 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.886552095413208 seconds.
#
#
# Test Case 91:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 3. 4. 1.]
#  [3. 5. 4. 3.]
#  [4. 4. 2. 2.]
#  [1. 3. 2. 4.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Time: 0.00025981804355978966 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Optimizer Time: 4.697636365890503 seconds.
#
#
# Test Case 92:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 5. 3.]
#  [2. 3. 5. 3.]
#  [5. 5. 0. 3.]
#  [3. 3. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 16.0.
# 		Time: 0.00021788990125060081 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 16.0.
# 		Optimizer Time: 4.7197113037109375 seconds.
#
#
# Test Case 93:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 5. 2. 1.]
#  [5. 4. 4. 5.]
#  [2. 4. 0. 1.]
#  [1. 5. 1. 5.]]
#
# 	Brute Force
# 		Solution = 0100 [1011].
# 		Maxcut = 14.0.
# 		Time: 0.00022174697369337082 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0100 [1011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 4.782748460769653 seconds.
#
#
# Test Case 94:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 2. 2. 0.]
#  [2. 3. 5. 3.]
#  [2. 5. 2. 0.]
#  [0. 3. 0. 5.]]
#
# 	Brute Force
# 		Solution = 0100 [1011].
# 		Maxcut = 10.0.
# 		Time: 0.0002237851731479168 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0100 [1011].
# 		Maxcut = 10.0.
# 		Optimizer Time: 4.638951301574707 seconds.
#
#
# Test Case 95:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 5. 3. 3.]
#  [5. 1. 1. 4.]
#  [3. 1. 0. 5.]
#  [3. 4. 5. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 17.0.
# 		Time: 0.0002450330648571253 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 17.0.
# 		Optimizer Time: 4.658194065093994 seconds.
#
#
# Test Case 96:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 1. 3.]
#  [1. 5. 1. 5.]
#  [1. 1. 1. 2.]
#  [3. 5. 2. 4.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Time: 0.00022565294057130814 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Optimizer Time: 4.881375551223755 seconds.
#
#
# Test Case 97:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 5. 3. 3.]
#  [5. 0. 1. 5.]
#  [3. 1. 3. 2.]
#  [3. 5. 2. 2.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.00023743207566440105 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 4.807986259460449 seconds.
#
#
# Test Case 98:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 5. 3. 1.]
#  [5. 1. 1. 5.]
#  [3. 1. 5. 3.]
#  [1. 5. 3. 3.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Time: 0.00022865599021315575 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Optimizer Time: 5.648454427719116 seconds.
#
#
# Test Case 99:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 4. 3.]
#  [1. 2. 4. 1.]
#  [4. 4. 4. 5.]
#  [3. 1. 5. 1.]]
#
# 	Brute Force
# 		Solution = 0010 [1101].
# 		Maxcut = 13.0.
# 		Time: 0.00022492301650345325 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0010 [1101].
# 		Maxcut = 13.0.
# 		Optimizer Time: 4.7376978397369385 seconds.

# %%
print(f'Success: {success} / {num_tests} = {(success/num_tests) * 100} %')
print(f'Fail: {failure} / {num_tests} = {(failure/num_tests) * 100} %')
# Out:
# Success: 100 / 100 = 100.0 %
# Fail: 0 / 100 = 0.0 %
