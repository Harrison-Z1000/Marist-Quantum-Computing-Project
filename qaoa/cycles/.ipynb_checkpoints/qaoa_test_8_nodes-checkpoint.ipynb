# %% [markdown]
# ## Random Graphs
#
# ### Helper Functions
#
# Randomly generate an adjancency matrix...

# %%
import timeit
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations, groupby

# Size of NxN Matrix
n = 8

# Moved to global scopee to allow for timing
bf_bit_string, bf_cost = None, None

def random_row():
    row = list(np.random.choice((0, 1, 2, 3, 4, 5),size=n))
    
    # Make sure there's no isolated nodes
    if sum(row) == 0:
        row = random_row()
    return row

def random_matrix():
    rows = []
    for i in range(0, n):
        rows.append(random_row())
    numpy_matrix = np.matrix(rows)
    
    return numpy_matrix

def random_graph():
    np_matrix = random_matrix()
    g = nx.convert_matrix.from_numpy_matrix(
        np_matrix, 
        parallel_edges=False, 
        create_using=nx.Graph
    )
    
    # nx.draw(g, node_color='lightblue', 
    #     with_labels=True, 
    #     node_size=500)
    
    return g, np_matrix

# %% [markdown]
# ### Brute Force

# %%
def brute_force(graph, w):
    global bf_bit_string
    global bf_cost
    
    bf_bit_string = None
    bf_cost = None
    
    best_cost_brute = 0
    for b in range(2**n):
        x = [int(t) for t in reversed(list(bin(b)[2:].zfill(n)))]
        cost = 0
        for i in range(n):
            for j in range(n):
                cost = cost + w[i,j]*x[i]*(1-x[j])
        if best_cost_brute < cost:
            best_cost_brute = cost
            xbest_brute = x
    bf_bit_string = xbest_brute
    bf_cost = best_cost_brute
    return xbest_brute, best_cost_brute

# %% [markdown]
# ### Quantum Apporximation Optimization Algorithm

# %%
import networkx as nx
import numpy as np
import plotly.graph_objects as go
import matplotlib as mpl
import pandas as pd
from IPython.display import clear_output
from plotly.subplots import make_subplots
from matplotlib import pyplot as plt
from qiskit import Aer
from qiskit import QuantumCircuit
from qiskit.visualization import plot_state_city
from qiskit.algorithms.optimizers import COBYLA, SLSQP, ADAM
from time import time
from copy import copy
from typing import List
from qc_grader.graph_util import display_maxcut_widget, QAOA_widget, graphs
from qiskit.circuit import Parameter, ParameterVector
from qiskit_optimization import QuadraticProgram
from qiskit.algorithms import QAOA
from qiskit_optimization.algorithms import MinimumEigenOptimizer

def maxcut_cost_fn(graph: nx.Graph, bitstring: List[int]) -> float:
    """
    Computes the maxcut cost function value for a given graph and cut represented by some bitstring
    Args:
        graph: The graph to compute cut values for
        bitstring: A list of integer values '0' or '1' specifying a cut of the graph
    Returns:
        The value of the cut
    """
    #Get the weight matrix of the graph
    weight_matrix = nx.adjacency_matrix(graph).toarray()
    size = weight_matrix.shape[0]
    value = 0.
    for i in range(size):
        for j in range(size):
            value = value + weight_matrix[i][j] * bitstring[i] * (1-bitstring[j])

    return value

def quadratic_program_from_graph(graph: nx.Graph) -> QuadraticProgram:
    """Constructs a quadratic program from a given graph for a MaxCut problem instance.
    Args:
        graph: Underlying graph of the problem.
    Returns:
        QuadraticProgram
    """
    #Get weight matrix of graph
    weight_matrix = nx.adjacency_matrix(graph)
    shape = weight_matrix.shape
    size = shape[0]
    
    #Build qubo matrix Q from weight matrix W
    qubo_matrix = np.zeros((size, size))
    qubo_vector = np.zeros(size)
    for i in range(size):
        for j in range(size):
            qubo_matrix[i, j] -= weight_matrix[i, j]
    for i in range(size):
        for j in range(size):
            qubo_vector[i] += weight_matrix[i,j]

    quadratic_program = QuadraticProgram('MaxCut as QUBO')
    for i in range(size):
        quadratic_program.binary_var(name = f'x_{i}')

    quadratic_program.maximize(quadratic = qubo_matrix, linear = qubo_vector)
    
    return quadratic_program

def qaoa_circuit(qubo: QuadraticProgram, p: int = 1, params: dict = []) -> QuantumCircuit:
    """
    Given a QUBO instance and the number of layers p, constructs the corresponding parameterized QAOA circuit with p layers.
    Args:
        qubo: The quadratic program instance
        p: The number of layers in the QAOA circuit
    Returns:
        The parameterized QAOA circuit
    """
    size = len(qubo.variables)
    qubo_matrix = qubo.objective.quadratic.to_array(symmetric=True)
    qubo_linearity = qubo.objective.linear.to_array()

    #Prepare the quantum and classical registers
    qaoa_circuit = QuantumCircuit(size,size)
    #Apply the initial layer of Hadamard gates to all qubits
    qaoa_circuit.h(range(size))

    #Create the parameters to be used in the circuit
    if not params:
        gammas = ParameterVector('gamma', p)
        betas = ParameterVector('beta', p)
    else:
        gammas = [params[1]]
        betas = [params[0]]

    #Outer loop to create each layer
    for i in range(p):

        #Apply R_Z rotational gates from cost layer
        for qubit in range(size):
            sum =0
            for col in range(size):
                sum += qubo_matrix[qubit][col]
            theta = (qubo_linearity[qubit] + sum) * gammas[i]
            qaoa_circuit.rz(theta, qubit)

        #Apply R_ZZ rotational gates for entangled qubit rotations from cost layer
        for j in range(size):
            for k in range(size):
                if j != k:
                    theta = qubo_matrix[j][k] * gammas[i] / 2
                    qaoa_circuit.rzz(theta, j, k)

        # Apply single qubit X - rotations with angle 2*beta_i to all qubits
        for qubit in range(size):
            qaoa_circuit.rx(2 * betas[i], qubit)
    return qaoa_circuit

def plot_qaoa_energy_landscape(graph: nx.Graph, cvar: float = None, plot: bool = True):
    num_shots = 1000
    seed = 42
    simulator = Aer.get_backend('qasm_simulator')
    simulator.set_options(seed_simulator = 42)

    #Generate circuit
    circuit = qaoa_circuit(qubo = quadratic_program_from_graph(graph), p=1)
    circuit.measure(range(graph.number_of_nodes()),range(graph.number_of_nodes()))

    #Create dictionary with precomputed cut values for all bitstrings 
    cut_values = {}
    size = graph.number_of_nodes()
    for i in range(2**size):
        bitstr = '{:b}'.format(i).rjust(size, '0')[::-1]
        x = [int(bit) for bit in bitstr]
        cut_values[bitstr] = maxcut_cost_fn(graph, x)

    #Perform grid search over all parameters
    data_points = []
    max_energy = None
    for beta in np.linspace(0,np.pi, 50):
        for gamma in np.linspace(0, 4*np.pi, 50):
            bound_circuit = circuit.assign_parameters([beta, gamma])
            result = simulator.run(bound_circuit, shots = num_shots).result()
            statevector = result.get_counts(bound_circuit)
            energy = 0
            measured_cuts = []
            for bitstring, count in statevector.items():
                measured_cuts =  measured_cuts + [cut_values[bitstring]]*count

            if cvar is None:
                # Calculate the mean of all cut values
                energy = sum(measured_cuts)/num_shots
            else:
                alpha_n = cvar*num_shots
                measured_cuts.sort(reverse=True)
                energy = sum(measured_cuts[:int(alpha_n)])/alpha_n

            #Update optimal parameters
            if max_energy is None or energy > max_energy:
                max_energy = energy
                optimum = {'beta': beta, 'gamma': gamma, 'energy': energy}

            #Update data
            data_points.append({'beta': beta, 'gamma': gamma, 'energy': energy})

    if plot:
        #Create and display surface plot from data_points
        df = pd.DataFrame(data_points)
        df = df.pivot(index='beta', columns='gamma', values='energy')
        matrix = df.to_numpy()
        beta_values = df.index.tolist()
        gamma_values = df.columns.tolist()

        surface_plot = go.Surface(
            x=gamma_values, 
            y=beta_values,
            z=matrix,
            coloraxis = 'coloraxis'
        )
        fig = go.Figure(data = surface_plot)
        fig.show()

    #Return optimum
    return optimum

def qaoa(nx_g):
    """
    Outline of how to use the QAOA class
        problem = QuadraticProgram()
        # specify problem here
        # specify minimum eigen solver to be used, e.g., QAOA
        qaoa = QAOA(...)
        optimizer = MinimumEigenOptimizer(qaoa)
        result = optimizer.solve(problem)
    
    """
    backend = Aer.get_backend('statevector_simulator')
    qaoa = QAOA(optimizer = ADAM(), quantum_instance = backend, reps=1, initial_point = [0.1,0.1])
    eigen_optimizer = MinimumEigenOptimizer(min_eigen_solver = qaoa)
    quadratic_program = quadratic_program_from_graph(nx_g)
    result = eigen_optimizer.solve(quadratic_program)
    
    # print results
    bit_string = map(int, result.x)
    return bit_string, result.fval, result.min_eigen_solver_result.optimizer_time

# %% [markdown]
# ## Tests

# %%
# Generate 1,000 graphs
success = 0
failure = 0

# TODO: Change the number of tests, ad hoc
num_tests: int = 100

for graph_id in range(num_tests):
    global bf_bit_string
    global bf_cost
    
    # Generate Random Graph
    graph, matrix = random_graph()
    
    # Computing the weight matrix from the random graph
    w = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            temp = graph.get_edge_data(i,j,default=0)
            if temp != 0:
                w[i,j] = temp['weight']
    
    print(f'\nTest Case {graph_id}: ')
    print('------------' + '-' * (len(str(graph_id)) * 2))
    print()
    print(w)
    
    # Brute Force Approach
    #
    # Time brute force algorithm
    bf_time: float = timeit.timeit(lambda: brute_force(graph, w), number=1)
    
    # Parse the bit sting answer
    bf_x = ''.join(str(e) for e in bf_bit_string)
    bf_x_inverse = ''.join('1' if x == '0' else '0' for x in bf_x)
    
    # Print results
    print('\n\tBrute Force')
    print(f'\t\tSolution = {bf_x} [{bf_x_inverse}].')
    print(f'\t\tMaxcut = {str(bf_cost)}.')
    print(f'\t\tTime: {bf_time} seconds.')
    
    # QAOA Approach
    #
    # Run QAOA
    qaoa_bit_string, qaoa_cost, qaoa_optimizer_time = qaoa(graph)
    
    # Parse the bit sting answer
    qaoa_x = ''.join(str(e) for e in qaoa_bit_string)
    qaoa_x_inverse = ''.join('1' if x == '0' else '0' for x in qaoa_x)
    
    # Print results
    print('\n\tQuantum Approximation Optimization Algorithm (QAOA):')
    print(f'\t\tSolution = {qaoa_x} [{qaoa_x_inverse}].')
    print(f'\t\tMaxcut = {str(qaoa_cost)}.')
    print(f'\t\tOptimizer Time: {str(qaoa_optimizer_time)} seconds.')
    # print(f'\t\tCompmute Minimum Eigenvalue Time: {str(optimizer_time)} seconds.')
    print()
    
    # Check validity
    if bf_x == qaoa_x or bf_x == qaoa_x_inverse or qaoa_x == bf_x_inverse:
        success += 1
    else:
        failure += 1
# Out:
# Test Case 0:
# ------------
#
# [[4. 5. 5. 1. 5. 3. 4. 2.]
#  [5. 0. 1. 1. 4. 3. 5. 2.]
#  [5. 1. 3. 5. 4. 4. 3. 4.]
#  [1. 1. 5. 3. 1. 5. 2. 1.]
#  [5. 4. 4. 1. 4. 4. 2. 1.]
#  [3. 3. 4. 5. 4. 4. 0. 0.]
#  [4. 5. 3. 2. 2. 0. 2. 3.]
#  [2. 2. 4. 1. 1. 0. 3. 0.]]
#
# 	Brute Force
# 		Solution = 01100110 [10011001].
# 		Maxcut = 53.0.
# 		Time: 0.017428043007384986 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01100110 [10011001].
# 		Maxcut = 53.0.
# 		Optimizer Time: 20.657767057418823 seconds.
#
#
# Test Case 1:
# --------------
#
# [[3. 2. 4. 4. 4. 3. 3. 1.]
#  [2. 2. 1. 2. 2. 1. 3. 3.]
#  [4. 1. 5. 2. 4. 1. 3. 3.]
#  [4. 2. 2. 3. 3. 4. 3. 5.]
#  [4. 2. 4. 3. 4. 5. 3. 5.]
#  [3. 1. 1. 4. 5. 0. 5. 5.]
#  [3. 3. 3. 3. 3. 5. 5. 2.]
#  [1. 3. 3. 5. 5. 5. 2. 2.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 57.0.
# 		Time: 0.01658342601149343 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01110100 [10001011].
# 		Maxcut = 57.0.
# 		Optimizer Time: 20.96103048324585 seconds.
#
#
# Test Case 2:
# ----------------
#
# [[5. 0. 5. 3. 2. 2. 3. 5.]
#  [0. 5. 4. 5. 2. 2. 2. 5.]
#  [5. 4. 3. 1. 1. 5. 2. 2.]
#  [3. 5. 1. 2. 1. 1. 0. 0.]
#  [2. 2. 1. 1. 3. 4. 5. 0.]
#  [2. 2. 5. 1. 4. 3. 4. 3.]
#  [3. 2. 2. 0. 5. 4. 3. 2.]
#  [5. 5. 2. 0. 0. 3. 2. 5.]]
#
# 	Brute Force
# 		Solution = 11000100 [00111011].
# 		Maxcut = 53.0.
# 		Time: 0.017081045982195064 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11000100 [00111011].
# 		Maxcut = 53.0.
# 		Optimizer Time: 17.608864068984985 seconds.
#
#
# Test Case 3:
# ------------------
#
# [[4. 2. 2. 3. 5. 2. 3. 1.]
#  [2. 2. 3. 1. 3. 2. 5. 4.]
#  [2. 3. 0. 0. 4. 3. 3. 1.]
#  [3. 1. 0. 3. 4. 5. 5. 5.]
#  [5. 3. 4. 4. 2. 0. 2. 1.]
#  [2. 2. 3. 5. 0. 3. 5. 1.]
#  [3. 5. 3. 5. 2. 5. 0. 5.]
#  [1. 4. 1. 5. 1. 1. 5. 2.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 55.0.
# 		Time: 0.01747854400309734 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11110000 [00001111].
# 		Maxcut = 55.0.
# 		Optimizer Time: 21.273977756500244 seconds.
#
#
# Test Case 4:
# --------------------
#
# [[4. 3. 5. 2. 4. 3. 3. 3.]
#  [3. 2. 5. 2. 3. 3. 2. 5.]
#  [5. 5. 5. 1. 4. 5. 4. 3.]
#  [2. 2. 1. 4. 2. 4. 4. 4.]
#  [4. 3. 4. 2. 3. 5. 0. 4.]
#  [3. 3. 5. 4. 5. 4. 5. 2.]
#  [3. 2. 4. 4. 0. 5. 4. 2.]
#  [3. 5. 3. 4. 4. 2. 2. 1.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 58.0.
# 		Time: 0.017145324003649876 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11010100 [00101011].
# 		Maxcut = 58.0.
# 		Optimizer Time: 20.98122787475586 seconds.
#
#
# Test Case 5:
# ----------------------
#
# [[0. 1. 2. 4. 5. 2. 5. 4.]
#  [1. 2. 5. 3. 5. 0. 0. 0.]
#  [2. 5. 4. 1. 3. 1. 3. 4.]
#  [4. 3. 1. 0. 2. 5. 1. 3.]
#  [5. 5. 3. 2. 3. 4. 5. 3.]
#  [2. 0. 1. 5. 4. 5. 5. 3.]
#  [5. 0. 3. 1. 5. 5. 2. 4.]
#  [4. 0. 4. 3. 3. 3. 4. 3.]]
#
# 	Brute Force
# 		Solution = 00111010 [11000101].
# 		Maxcut = 58.0.
# 		Time: 0.029836913978215307 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00111010 [11000101].
# 		Maxcut = 58.0.
# 		Optimizer Time: 18.21300721168518 seconds.
#
#
# Test Case 6:
# ------------------------
#
# [[5. 3. 1. 5. 4. 3. 3. 3.]
#  [3. 1. 4. 1. 4. 1. 4. 1.]
#  [1. 4. 1. 1. 5. 2. 3. 1.]
#  [5. 1. 1. 0. 4. 4. 5. 4.]
#  [4. 4. 5. 4. 4. 5. 5. 3.]
#  [3. 1. 2. 4. 5. 0. 5. 5.]
#  [3. 4. 3. 5. 5. 5. 3. 5.]
#  [3. 1. 1. 4. 3. 5. 5. 5.]]
#
# 	Brute Force
# 		Solution = 10100110 [01011001].
# 		Maxcut = 60.0.
# 		Time: 0.04328965101740323 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10100110 [01011001].
# 		Maxcut = 60.0.
# 		Optimizer Time: 22.442054986953735 seconds.
#
#
# Test Case 7:
# --------------------------
#
# [[4. 1. 1. 3. 2. 3. 1. 3.]
#  [1. 1. 2. 1. 0. 5. 4. 3.]
#  [1. 2. 3. 2. 3. 1. 1. 1.]
#  [3. 1. 2. 4. 1. 4. 1. 4.]
#  [2. 0. 3. 1. 2. 2. 1. 1.]
#  [3. 5. 1. 4. 2. 1. 5. 4.]
#  [1. 4. 1. 1. 1. 5. 1. 2.]
#  [3. 3. 1. 4. 1. 4. 2. 4.]]
#
# 	Brute Force
# 		Solution = 01011010 [10100101].
# 		Maxcut = 41.0.
# 		Time: 0.01704268201137893 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01011010 [10100101].
# 		Maxcut = 41.0.
# 		Optimizer Time: 21.865553379058838 seconds.
#
#
# Test Case 8:
# ----------------------------
#
# [[3. 0. 4. 4. 2. 3. 2. 4.]
#  [0. 2. 3. 2. 3. 3. 3. 4.]
#  [4. 3. 0. 5. 3. 5. 0. 4.]
#  [4. 2. 5. 3. 3. 3. 3. 1.]
#  [2. 3. 3. 3. 4. 2. 2. 1.]
#  [3. 3. 5. 3. 2. 1. 4. 5.]
#  [2. 3. 0. 3. 2. 4. 3. 1.]
#  [4. 4. 4. 1. 1. 5. 1. 4.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 53.0.
# 		Time: 0.022745444992324337 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11010100 [00101011].
# 		Maxcut = 53.0.
# 		Optimizer Time: 21.158984661102295 seconds.
#
#
# Test Case 9:
# ------------------------------
#
# [[2. 1. 2. 5. 4. 5. 4. 1.]
#  [1. 3. 1. 2. 3. 2. 1. 1.]
#  [2. 1. 2. 4. 3. 1. 3. 2.]
#  [5. 2. 4. 0. 5. 1. 5. 4.]
#  [4. 3. 3. 5. 3. 2. 1. 3.]
#  [5. 2. 1. 1. 2. 5. 3. 5.]
#  [4. 1. 3. 5. 1. 3. 3. 4.]
#  [1. 1. 2. 4. 3. 5. 4. 3.]]
#
# 	Brute Force
# 		Solution = 00011110 [11100001].
# 		Maxcut = 53.0.
# 		Time: 0.017988691019127145 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00011110 [11100001].
# 		Maxcut = 53.0.
# 		Optimizer Time: 20.89623236656189 seconds.
#
#
# Test Case 10:
# --------------------------------
#
# [[0. 4. 4. 5. 2. 3. 4. 4.]
#  [4. 4. 3. 5. 3. 3. 2. 3.]
#  [4. 3. 2. 2. 1. 1. 3. 4.]
#  [5. 5. 2. 4. 5. 1. 2. 3.]
#  [2. 3. 1. 5. 3. 3. 5. 4.]
#  [3. 3. 1. 1. 3. 1. 3. 4.]
#  [4. 2. 3. 2. 5. 3. 0. 5.]
#  [4. 3. 4. 3. 4. 4. 5. 2.]]
#
# 	Brute Force
# 		Solution = 00110110 [11001001].
# 		Maxcut = 59.0.
# 		Time: 0.01669042100547813 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00110110 [11001001].
# 		Maxcut = 59.0.
# 		Optimizer Time: 21.352389335632324 seconds.
#
#
# Test Case 11:
# ----------------------------------
#
# [[4. 5. 1. 2. 4. 4. 4. 3.]
#  [5. 1. 2. 4. 5. 4. 5. 5.]
#  [1. 2. 2. 4. 3. 4. 5. 2.]
#  [2. 4. 4. 0. 1. 4. 5. 0.]
#  [4. 5. 3. 1. 4. 1. 5. 1.]
#  [4. 4. 4. 4. 1. 1. 2. 3.]
#  [4. 5. 5. 5. 5. 2. 4. 1.]
#  [3. 5. 2. 0. 1. 3. 1. 1.]]
#
# 	Brute Force
# 		Solution = 11100000 [00011111].
# 		Maxcut = 58.0.
# 		Time: 0.01877402001991868 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11100000 [00011111].
# 		Maxcut = 58.0.
# 		Optimizer Time: 21.260797262191772 seconds.
#
#
# Test Case 12:
# ------------------------------------
#
# [[1. 5. 4. 1. 1. 2. 3. 4.]
#  [5. 3. 4. 5. 3. 2. 3. 5.]
#  [4. 4. 5. 1. 2. 4. 3. 2.]
#  [1. 5. 1. 1. 5. 4. 4. 2.]
#  [1. 3. 2. 5. 0. 3. 1. 2.]
#  [2. 2. 4. 4. 3. 1. 5. 2.]
#  [3. 3. 3. 4. 1. 5. 4. 1.]
#  [4. 5. 2. 2. 2. 2. 1. 2.]]
#
# 	Brute Force
# 		Solution = 11001100 [00110011].
# 		Maxcut = 54.0.
# 		Time: 0.016634959989460185 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11001100 [00110011].
# 		Maxcut = 54.0.
# 		Optimizer Time: 20.997801542282104 seconds.
#
#
# Test Case 13:
# --------------------------------------
#
# [[5. 1. 3. 0. 4. 2. 4. 4.]
#  [1. 4. 1. 3. 2. 4. 3. 1.]
#  [3. 1. 4. 1. 4. 5. 5. 5.]
#  [0. 3. 1. 5. 1. 1. 5. 2.]
#  [4. 2. 4. 1. 0. 3. 1. 2.]
#  [2. 4. 5. 1. 3. 0. 3. 2.]
#  [4. 3. 5. 5. 1. 3. 5. 5.]
#  [4. 1. 5. 2. 2. 2. 5. 2.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 52.0.
# 		Time: 0.01885720799327828 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11110000 [00001111].
# 		Maxcut = 52.0.
# 		Optimizer Time: 21.834418058395386 seconds.
#
#
# Test Case 14:
# ----------------------------------------
#
# [[3. 4. 3. 2. 3. 1. 4. 5.]
#  [4. 3. 1. 0. 2. 2. 5. 5.]
#  [3. 1. 0. 4. 1. 2. 4. 5.]
#  [2. 0. 4. 1. 3. 4. 5. 0.]
#  [3. 2. 1. 3. 4. 5. 5. 2.]
#  [1. 2. 2. 4. 5. 4. 3. 2.]
#  [4. 5. 4. 5. 5. 3. 5. 4.]
#  [5. 5. 5. 0. 2. 2. 4. 3.]]
#
# 	Brute Force
# 		Solution = 10100110 [01011001].
# 		Maxcut = 57.0.
# 		Time: 0.017380670993588865 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10100110 [01011001].
# 		Maxcut = 57.0.
# 		Optimizer Time: 22.491395473480225 seconds.
#
#
# Test Case 15:
# ------------------------------------------
#
# [[5. 1. 1. 3. 1. 2. 3. 5.]
#  [1. 5. 2. 2. 5. 2. 1. 2.]
#  [1. 2. 4. 3. 5. 5. 4. 2.]
#  [3. 2. 3. 0. 4. 5. 1. 5.]
#  [1. 5. 5. 4. 5. 1. 3. 2.]
#  [2. 2. 5. 5. 1. 1. 4. 5.]
#  [3. 1. 4. 1. 3. 4. 4. 0.]
#  [5. 2. 2. 5. 2. 5. 0. 4.]]
#
# 	Brute Force
# 		Solution = 10001100 [01110011].
# 		Maxcut = 53.0.
# 		Time: 0.042104645021026954 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10001100 [01110011].
# 		Maxcut = 53.0.
# 		Optimizer Time: 21.207590579986572 seconds.
#
#
# Test Case 16:
# --------------------------------------------
#
# [[5. 1. 2. 4. 5. 5. 4. 3.]
#  [1. 3. 2. 4. 4. 5. 2. 4.]
#  [2. 2. 4. 2. 1. 5. 2. 4.]
#  [4. 4. 2. 2. 5. 1. 5. 3.]
#  [5. 4. 1. 5. 1. 5. 5. 5.]
#  [5. 5. 5. 1. 5. 0. 2. 2.]
#  [4. 2. 2. 5. 5. 2. 2. 3.]
#  [3. 4. 4. 3. 5. 2. 3. 4.]]
#
# 	Brute Force
# 		Solution = 11101000 [00010111].
# 		Maxcut = 64.0.
# 		Time: 0.017905049986438826 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11101000 [00010111].
# 		Maxcut = 64.0.
# 		Optimizer Time: 21.668494939804077 seconds.
#
#
# Test Case 17:
# ----------------------------------------------
#
# [[5. 3. 5. 4. 3. 5. 1. 3.]
#  [3. 5. 5. 3. 3. 1. 4. 3.]
#  [5. 5. 4. 3. 1. 5. 5. 3.]
#  [4. 3. 3. 4. 2. 5. 1. 3.]
#  [3. 3. 1. 2. 2. 1. 3. 4.]
#  [5. 1. 5. 5. 1. 5. 2. 4.]
#  [1. 4. 5. 1. 3. 2. 3. 1.]
#  [3. 3. 3. 3. 4. 4. 1. 0.]]
#
# 	Brute Force
# 		Solution = 01101100 [10010011].
# 		Maxcut = 57.0.
# 		Time: 0.016944305010838434 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01101100 [10010011].
# 		Maxcut = 57.0.
# 		Optimizer Time: 21.82795000076294 seconds.
#
#
# Test Case 18:
# ------------------------------------------------
#
# [[3. 5. 3. 4. 2. 2. 2. 4.]
#  [5. 2. 5. 5. 3. 1. 5. 2.]
#  [3. 5. 0. 1. 5. 2. 4. 5.]
#  [4. 5. 1. 3. 1. 4. 3. 1.]
#  [2. 3. 5. 1. 2. 2. 5. 3.]
#  [2. 1. 2. 4. 2. 2. 4. 1.]
#  [2. 5. 4. 3. 5. 4. 0. 4.]
#  [4. 2. 5. 1. 3. 1. 4. 0.]]
#
# 	Brute Force
# 		Solution = 10110010 [01001101].
# 		Maxcut = 59.0.
# 		Time: 0.031147214001975954 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10110010 [01001101].
# 		Maxcut = 59.0.
# 		Optimizer Time: 21.384564876556396 seconds.
#
#
# Test Case 19:
# --------------------------------------------------
#
# [[0. 4. 5. 1. 3. 2. 3. 5.]
#  [4. 0. 5. 4. 1. 1. 1. 2.]
#  [5. 5. 4. 5. 5. 1. 4. 4.]
#  [1. 4. 5. 2. 5. 2. 5. 2.]
#  [3. 1. 5. 5. 2. 5. 0. 2.]
#  [2. 1. 1. 2. 5. 1. 2. 0.]
#  [3. 1. 4. 5. 0. 2. 2. 3.]
#  [5. 2. 4. 2. 2. 0. 3. 1.]]
#
# 	Brute Force
# 		Solution = 10110100 [01001011].
# 		Maxcut = 57.0.
# 		Time: 0.0168676890025381 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10110100 [01001011].
# 		Maxcut = 57.0.
# 		Optimizer Time: 21.416444063186646 seconds.
#
#
# Test Case 20:
# ----------------------------------------------------
#
# [[2. 4. 2. 3. 4. 3. 5. 4.]
#  [4. 5. 3. 2. 5. 1. 2. 4.]
#  [2. 3. 4. 1. 5. 5. 1. 4.]
#  [3. 2. 1. 1. 2. 3. 2. 5.]
#  [4. 5. 5. 2. 1. 4. 3. 5.]
#  [3. 1. 5. 3. 4. 1. 5. 2.]
#  [5. 2. 1. 2. 3. 5. 0. 5.]
#  [4. 4. 4. 5. 5. 2. 5. 3.]]
#
# 	Brute Force
# 		Solution = 00111010 [11000101].
# 		Maxcut = 62.0.
# 		Time: 0.016712112992536277 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00111010 [11000101].
# 		Maxcut = 62.0.
# 		Optimizer Time: 21.717116594314575 seconds.
#
#
# Test Case 21:
# ------------------------------------------------------
#
# [[1. 1. 4. 4. 1. 5. 2. 2.]
#  [1. 4. 1. 2. 4. 1. 4. 3.]
#  [4. 1. 5. 1. 1. 5. 3. 5.]
#  [4. 2. 1. 5. 4. 1. 2. 2.]
#  [1. 4. 1. 4. 0. 3. 1. 2.]
#  [5. 1. 5. 1. 3. 5. 4. 5.]
#  [2. 4. 3. 2. 1. 4. 4. 1.]
#  [2. 3. 5. 2. 2. 5. 1. 5.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 54.0.
# 		Time: 0.017400655982783064 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01110100 [10001011].
# 		Maxcut = 54.0.
# 		Optimizer Time: 21.50558352470398 seconds.
#
#
# Test Case 22:
# --------------------------------------------------------
#
# [[5. 3. 0. 1. 4. 2. 1. 4.]
#  [3. 2. 1. 4. 3. 4. 2. 5.]
#  [0. 1. 1. 2. 3. 3. 0. 5.]
#  [1. 4. 2. 1. 2. 2. 3. 1.]
#  [4. 3. 3. 2. 5. 2. 5. 1.]
#  [2. 4. 3. 2. 2. 0. 2. 0.]
#  [1. 2. 0. 3. 5. 2. 4. 3.]
#  [4. 5. 5. 1. 1. 0. 3. 2.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 53.0.
# 		Time: 0.017689384025288746 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11100010 [00011101].
# 		Maxcut = 53.0.
# 		Optimizer Time: 19.295103788375854 seconds.
#
#
# Test Case 23:
# ----------------------------------------------------------
#
# [[1. 5. 4. 1. 4. 0. 1. 1.]
#  [5. 1. 1. 5. 2. 4. 2. 2.]
#  [4. 1. 5. 2. 1. 1. 1. 2.]
#  [1. 5. 2. 3. 3. 4. 1. 5.]
#  [4. 2. 1. 3. 0. 4. 5. 3.]
#  [0. 4. 1. 4. 4. 1. 2. 4.]
#  [1. 2. 1. 1. 5. 2. 4. 5.]
#  [1. 2. 2. 5. 3. 4. 5. 0.]]
#
# 	Brute Force
# 		Solution = 10010110 [01101001].
# 		Maxcut = 55.0.
# 		Time: 0.017733485001372173 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10010110 [01101001].
# 		Maxcut = 55.0.
# 		Optimizer Time: 23.577759504318237 seconds.
#
#
# Test Case 24:
# ------------------------------------------------------------
#
# [[4. 5. 4. 3. 3. 5. 3. 5.]
#  [5. 0. 5. 4. 2. 5. 2. 1.]
#  [4. 5. 5. 4. 1. 2. 3. 2.]
#  [3. 4. 4. 5. 4. 5. 4. 1.]
#  [3. 2. 1. 4. 4. 4. 5. 3.]
#  [5. 5. 2. 5. 4. 1. 4. 1.]
#  [3. 2. 3. 4. 5. 4. 2. 4.]
#  [5. 1. 2. 1. 3. 1. 4. 0.]]
#
# 	Brute Force
# 		Solution = 11010010 [00101101].
# 		Maxcut = 60.0.
# 		Time: 0.02978416599216871 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11010010 [00101101].
# 		Maxcut = 60.0.
# 		Optimizer Time: 18.857563018798828 seconds.
#
#
# Test Case 25:
# --------------------------------------------------------------
#
# [[1. 2. 1. 4. 4. 1. 1. 4.]
#  [2. 3. 1. 0. 2. 3. 3. 3.]
#  [1. 1. 5. 0. 2. 1. 5. 4.]
#  [4. 0. 0. 3. 3. 4. 2. 3.]
#  [4. 2. 2. 3. 4. 0. 4. 4.]
#  [1. 3. 1. 4. 0. 4. 1. 4.]
#  [1. 3. 5. 2. 4. 1. 1. 5.]
#  [4. 3. 4. 3. 4. 4. 5. 1.]]
#
# 	Brute Force
# 		Solution = 10001110 [01110001].
# 		Maxcut = 49.0.
# 		Time: 0.028591697016963735 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10001110 [01110001].
# 		Maxcut = 49.0.
# 		Optimizer Time: 19.201326608657837 seconds.
#
#
# Test Case 26:
# ----------------------------------------------------------------
#
# [[4. 4. 2. 3. 1. 3. 5. 2.]
#  [4. 4. 0. 2. 2. 1. 2. 5.]
#  [2. 0. 4. 5. 1. 5. 4. 2.]
#  [3. 2. 5. 3. 1. 4. 4. 5.]
#  [1. 2. 1. 1. 2. 4. 5. 1.]
#  [3. 1. 5. 4. 4. 3. 1. 4.]
#  [5. 2. 4. 4. 5. 1. 3. 1.]
#  [2. 5. 2. 5. 1. 4. 1. 3.]]
#
# 	Brute Force
# 		Solution = 01010110 [10101001].
# 		Maxcut = 56.0.
# 		Time: 0.016786167019745335 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01010110 [10101001].
# 		Maxcut = 56.0.
# 		Optimizer Time: 22.26519250869751 seconds.
#
#
# Test Case 27:
# ------------------------------------------------------------------
#
# [[3. 1. 5. 4. 4. 1. 3. 5.]
#  [1. 3. 2. 3. 2. 5. 4. 2.]
#  [5. 2. 5. 3. 2. 1. 4. 2.]
#  [4. 3. 3. 2. 5. 4. 2. 2.]
#  [4. 2. 2. 5. 2. 3. 3. 1.]
#  [1. 5. 1. 4. 3. 0. 1. 5.]
#  [3. 4. 4. 2. 3. 1. 5. 3.]
#  [5. 2. 2. 2. 1. 5. 3. 3.]]
#
# 	Brute Force
# 		Solution = 10010110 [01101001].
# 		Maxcut = 56.0.
# 		Time: 0.01724429099704139 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10010110 [01101001].
# 		Maxcut = 56.0.
# 		Optimizer Time: 19.376755952835083 seconds.
#
#
# Test Case 28:
# --------------------------------------------------------------------
#
# [[4. 4. 4. 3. 1. 2. 3. 5.]
#  [4. 2. 2. 5. 3. 3. 3. 4.]
#  [4. 2. 0. 0. 2. 5. 3. 4.]
#  [3. 5. 0. 0. 4. 4. 2. 1.]
#  [1. 3. 2. 4. 3. 5. 5. 2.]
#  [2. 3. 5. 4. 5. 5. 0. 4.]
#  [3. 3. 3. 2. 5. 0. 3. 5.]
#  [5. 4. 4. 1. 2. 4. 5. 4.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 60.0.
# 		Time: 0.03909540397580713 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11000110 [00111001].
# 		Maxcut = 60.0.
# 		Optimizer Time: 21.05573034286499 seconds.
#
#
# Test Case 29:
# ----------------------------------------------------------------------
#
# [[1. 5. 1. 5. 5. 1. 3. 5.]
#  [5. 3. 3. 1. 4. 5. 2. 0.]
#  [1. 3. 0. 1. 5. 1. 2. 3.]
#  [5. 1. 1. 3. 0. 5. 4. 1.]
#  [5. 4. 5. 0. 4. 1. 2. 3.]
#  [1. 5. 1. 5. 1. 1. 2. 1.]
#  [3. 2. 2. 4. 2. 2. 5. 3.]
#  [5. 0. 3. 1. 3. 1. 3. 5.]]
#
# 	Brute Force
# 		Solution = 10100110 [01011001].
# 		Maxcut = 55.0.
# 		Time: 0.01820068500819616 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10100110 [01011001].
# 		Maxcut = 55.0.
# 		Optimizer Time: 21.14890956878662 seconds.
#
#
# Test Case 30:
# ------------------------------------------------------------------------
#
# [[3. 5. 1. 1. 3. 2. 5. 3.]
#  [5. 1. 5. 2. 1. 2. 5. 4.]
#  [1. 5. 3. 5. 5. 3. 3. 3.]
#  [1. 2. 5. 3. 1. 1. 4. 3.]
#  [3. 1. 5. 1. 2. 2. 5. 3.]
#  [2. 2. 3. 1. 2. 2. 4. 5.]
#  [5. 5. 3. 4. 5. 4. 1. 3.]
#  [3. 4. 3. 3. 3. 5. 3. 3.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 62.0.
# 		Time: 0.018243024009279907 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01011100 [10100011].
# 		Maxcut = 62.0.
# 		Optimizer Time: 20.85200786590576 seconds.
#
#
# Test Case 31:
# --------------------------------------------------------------------------
#
# [[1. 3. 1. 0. 5. 5. 4. 4.]
#  [3. 1. 5. 2. 1. 3. 2. 2.]
#  [1. 5. 4. 1. 4. 4. 1. 3.]
#  [0. 2. 1. 3. 4. 5. 3. 3.]
#  [5. 1. 4. 4. 5. 4. 3. 4.]
#  [5. 3. 4. 5. 4. 3. 1. 2.]
#  [4. 2. 1. 3. 3. 1. 2. 1.]
#  [4. 2. 3. 3. 4. 2. 1. 2.]]
#
# 	Brute Force
# 		Solution = 10110000 [01001111].
# 		Maxcut = 55.0.
# 		Time: 0.020081733993720263 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10110000 [01001111].
# 		Maxcut = 55.0.
# 		Optimizer Time: 21.123879432678223 seconds.
#
#
# Test Case 32:
# ----------------------------------------------------------------------------
#
# [[5. 5. 3. 4. 3. 4. 5. 1.]
#  [5. 4. 3. 2. 1. 0. 0. 2.]
#  [3. 3. 0. 3. 5. 2. 2. 2.]
#  [4. 2. 3. 3. 1. 5. 5. 5.]
#  [3. 1. 5. 1. 0. 4. 3. 1.]
#  [4. 0. 2. 5. 4. 4. 1. 4.]
#  [5. 0. 2. 5. 3. 1. 3. 1.]
#  [1. 2. 2. 5. 1. 4. 1. 4.]]
#
# 	Brute Force
# 		Solution = 01100110 [10011001].
# 		Maxcut = 54.0.
# 		Time: 0.017471436003688723 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01100110 [10011001].
# 		Maxcut = 54.0.
# 		Optimizer Time: 21.077768564224243 seconds.
#
#
# Test Case 33:
# ------------------------------------------------------------------------------
#
# [[0. 3. 5. 5. 5. 4. 5. 4.]
#  [3. 1. 4. 1. 5. 4. 0. 2.]
#  [5. 4. 5. 1. 3. 1. 2. 3.]
#  [5. 1. 1. 0. 1. 5. 3. 1.]
#  [5. 5. 3. 1. 0. 3. 4. 4.]
#  [4. 4. 1. 5. 3. 1. 1. 5.]
#  [5. 0. 2. 3. 4. 1. 4. 5.]
#  [4. 2. 3. 1. 4. 5. 5. 3.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 59.0.
# 		Time: 0.02557055398938246 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11000110 [00111001].
# 		Maxcut = 59.0.
# 		Optimizer Time: 22.016201496124268 seconds.
#
#
# Test Case 34:
# --------------------------------------------------------------------------------
#
# [[5. 4. 3. 1. 5. 1. 3. 5.]
#  [4. 2. 1. 5. 5. 1. 4. 1.]
#  [3. 1. 4. 2. 1. 5. 1. 3.]
#  [1. 5. 2. 3. 1. 3. 4. 2.]
#  [5. 5. 1. 1. 5. 4. 3. 2.]
#  [1. 1. 5. 3. 4. 4. 3. 4.]
#  [3. 4. 1. 4. 3. 3. 2. 4.]
#  [5. 1. 3. 2. 2. 4. 4. 2.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 54.0.
# 		Time: 0.016899083013413474 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11000110 [00111001].
# 		Maxcut = 54.0.
# 		Optimizer Time: 22.58120894432068 seconds.
#
#
# Test Case 35:
# ----------------------------------------------------------------------------------
#
# [[4. 4. 3. 5. 5. 1. 4. 3.]
#  [4. 5. 5. 1. 2. 3. 1. 4.]
#  [3. 5. 2. 1. 3. 3. 2. 1.]
#  [5. 1. 1. 0. 1. 3. 4. 0.]
#  [5. 2. 3. 1. 4. 5. 5. 1.]
#  [1. 3. 3. 3. 5. 5. 5. 1.]
#  [4. 1. 2. 4. 5. 5. 4. 5.]
#  [3. 4. 1. 0. 1. 1. 5. 4.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 56.0.
# 		Time: 0.01752988001680933 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11000110 [00111001].
# 		Maxcut = 56.0.
# 		Optimizer Time: 22.414759397506714 seconds.
#
#
# Test Case 36:
# ------------------------------------------------------------------------------------
#
# [[1. 3. 1. 4. 4. 2. 1. 1.]
#  [3. 3. 1. 0. 5. 4. 2. 4.]
#  [1. 1. 4. 5. 4. 1. 3. 5.]
#  [4. 0. 5. 4. 4. 2. 5. 3.]
#  [4. 5. 4. 4. 0. 1. 2. 4.]
#  [2. 4. 1. 2. 1. 5. 3. 0.]
#  [1. 2. 3. 5. 2. 3. 1. 3.]
#  [1. 4. 5. 3. 4. 0. 3. 2.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 52.0.
# 		Time: 0.0159867110196501 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11100010 [00011101].
# 		Maxcut = 52.0.
# 		Optimizer Time: 22.592872619628906 seconds.
#
#
# Test Case 37:
# --------------------------------------------------------------------------------------
#
# [[0. 3. 1. 5. 5. 4. 3. 4.]
#  [3. 1. 2. 1. 3. 2. 3. 3.]
#  [1. 2. 5. 3. 5. 1. 2. 3.]
#  [5. 1. 3. 1. 3. 5. 5. 1.]
#  [5. 3. 5. 3. 1. 5. 4. 4.]
#  [4. 2. 1. 5. 5. 0. 3. 5.]
#  [3. 3. 2. 5. 4. 3. 2. 4.]
#  [4. 3. 3. 1. 4. 5. 4. 3.]]
#
# 	Brute Force
# 		Solution = 10100110 [01011001].
# 		Maxcut = 63.0.
# 		Time: 0.018466262001311406 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10100110 [01011001].
# 		Maxcut = 63.0.
# 		Optimizer Time: 21.543989181518555 seconds.
#
#
# Test Case 38:
# ----------------------------------------------------------------------------------------
#
# [[5. 1. 1. 2. 5. 3. 5. 2.]
#  [1. 4. 4. 3. 2. 1. 5. 1.]
#  [1. 4. 1. 5. 5. 5. 5. 2.]
#  [2. 3. 5. 1. 3. 1. 2. 1.]
#  [5. 2. 5. 3. 4. 4. 3. 2.]
#  [3. 1. 5. 1. 4. 2. 5. 1.]
#  [5. 5. 5. 2. 3. 5. 0. 5.]
#  [2. 1. 2. 1. 2. 1. 5. 3.]]
#
# 	Brute Force
# 		Solution = 00101010 [11010101].
# 		Maxcut = 55.0.
# 		Time: 0.03175187500892207 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00101010 [11010101].
# 		Maxcut = 55.0.
# 		Optimizer Time: 22.131632328033447 seconds.
#
#
# Test Case 39:
# ------------------------------------------------------------------------------------------
#
# [[1. 3. 2. 4. 3. 4. 2. 4.]
#  [3. 5. 2. 1. 4. 2. 1. 3.]
#  [2. 2. 0. 3. 5. 5. 1. 2.]
#  [4. 1. 3. 0. 3. 1. 3. 3.]
#  [3. 4. 5. 3. 1. 3. 1. 2.]
#  [4. 2. 5. 1. 3. 2. 5. 4.]
#  [2. 1. 1. 3. 1. 5. 2. 1.]
#  [4. 3. 2. 3. 2. 4. 1. 3.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 51.0.
# 		Time: 0.01839806800126098 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01011100 [10100011].
# 		Maxcut = 51.0.
# 		Optimizer Time: 21.61512517929077 seconds.
#
#
# Test Case 40:
# --------------------------------------------------------------------------------------------
#
# [[5. 4. 1. 5. 5. 4. 4. 3.]
#  [4. 3. 4. 5. 2. 3. 1. 2.]
#  [1. 4. 3. 4. 4. 4. 4. 4.]
#  [5. 5. 4. 4. 5. 4. 4. 3.]
#  [5. 2. 4. 5. 5. 1. 3. 4.]
#  [4. 3. 4. 4. 1. 1. 4. 1.]
#  [4. 1. 4. 4. 3. 4. 2. 5.]
#  [3. 2. 4. 3. 4. 1. 5. 3.]]
#
# 	Brute Force
# 		Solution = 01001110 [10110001].
# 		Maxcut = 63.0.
# 		Time: 0.024566532985772938 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01001110 [10110001].
# 		Maxcut = 63.0.
# 		Optimizer Time: 21.58351445198059 seconds.
#
#
# Test Case 41:
# ----------------------------------------------------------------------------------------------
#
# [[1. 4. 3. 1. 2. 3. 2. 3.]
#  [4. 5. 1. 1. 5. 4. 2. 2.]
#  [3. 1. 0. 1. 1. 4. 4. 3.]
#  [1. 1. 1. 3. 4. 4. 4. 2.]
#  [2. 5. 1. 4. 3. 4. 3. 2.]
#  [3. 4. 4. 4. 4. 2. 4. 3.]
#  [2. 2. 4. 4. 3. 4. 1. 2.]
#  [3. 2. 3. 2. 2. 3. 2. 2.]]
#
# 	Brute Force
# 		Solution = 10001110 [01110001].
# 		Maxcut = 50.0.
# 		Time: 0.020496309007285163 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10001110 [01110001].
# 		Maxcut = 50.0.
# 		Optimizer Time: 20.41926884651184 seconds.
#
#
# Test Case 42:
# ------------------------------------------------------------------------------------------------
#
# [[1. 4. 5. 1. 4. 1. 5. 3.]
#  [4. 0. 3. 1. 4. 2. 3. 4.]
#  [5. 3. 5. 4. 3. 2. 5. 2.]
#  [1. 1. 4. 3. 1. 5. 3. 1.]
#  [4. 4. 3. 1. 2. 3. 4. 5.]
#  [1. 2. 2. 5. 3. 1. 3. 1.]
#  [5. 3. 5. 3. 4. 3. 2. 3.]
#  [3. 4. 2. 1. 5. 1. 3. 0.]]
#
# 	Brute Force
# 		Solution = 01011010 [10100101].
# 		Maxcut = 55.0.
# 		Time: 0.023077391990227625 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01011010 [10100101].
# 		Maxcut = 55.0.
# 		Optimizer Time: 22.22165274620056 seconds.
#
#
# Test Case 43:
# --------------------------------------------------------------------------------------------------
#
# [[1. 3. 4. 1. 4. 4. 3. 5.]
#  [3. 2. 4. 2. 2. 1. 2. 2.]
#  [4. 4. 1. 3. 5. 1. 1. 2.]
#  [1. 2. 3. 4. 2. 2. 1. 1.]
#  [4. 2. 5. 2. 4. 3. 2. 0.]
#  [4. 1. 1. 2. 3. 4. 2. 4.]
#  [3. 2. 1. 1. 2. 2. 1. 4.]
#  [5. 2. 2. 1. 0. 4. 4. 3.]]
#
# 	Brute Force
# 		Solution = 10100110 [01011001].
# 		Maxcut = 46.0.
# 		Time: 0.029334611986996606 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10100110 [01011001].
# 		Maxcut = 46.0.
# 		Optimizer Time: 19.677355527877808 seconds.
#
#
# Test Case 44:
# ----------------------------------------------------------------------------------------------------
#
# [[3. 5. 2. 3. 5. 4. 1. 3.]
#  [5. 5. 5. 1. 4. 3. 3. 3.]
#  [2. 5. 2. 5. 1. 3. 3. 2.]
#  [3. 1. 5. 2. 5. 3. 5. 4.]
#  [5. 4. 1. 5. 5. 4. 1. 5.]
#  [4. 3. 3. 3. 4. 5. 5. 2.]
#  [1. 3. 3. 5. 1. 5. 1. 5.]
#  [3. 3. 2. 4. 5. 2. 5. 4.]]
#
# 	Brute Force
# 		Solution = 10101010 [01010101].
# 		Maxcut = 66.0.
# 		Time: 0.019337164994794875 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10101010 [01010101].
# 		Maxcut = 66.0.
# 		Optimizer Time: 21.163928270339966 seconds.
#
#
# Test Case 45:
# ------------------------------------------------------------------------------------------------------
#
# [[3. 3. 3. 5. 2. 1. 4. 1.]
#  [3. 5. 2. 5. 1. 2. 5. 2.]
#  [3. 2. 2. 3. 1. 4. 4. 5.]
#  [5. 5. 3. 3. 4. 2. 2. 1.]
#  [2. 1. 1. 4. 0. 3. 4. 2.]
#  [1. 2. 4. 2. 3. 5. 2. 4.]
#  [4. 5. 4. 2. 4. 2. 4. 4.]
#  [1. 2. 5. 1. 2. 4. 4. 4.]]
#
# 	Brute Force
# 		Solution = 11101000 [00010111].
# 		Maxcut = 54.0.
# 		Time: 0.02383203399949707 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11101000 [00010111].
# 		Maxcut = 54.0.
# 		Optimizer Time: 22.589709043502808 seconds.
#
#
# Test Case 46:
# --------------------------------------------------------------------------------------------------------
#
# [[3. 3. 4. 1. 3. 4. 1. 2.]
#  [3. 5. 5. 3. 2. 5. 1. 5.]
#  [4. 5. 5. 4. 3. 3. 2. 1.]
#  [1. 3. 4. 5. 5. 1. 5. 2.]
#  [3. 2. 3. 5. 1. 4. 4. 3.]
#  [4. 5. 3. 1. 4. 3. 3. 4.]
#  [1. 1. 2. 5. 4. 3. 1. 1.]
#  [2. 5. 1. 2. 3. 4. 1. 1.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 55.0.
# 		Time: 0.0170942610129714 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11001010 [00110101].
# 		Maxcut = 55.0.
# 		Optimizer Time: 21.160219192504883 seconds.
#
#
# Test Case 47:
# ----------------------------------------------------------------------------------------------------------
#
# [[3. 2. 3. 1. 3. 5. 1. 5.]
#  [2. 1. 4. 0. 1. 5. 5. 3.]
#  [3. 4. 4. 5. 2. 5. 4. 5.]
#  [1. 0. 5. 0. 0. 1. 1. 3.]
#  [3. 1. 2. 0. 5. 0. 1. 2.]
#  [5. 5. 5. 1. 0. 1. 1. 1.]
#  [1. 5. 4. 1. 1. 1. 2. 2.]
#  [5. 3. 5. 3. 2. 1. 2. 2.]]
#
# 	Brute Force
# 		Solution = 11100000 [00011111].
# 		Maxcut = 50.0.
# 		Time: 0.047194740996928886 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11100000 [00011111].
# 		Maxcut = 50.0.
# 		Optimizer Time: 21.367711305618286 seconds.
#
#
# Test Case 48:
# ------------------------------------------------------------------------------------------------------------
#
# [[0. 4. 1. 3. 2. 1. 5. 2.]
#  [4. 5. 3. 3. 1. 3. 1. 4.]
#  [1. 3. 1. 1. 2. 3. 1. 2.]
#  [3. 3. 1. 3. 2. 5. 3. 2.]
#  [2. 1. 2. 2. 4. 3. 3. 1.]
#  [1. 3. 3. 5. 3. 4. 5. 2.]
#  [5. 1. 1. 3. 3. 5. 3. 5.]
#  [2. 4. 2. 2. 1. 2. 5. 0.]]
#
# 	Brute Force
# 		Solution = 01110010 [10001101].
# 		Maxcut = 50.0.
# 		Time: 0.017068649001885206 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01110010 [10001101].
# 		Maxcut = 50.0.
# 		Optimizer Time: 22.493377685546875 seconds.
#
#
# Test Case 49:
# --------------------------------------------------------------------------------------------------------------
#
# [[3. 5. 4. 3. 2. 4. 1. 3.]
#  [5. 5. 4. 5. 3. 2. 5. 3.]
#  [4. 4. 4. 1. 5. 4. 2. 3.]
#  [3. 5. 1. 2. 3. 3. 3. 4.]
#  [2. 3. 5. 3. 1. 4. 3. 1.]
#  [4. 2. 4. 3. 4. 0. 3. 5.]
#  [1. 5. 2. 3. 3. 3. 2. 2.]
#  [3. 3. 3. 4. 1. 5. 2. 3.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 59.0.
# 		Time: 0.017037654004525393 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01110100 [10001011].
# 		Maxcut = 59.0.
# 		Optimizer Time: 19.731844902038574 seconds.
#
#
# Test Case 50:
# ----------------------------------------------------------------------------------------------------------------
#
# [[3. 4. 2. 2. 3. 1. 5. 3.]
#  [4. 2. 3. 2. 5. 2. 3. 4.]
#  [2. 3. 5. 0. 4. 5. 5. 1.]
#  [2. 2. 0. 3. 3. 4. 3. 2.]
#  [3. 5. 4. 3. 3. 2. 3. 3.]
#  [1. 2. 5. 4. 2. 0. 4. 5.]
#  [5. 3. 5. 3. 3. 4. 0. 2.]
#  [3. 4. 1. 2. 3. 5. 2. 2.]]
#
# 	Brute Force
# 		Solution = 01001110 [10110001].
# 		Maxcut = 56.0.
# 		Time: 0.018907424004282802 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01001110 [10110001].
# 		Maxcut = 56.0.
# 		Optimizer Time: 19.967716693878174 seconds.
#
#
# Test Case 51:
# ------------------------------------------------------------------------------------------------------------------
#
# [[2. 5. 1. 2. 5. 5. 3. 2.]
#  [5. 2. 5. 2. 5. 5. 3. 5.]
#  [1. 5. 1. 1. 2. 4. 2. 5.]
#  [2. 2. 1. 2. 3. 4. 5. 4.]
#  [5. 5. 2. 3. 0. 3. 2. 3.]
#  [5. 5. 4. 4. 3. 0. 4. 2.]
#  [3. 3. 2. 5. 2. 4. 2. 3.]
#  [2. 5. 5. 4. 3. 2. 3. 3.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 62.0.
# 		Time: 0.017205771000590175 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11110000 [00001111].
# 		Maxcut = 62.0.
# 		Optimizer Time: 19.239776134490967 seconds.
#
#
# Test Case 52:
# --------------------------------------------------------------------------------------------------------------------
#
# [[1. 0. 4. 4. 5. 1. 4. 3.]
#  [0. 5. 4. 2. 4. 3. 4. 4.]
#  [4. 4. 3. 4. 3. 4. 2. 2.]
#  [4. 2. 4. 0. 5. 5. 3. 5.]
#  [5. 4. 3. 5. 3. 4. 3. 3.]
#  [1. 3. 4. 5. 4. 2. 3. 1.]
#  [4. 4. 2. 3. 3. 3. 3. 1.]
#  [3. 4. 2. 5. 3. 1. 1. 2.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 61.0.
# 		Time: 0.017633305018534884 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11010100 [00101011].
# 		Maxcut = 61.0.
# 		Optimizer Time: 19.90131688117981 seconds.
#
#
# Test Case 53:
# ----------------------------------------------------------------------------------------------------------------------
#
# [[0. 4. 5. 4. 5. 4. 1. 0.]
#  [4. 3. 5. 3. 5. 2. 4. 4.]
#  [5. 5. 4. 4. 2. 5. 5. 2.]
#  [4. 3. 4. 4. 3. 1. 0. 5.]
#  [5. 5. 2. 3. 3. 2. 1. 2.]
#  [4. 2. 5. 1. 2. 5. 4. 2.]
#  [1. 4. 5. 0. 1. 4. 2. 4.]
#  [0. 4. 2. 5. 2. 2. 4. 5.]]
#
# 	Brute Force
# 		Solution = 01010110 [10101001].
# 		Maxcut = 58.0.
# 		Time: 0.029228965024231002 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01010110 [10101001].
# 		Maxcut = 58.0.
# 		Optimizer Time: 23.02333354949951 seconds.
#
#
# Test Case 54:
# ------------------------------------------------------------------------------------------------------------------------
#
# [[4. 3. 3. 1. 2. 4. 4. 3.]
#  [3. 4. 2. 1. 3. 1. 1. 2.]
#  [3. 2. 5. 3. 3. 4. 5. 3.]
#  [1. 1. 3. 5. 0. 3. 1. 5.]
#  [2. 3. 3. 0. 0. 1. 2. 2.]
#  [4. 1. 4. 3. 1. 1. 5. 4.]
#  [4. 1. 5. 1. 2. 5. 0. 1.]
#  [3. 2. 3. 5. 2. 4. 1. 4.]]
#
# 	Brute Force
# 		Solution = 10011100 [01100011].
# 		Maxcut = 47.0.
# 		Time: 0.017095271992729977 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10011100 [01100011].
# 		Maxcut = 47.0.
# 		Optimizer Time: 21.572453022003174 seconds.
#
#
# Test Case 55:
# --------------------------------------------------------------------------------------------------------------------------
#
# [[5. 2. 5. 1. 5. 0. 5. 3.]
#  [2. 2. 0. 3. 3. 2. 1. 2.]
#  [5. 0. 0. 2. 3. 1. 3. 4.]
#  [1. 3. 2. 4. 1. 2. 4. 1.]
#  [5. 3. 3. 1. 2. 2. 3. 3.]
#  [0. 2. 1. 2. 2. 5. 4. 1.]
#  [5. 1. 3. 4. 3. 4. 0. 3.]
#  [3. 2. 4. 1. 3. 1. 3. 2.]]
#
# 	Brute Force
# 		Solution = 01101010 [10010101].
# 		Maxcut = 48.0.
# 		Time: 0.01816532399971038 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01101010 [10010101].
# 		Maxcut = 48.0.
# 		Optimizer Time: 20.787177801132202 seconds.
#
#
# Test Case 56:
# ----------------------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 1. 1. 1. 1. 3. 5.]
#  [1. 3. 4. 2. 5. 4. 1. 3.]
#  [1. 4. 5. 5. 2. 4. 3. 3.]
#  [1. 2. 5. 5. 4. 1. 1. 4.]
#  [1. 5. 2. 4. 4. 3. 1. 5.]
#  [1. 4. 4. 1. 3. 4. 4. 3.]
#  [3. 1. 3. 1. 1. 4. 4. 4.]
#  [5. 3. 3. 4. 5. 3. 4. 4.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 52.0.
# 		Time: 0.03038945500156842 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10101100 [01010011].
# 		Maxcut = 52.0.
# 		Optimizer Time: 22.714886903762817 seconds.
#
#
# Test Case 57:
# ------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 2. 4. 1. 2. 1. 3. 4.]
#  [2. 2. 5. 3. 4. 2. 5. 3.]
#  [4. 5. 3. 4. 3. 4. 2. 5.]
#  [1. 3. 4. 2. 2. 4. 2. 4.]
#  [2. 4. 3. 2. 3. 3. 4. 5.]
#  [1. 2. 4. 4. 3. 4. 1. 2.]
#  [3. 5. 2. 2. 4. 1. 2. 3.]
#  [4. 3. 5. 4. 5. 2. 3. 4.]]
#
# 	Brute Force
# 		Solution = 11011000 [00100111].
# 		Maxcut = 56.0.
# 		Time: 0.022053861001040787 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11011000 [00100111].
# 		Maxcut = 56.0.
# 		Optimizer Time: 22.442992448806763 seconds.
#
#
# Test Case 58:
# --------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 2. 3. 2. 3. 3. 4. 2.]
#  [2. 2. 5. 1. 2. 3. 4. 2.]
#  [3. 5. 2. 0. 3. 2. 5. 5.]
#  [2. 1. 0. 2. 4. 5. 4. 1.]
#  [3. 2. 3. 4. 2. 2. 1. 1.]
#  [3. 3. 2. 5. 2. 5. 5. 5.]
#  [4. 4. 5. 4. 1. 5. 4. 4.]
#  [2. 2. 5. 1. 1. 5. 4. 3.]]
#
# 	Brute Force
# 		Solution = 00101110 [11010001].
# 		Maxcut = 55.0.
# 		Time: 0.01817910699173808 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00101110 [11010001].
# 		Maxcut = 55.0.
# 		Optimizer Time: 21.359619855880737 seconds.
#
#
# Test Case 59:
# ----------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 1. 4. 3. 5. 4. 2. 1.]
#  [1. 1. 0. 2. 5. 1. 1. 4.]
#  [4. 0. 4. 1. 2. 4. 1. 3.]
#  [3. 2. 1. 0. 2. 4. 3. 1.]
#  [5. 5. 2. 2. 2. 2. 5. 2.]
#  [4. 1. 4. 4. 2. 2. 3. 5.]
#  [2. 1. 1. 3. 5. 3. 1. 5.]
#  [1. 4. 3. 1. 2. 5. 5. 2.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 53.0.
# 		Time: 0.016789769986644387 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11000110 [00111001].
# 		Maxcut = 53.0.
# 		Optimizer Time: 21.15127182006836 seconds.
#
#
# Test Case 60:
# ------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 4. 4. 1. 5. 1. 1. 4.]
#  [4. 4. 5. 5. 3. 1. 4. 5.]
#  [4. 5. 1. 1. 4. 2. 1. 4.]
#  [1. 5. 1. 3. 2. 3. 1. 3.]
#  [5. 3. 4. 2. 1. 3. 5. 1.]
#  [1. 1. 2. 3. 3. 0. 5. 4.]
#  [1. 4. 1. 1. 5. 5. 0. 3.]
#  [4. 5. 4. 3. 1. 4. 3. 2.]]
#
# 	Brute Force
# 		Solution = 10110010 [01001101].
# 		Maxcut = 59.0.
# 		Time: 0.019151389016769826 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10110010 [01001101].
# 		Maxcut = 59.0.
# 		Optimizer Time: 20.653884172439575 seconds.
#
#
# Test Case 61:
# --------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 3. 3. 3. 4. 2. 1. 2.]
#  [3. 3. 2. 2. 4. 4. 4. 3.]
#  [3. 2. 4. 0. 3. 3. 5. 0.]
#  [3. 2. 0. 1. 2. 2. 3. 3.]
#  [4. 4. 3. 2. 0. 2. 0. 5.]
#  [2. 4. 3. 2. 2. 3. 2. 4.]
#  [1. 4. 5. 3. 0. 2. 1. 1.]
#  [2. 3. 0. 3. 5. 4. 1. 4.]]
#
# 	Brute Force
# 		Solution = 10001110 [01110001].
# 		Maxcut = 51.0.
# 		Time: 0.016698222985723987 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10001110 [01110001].
# 		Maxcut = 51.0.
# 		Optimizer Time: 14.607102155685425 seconds.
#
#
# Test Case 62:
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 3. 3. 2. 3. 5. 5.]
#  [5. 0. 1. 5. 4. 4. 1. 0.]
#  [3. 1. 2. 5. 5. 1. 3. 3.]
#  [3. 5. 5. 0. 3. 5. 5. 5.]
#  [2. 4. 5. 3. 5. 4. 1. 3.]
#  [3. 4. 1. 5. 4. 4. 2. 4.]
#  [5. 1. 3. 5. 1. 2. 0. 2.]
#  [5. 0. 3. 5. 3. 4. 2. 0.]]
#
# 	Brute Force
# 		Solution = 10011000 [01100111].
# 		Maxcut = 63.0.
# 		Time: 0.017571522999787703 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10011000 [01100111].
# 		Maxcut = 63.0.
# 		Optimizer Time: 15.390639066696167 seconds.
#
#
# Test Case 63:
# ------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 1. 2. 1. 3. 4. 1. 1.]
#  [1. 3. 5. 1. 4. 5. 1. 1.]
#  [2. 5. 0. 3. 3. 2. 3. 4.]
#  [1. 1. 3. 0. 2. 3. 4. 3.]
#  [3. 4. 3. 2. 0. 2. 3. 1.]
#  [4. 5. 2. 3. 2. 4. 3. 2.]
#  [1. 1. 3. 4. 3. 3. 1. 3.]
#  [1. 1. 4. 3. 1. 2. 3. 5.]]
#
# 	Brute Force
# 		Solution = 00111100 [11000011].
# 		Maxcut = 48.0.
# 		Time: 0.018316831992706284 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00111100 [11000011].
# 		Maxcut = 48.0.
# 		Optimizer Time: 15.893584966659546 seconds.
#
#
# Test Case 64:
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 0. 3. 5. 1. 1. 4. 1.]
#  [0. 1. 3. 3. 4. 5. 5. 5.]
#  [3. 3. 2. 2. 3. 2. 5. 4.]
#  [5. 3. 2. 0. 3. 1. 5. 5.]
#  [1. 4. 3. 3. 0. 4. 5. 2.]
#  [1. 5. 2. 1. 4. 1. 5. 5.]
#  [4. 5. 5. 5. 5. 5. 1. 5.]
#  [1. 5. 4. 5. 2. 5. 5. 4.]]
#
# 	Brute Force
# 		Solution = 00110110 [11001001].
# 		Maxcut = 63.0.
# 		Time: 0.017862100998172536 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00110110 [11001001].
# 		Maxcut = 63.0.
# 		Optimizer Time: 15.249484300613403 seconds.
#
#
# Test Case 65:
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 1. 3. 3. 3. 2. 3. 5.]
#  [1. 2. 2. 1. 3. 2. 5. 4.]
#  [3. 2. 1. 2. 2. 4. 2. 5.]
#  [3. 1. 2. 5. 4. 1. 2. 3.]
#  [3. 3. 2. 4. 2. 1. 1. 0.]
#  [2. 2. 4. 1. 1. 4. 2. 4.]
#  [3. 5. 2. 2. 1. 2. 3. 1.]
#  [5. 4. 5. 3. 0. 4. 1. 3.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 50.0.
# 		Time: 0.01640588601003401 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11110000 [00001111].
# 		Maxcut = 50.0.
# 		Optimizer Time: 16.11327075958252 seconds.
#
#
# Test Case 66:
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 3. 1. 3. 5. 2. 4.]
#  [1. 2. 4. 2. 4. 0. 1. 3.]
#  [3. 4. 4. 1. 5. 1. 3. 3.]
#  [1. 2. 1. 0. 2. 4. 2. 1.]
#  [3. 4. 5. 2. 2. 3. 1. 2.]
#  [5. 0. 1. 4. 3. 4. 3. 2.]
#  [2. 1. 3. 2. 1. 3. 1. 1.]
#  [4. 3. 3. 1. 2. 2. 1. 0.]]
#
# 	Brute Force
# 		Solution = 11100100 [00011011].
# 		Maxcut = 44.0.
# 		Time: 0.017542982008308172 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11100100 [00011011].
# 		Maxcut = 44.0.
# 		Optimizer Time: 15.624686241149902 seconds.
#
#
# Test Case 67:
# --------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 4. 1. 5. 5. 1. 1. 4.]
#  [4. 3. 2. 3. 2. 2. 4. 3.]
#  [1. 2. 2. 1. 5. 4. 1. 4.]
#  [5. 3. 1. 3. 3. 3. 3. 4.]
#  [5. 2. 5. 3. 5. 2. 2. 5.]
#  [1. 2. 4. 3. 2. 2. 1. 4.]
#  [1. 4. 1. 3. 2. 1. 0. 5.]
#  [4. 3. 4. 4. 5. 4. 5. 0.]]
#
# 	Brute Force
# 		Solution = 10100110 [01011001].
# 		Maxcut = 55.0.
# 		Time: 0.01642052599345334 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10100110 [01011001].
# 		Maxcut = 55.0.
# 		Optimizer Time: 15.319286346435547 seconds.
#
#
# Test Case 68:
# ----------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 1. 3. 4. 2. 4. 1. 0.]
#  [1. 5. 3. 1. 5. 5. 5. 3.]
#  [3. 3. 3. 1. 2. 4. 0. 3.]
#  [4. 1. 1. 5. 5. 4. 0. 2.]
#  [2. 5. 2. 5. 2. 2. 2. 2.]
#  [4. 5. 4. 4. 2. 1. 1. 4.]
#  [1. 5. 0. 0. 2. 1. 5. 4.]
#  [0. 3. 3. 2. 2. 4. 4. 5.]]
#
# 	Brute Force
# 		Solution = 00101110 [11010001].
# 		Maxcut = 51.0.
# 		Time: 0.017892909003421664 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00101110 [11010001].
# 		Maxcut = 51.0.
# 		Optimizer Time: 14.30842113494873 seconds.
#
#
# Test Case 69:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 2. 1. 3. 3. 2. 1. 1.]
#  [2. 5. 2. 3. 4. 2. 4. 0.]
#  [1. 2. 0. 4. 2. 3. 3. 2.]
#  [3. 3. 4. 2. 1. 2. 2. 4.]
#  [3. 4. 2. 1. 3. 5. 4. 0.]
#  [2. 2. 3. 2. 5. 1. 2. 4.]
#  [1. 4. 3. 2. 4. 2. 5. 2.]
#  [1. 0. 2. 4. 0. 4. 2. 5.]]
#
# 	Brute Force
# 		Solution = 10010110 [01101001].
# 		Maxcut = 46.0.
# 		Time: 0.016355277999537066 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10010110 [01101001].
# 		Maxcut = 46.0.
# 		Optimizer Time: 15.051105499267578 seconds.
#
#
# Test Case 70:
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 4. 3. 2. 5. 2. 4.]
#  [5. 3. 5. 3. 3. 4. 5. 3.]
#  [4. 5. 2. 1. 2. 5. 4. 5.]
#  [3. 3. 1. 3. 5. 2. 2. 5.]
#  [2. 3. 2. 5. 0. 4. 1. 2.]
#  [5. 4. 5. 2. 4. 5. 5. 5.]
#  [2. 5. 4. 2. 1. 5. 3. 4.]
#  [4. 3. 5. 5. 2. 5. 4. 3.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 65.0.
# 		Time: 0.017577004007762298 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01110100 [10001011].
# 		Maxcut = 65.0.
# 		Optimizer Time: 15.180404663085938 seconds.
#
#
# Test Case 71:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 1. 0. 1. 4. 2. 2.]
#  [1. 0. 4. 3. 3. 5. 3. 5.]
#  [1. 4. 1. 2. 1. 3. 2. 2.]
#  [0. 3. 2. 2. 5. 2. 1. 1.]
#  [1. 3. 1. 5. 5. 1. 5. 2.]
#  [4. 5. 3. 2. 1. 5. 4. 3.]
#  [2. 3. 2. 1. 5. 4. 1. 5.]
#  [2. 5. 2. 1. 2. 3. 5. 0.]]
#
# 	Brute Force
# 		Solution = 11010010 [00101101].
# 		Maxcut = 51.0.
# 		Time: 0.017275008984142914 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11010010 [00101101].
# 		Maxcut = 51.0.
# 		Optimizer Time: 15.244507074356079 seconds.
#
#
# Test Case 72:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 2. 4. 3. 2. 5. 2. 2.]
#  [2. 1. 2. 1. 4. 5. 3. 2.]
#  [4. 2. 5. 3. 1. 5. 2. 2.]
#  [3. 1. 3. 4. 3. 1. 4. 1.]
#  [2. 4. 1. 3. 0. 1. 5. 2.]
#  [5. 5. 5. 1. 1. 2. 3. 3.]
#  [2. 3. 2. 4. 5. 3. 3. 4.]
#  [2. 2. 2. 1. 2. 3. 4. 2.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 51.0.
# 		Time: 0.016916643013246357 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11100010 [00011101].
# 		Maxcut = 51.0.
# 		Optimizer Time: 15.295106410980225 seconds.
#
#
# Test Case 73:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 3. 4. 5. 5. 5. 0. 2.]
#  [3. 0. 1. 1. 2. 1. 3. 4.]
#  [4. 1. 2. 1. 1. 0. 3. 1.]
#  [5. 1. 1. 5. 5. 3. 2. 4.]
#  [5. 2. 1. 5. 0. 4. 5. 1.]
#  [5. 1. 0. 3. 4. 5. 4. 2.]
#  [0. 3. 3. 2. 5. 4. 0. 2.]
#  [2. 4. 1. 4. 1. 2. 2. 3.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 52.0.
# 		Time: 0.017408760002581403 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01110100 [10001011].
# 		Maxcut = 52.0.
# 		Optimizer Time: 15.23061466217041 seconds.
#
#
# Test Case 74:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 1. 5. 5. 4. 4. 3. 3.]
#  [1. 1. 4. 5. 4. 3. 3. 3.]
#  [5. 4. 2. 1. 3. 2. 2. 4.]
#  [5. 5. 1. 0. 1. 2. 1. 5.]
#  [4. 4. 3. 1. 3. 3. 1. 4.]
#  [4. 3. 2. 2. 3. 4. 4. 3.]
#  [3. 3. 2. 1. 1. 4. 4. 5.]
#  [3. 3. 4. 5. 4. 3. 5. 1.]]
#
# 	Brute Force
# 		Solution = 00111010 [11000101].
# 		Maxcut = 62.0.
# 		Time: 0.016391940996982157 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00111010 [11000101].
# 		Maxcut = 62.0.
# 		Optimizer Time: 15.657553911209106 seconds.
#
#
# Test Case 75:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 5. 1. 4. 1. 4. 1. 3.]
#  [5. 2. 4. 4. 4. 5. 1. 2.]
#  [1. 4. 3. 4. 5. 0. 3. 5.]
#  [4. 4. 4. 5. 3. 5. 2. 5.]
#  [1. 4. 5. 3. 1. 2. 3. 2.]
#  [4. 5. 0. 5. 2. 1. 1. 5.]
#  [1. 1. 3. 2. 3. 1. 0. 5.]
#  [3. 2. 5. 5. 2. 5. 5. 3.]]
#
# 	Brute Force
# 		Solution = 10100110 [01011001].
# 		Maxcut = 59.0.
# 		Time: 0.02205144500476308 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10100110 [01011001].
# 		Maxcut = 59.0.
# 		Optimizer Time: 15.34221887588501 seconds.
#
#
# Test Case 76:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 5. 4. 1. 0. 3. 5.]
#  [1. 1. 0. 1. 1. 2. 2. 4.]
#  [5. 0. 1. 4. 4. 4. 5. 2.]
#  [4. 1. 4. 4. 4. 2. 3. 3.]
#  [1. 1. 4. 4. 0. 4. 0. 2.]
#  [0. 2. 4. 2. 4. 4. 2. 5.]
#  [3. 2. 5. 3. 0. 2. 4. 0.]
#  [5. 4. 2. 3. 2. 5. 0. 5.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 50.0.
# 		Time: 0.01722323297872208 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11010100 [00101011].
# 		Maxcut = 50.0.
# 		Optimizer Time: 14.097269773483276 seconds.
#
#
# Test Case 77:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 4. 5. 4. 2. 2. 2. 3.]
#  [4. 5. 3. 1. 1. 5. 2. 3.]
#  [5. 3. 0. 1. 4. 3. 5. 1.]
#  [4. 1. 1. 4. 2. 2. 2. 4.]
#  [2. 1. 4. 2. 2. 3. 1. 5.]
#  [2. 5. 3. 2. 3. 3. 5. 3.]
#  [2. 2. 5. 2. 1. 5. 0. 0.]
#  [3. 3. 1. 4. 5. 3. 0. 1.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 52.0.
# 		Time: 0.016761359001975507 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11001010 [00110101].
# 		Maxcut = 52.0.
# 		Optimizer Time: 15.394121646881104 seconds.
#
#
# Test Case 78:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 4. 5. 1. 4. 1. 1. 2.]
#  [4. 2. 4. 4. 4. 5. 1. 5.]
#  [5. 4. 1. 4. 2. 5. 1. 5.]
#  [1. 4. 4. 5. 5. 3. 3. 1.]
#  [4. 4. 2. 5. 2. 1. 2. 2.]
#  [1. 5. 5. 3. 1. 3. 1. 5.]
#  [1. 1. 1. 3. 2. 1. 1. 2.]
#  [2. 5. 5. 1. 2. 5. 2. 5.]]
#
# 	Brute Force
# 		Solution = 01101010 [10010101].
# 		Maxcut = 56.0.
# 		Time: 0.01685751200420782 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01101010 [10010101].
# 		Maxcut = 56.0.
# 		Optimizer Time: 15.795809507369995 seconds.
#
#
# Test Case 79:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 4. 3. 4. 5. 5. 2. 2.]
#  [4. 2. 1. 5. 1. 1. 3. 4.]
#  [3. 1. 4. 5. 5. 1. 3. 2.]
#  [4. 5. 5. 4. 4. 2. 2. 2.]
#  [5. 1. 5. 4. 5. 2. 4. 4.]
#  [5. 1. 1. 2. 2. 5. 2. 4.]
#  [2. 3. 3. 2. 4. 2. 4. 1.]
#  [2. 4. 2. 2. 4. 4. 1. 2.]]
#
# 	Brute Force
# 		Solution = 01101100 [10010011].
# 		Maxcut = 59.0.
# 		Time: 0.01675500100827776 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01101100 [10010011].
# 		Maxcut = 59.0.
# 		Optimizer Time: 15.75291895866394 seconds.
#
#
# Test Case 80:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 3. 3. 1. 1. 5. 3. 5.]
#  [3. 4. 2. 2. 1. 1. 1. 5.]
#  [3. 2. 1. 2. 4. 3. 3. 2.]
#  [1. 2. 2. 3. 2. 4. 5. 2.]
#  [1. 1. 4. 2. 0. 2. 2. 4.]
#  [5. 1. 3. 4. 2. 4. 1. 1.]
#  [3. 1. 3. 5. 2. 1. 3. 2.]
#  [5. 5. 2. 2. 4. 1. 2. 5.]]
#
# 	Brute Force
# 		Solution = 11011000 [00100111].
# 		Maxcut = 50.0.
# 		Time: 0.019046566012548283 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11011000 [00100111].
# 		Maxcut = 50.0.
# 		Optimizer Time: 16.208807229995728 seconds.
#
#
# Test Case 81:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 2. 3. 1. 3. 4. 1. 5.]
#  [2. 5. 5. 3. 5. 1. 2. 0.]
#  [3. 5. 5. 1. 5. 4. 3. 3.]
#  [1. 3. 1. 0. 2. 2. 2. 3.]
#  [3. 5. 5. 2. 3. 5. 5. 5.]
#  [4. 1. 4. 2. 5. 1. 3. 5.]
#  [1. 2. 3. 2. 5. 3. 4. 2.]
#  [5. 0. 3. 3. 5. 5. 2. 4.]]
#
# 	Brute Force
# 		Solution = 10111000 [01000111].
# 		Maxcut = 57.0.
# 		Time: 0.018103812995832413 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10111000 [01000111].
# 		Maxcut = 57.0.
# 		Optimizer Time: 15.388145923614502 seconds.
#
#
# Test Case 82:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 4. 5. 3. 4. 3. 4.]
#  [1. 0. 3. 2. 1. 5. 1. 1.]
#  [4. 3. 0. 1. 5. 5. 3. 5.]
#  [5. 2. 1. 1. 1. 3. 1. 3.]
#  [3. 1. 5. 1. 3. 2. 3. 1.]
#  [4. 5. 5. 3. 2. 5. 4. 5.]
#  [3. 1. 3. 1. 3. 4. 4. 5.]
#  [4. 1. 5. 3. 1. 5. 5. 1.]]
#
# 	Brute Force
# 		Solution = 00110110 [11001001].
# 		Maxcut = 56.0.
# 		Time: 0.02121077201445587 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00110110 [11001001].
# 		Maxcut = 56.0.
# 		Optimizer Time: 15.125690937042236 seconds.
#
#
# Test Case 83:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 2. 1. 2. 1. 5. 1. 2.]
#  [2. 3. 4. 3. 2. 2. 5. 4.]
#  [1. 4. 1. 0. 4. 3. 4. 1.]
#  [2. 3. 0. 1. 1. 0. 4. 3.]
#  [1. 2. 4. 1. 4. 2. 3. 1.]
#  [5. 2. 3. 0. 2. 1. 3. 5.]
#  [1. 5. 4. 4. 3. 3. 4. 5.]
#  [2. 4. 1. 3. 1. 5. 5. 3.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 49.0.
# 		Time: 0.016626642987830564 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01011100 [10100011].
# 		Maxcut = 49.0.
# 		Optimizer Time: 15.5786771774292 seconds.
#
#
# Test Case 84:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 5. 4. 2. 3. 3. 4. 1.]
#  [5. 2. 5. 2. 4. 4. 1. 1.]
#  [4. 5. 5. 3. 5. 4. 5. 2.]
#  [2. 2. 3. 0. 5. 1. 3. 4.]
#  [3. 4. 5. 5. 4. 1. 3. 5.]
#  [3. 4. 4. 1. 1. 0. 3. 2.]
#  [4. 1. 5. 3. 3. 3. 4. 1.]
#  [1. 1. 2. 4. 5. 2. 1. 2.]]
#
# 	Brute Force
# 		Solution = 10011100 [01100011].
# 		Maxcut = 56.0.
# 		Time: 0.01761092897504568 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10011100 [01100011].
# 		Maxcut = 56.0.
# 		Optimizer Time: 15.584876537322998 seconds.
#
#
# Test Case 85:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 1. 3. 0. 2. 1. 2.]
#  [1. 0. 4. 4. 1. 1. 2. 2.]
#  [1. 4. 2. 3. 3. 4. 5. 2.]
#  [3. 4. 3. 1. 3. 3. 3. 5.]
#  [0. 1. 3. 3. 5. 0. 3. 2.]
#  [2. 1. 4. 3. 0. 4. 2. 1.]
#  [1. 2. 5. 3. 3. 2. 1. 4.]
#  [2. 2. 2. 5. 2. 1. 4. 4.]]
#
# 	Brute Force
# 		Solution = 00110010 [11001101].
# 		Maxcut = 44.0.
# 		Time: 0.017053493997082114 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 00110010 [11001101].
# 		Maxcut = 44.0.
# 		Optimizer Time: 15.755630731582642 seconds.
#
#
# Test Case 86:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 2. 5. 5. 1. 3. 2.]
#  [5. 0. 1. 3. 1. 2. 2. 3.]
#  [2. 1. 2. 1. 2. 0. 5. 1.]
#  [5. 3. 1. 5. 2. 3. 2. 3.]
#  [5. 1. 2. 2. 3. 3. 3. 5.]
#  [1. 2. 0. 3. 3. 5. 2. 3.]
#  [3. 2. 5. 2. 3. 2. 1. 2.]
#  [2. 3. 1. 3. 5. 3. 2. 0.]]
#
# 	Brute Force
# 		Solution = 01011010 [10100101].
# 		Maxcut = 50.0.
# 		Time: 0.017683776008198038 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01011010 [10100101].
# 		Maxcut = 50.0.
# 		Optimizer Time: 15.449618816375732 seconds.
#
#
# Test Case 87:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 5. 4. 4. 1. 2. 1. 5.]
#  [5. 1. 2. 3. 5. 3. 3. 2.]
#  [4. 2. 1. 1. 0. 2. 5. 4.]
#  [4. 3. 1. 1. 1. 3. 4. 3.]
#  [1. 5. 0. 1. 5. 5. 1. 1.]
#  [2. 3. 2. 3. 5. 4. 1. 4.]
#  [1. 3. 5. 4. 1. 1. 5. 5.]
#  [5. 2. 4. 3. 1. 4. 5. 0.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 55.0.
# 		Time: 0.016424167988589033 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11000110 [00111001].
# 		Maxcut = 55.0.
# 		Optimizer Time: 16.032254695892334 seconds.
#
#
# Test Case 88:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 5. 4. 5. 2. 2. 1. 4.]
#  [5. 2. 4. 4. 5. 4. 4. 2.]
#  [4. 4. 1. 4. 2. 4. 1. 4.]
#  [5. 4. 4. 0. 3. 5. 3. 3.]
#  [2. 5. 2. 3. 3. 3. 1. 1.]
#  [2. 4. 4. 5. 3. 1. 3. 5.]
#  [1. 4. 1. 3. 1. 3. 0. 1.]
#  [4. 2. 4. 3. 1. 5. 1. 4.]]
#
# 	Brute Force
# 		Solution = 10101110 [01010001].
# 		Maxcut = 57.0.
# 		Time: 0.01740779000101611 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10101110 [01010001].
# 		Maxcut = 57.0.
# 		Optimizer Time: 15.395603895187378 seconds.
#
#
# Test Case 89:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 5. 5. 4. 1. 5. 5. 0.]
#  [5. 1. 2. 0. 5. 5. 5. 2.]
#  [5. 2. 5. 4. 4. 2. 4. 2.]
#  [4. 0. 4. 2. 1. 1. 3. 3.]
#  [1. 5. 4. 1. 1. 1. 2. 3.]
#  [5. 5. 2. 1. 1. 3. 2. 2.]
#  [5. 5. 4. 3. 2. 2. 3. 1.]
#  [0. 2. 2. 3. 3. 2. 1. 3.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 53.0.
# 		Time: 0.016704364999895915 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01110100 [10001011].
# 		Maxcut = 53.0.
# 		Optimizer Time: 15.880300760269165 seconds.
#
#
# Test Case 90:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 4. 3. 2. 1. 1. 4. 3.]
#  [4. 5. 5. 5. 4. 4. 4. 4.]
#  [3. 5. 3. 2. 1. 4. 5. 5.]
#  [2. 5. 2. 0. 2. 4. 5. 1.]
#  [1. 4. 1. 2. 5. 3. 1. 1.]
#  [1. 4. 4. 4. 3. 1. 4. 1.]
#  [4. 4. 5. 5. 1. 4. 5. 3.]
#  [3. 4. 5. 1. 1. 1. 3. 4.]]
#
# 	Brute Force
# 		Solution = 10111000 [01000111].
# 		Maxcut = 55.0.
# 		Time: 0.01742217398714274 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10111000 [01000111].
# 		Maxcut = 55.0.
# 		Optimizer Time: 16.510101556777954 seconds.
#
#
# Test Case 91:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 3. 5. 2. 1. 4. 1. 2.]
#  [3. 3. 2. 1. 0. 3. 5. 5.]
#  [5. 2. 5. 2. 2. 5. 1. 2.]
#  [2. 1. 2. 0. 3. 3. 5. 3.]
#  [1. 0. 2. 3. 0. 3. 5. 1.]
#  [4. 3. 5. 3. 3. 1. 1. 1.]
#  [1. 5. 1. 5. 5. 1. 5. 2.]
#  [2. 5. 2. 3. 1. 1. 2. 2.]]
#
# 	Brute Force
# 		Solution = 01111000 [10000111].
# 		Maxcut = 52.0.
# 		Time: 0.018860579992178828 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01111000 [10000111].
# 		Maxcut = 52.0.
# 		Optimizer Time: 15.69736123085022 seconds.
#
#
# Test Case 92:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 3. 2. 3. 1. 4. 4. 5.]
#  [3. 0. 1. 2. 1. 5. 1. 5.]
#  [2. 1. 2. 1. 2. 2. 3. 1.]
#  [3. 2. 1. 3. 2. 4. 3. 4.]
#  [1. 1. 2. 2. 2. 4. 5. 3.]
#  [4. 5. 2. 4. 4. 0. 4. 3.]
#  [4. 1. 3. 3. 5. 4. 3. 4.]
#  [5. 5. 1. 4. 3. 3. 4. 4.]]
#
# 	Brute Force
# 		Solution = 11011000 [00100111].
# 		Maxcut = 53.0.
# 		Time: 0.016718794009648263 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11011000 [00100111].
# 		Maxcut = 53.0.
# 		Optimizer Time: 15.40437912940979 seconds.
#
#
# Test Case 93:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 4. 3. 4. 3. 5. 1. 3.]
#  [4. 4. 1. 2. 5. 5. 4. 4.]
#  [3. 1. 5. 1. 3. 3. 3. 3.]
#  [4. 2. 1. 4. 3. 5. 5. 1.]
#  [3. 5. 3. 3. 3. 3. 2. 4.]
#  [5. 5. 3. 5. 3. 0. 4. 1.]
#  [1. 4. 3. 5. 2. 4. 5. 1.]
#  [3. 4. 3. 1. 4. 1. 1. 1.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 56.0.
# 		Time: 0.018155958008719608 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11110000 [00001111].
# 		Maxcut = 56.0.
# 		Optimizer Time: 16.267141342163086 seconds.
#
#
# Test Case 94:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 3. 3. 2. 2. 3. 1.]
#  [2. 4. 1. 1. 3. 1. 2. 3.]
#  [3. 1. 5. 1. 4. 2. 1. 5.]
#  [3. 1. 1. 3. 1. 1. 2. 5.]
#  [2. 3. 4. 1. 1. 2. 3. 3.]
#  [2. 1. 2. 1. 2. 2. 5. 5.]
#  [3. 2. 1. 2. 3. 5. 1. 3.]
#  [1. 3. 5. 5. 3. 5. 3. 0.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 48.0.
# 		Time: 0.018183205014793202 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01110100 [10001011].
# 		Maxcut = 48.0.
# 		Optimizer Time: 15.718657493591309 seconds.
#
#
# Test Case 95:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 2. 1. 3. 1. 3. 5.]
#  [1. 4. 2. 3. 1. 0. 4. 1.]
#  [2. 2. 0. 1. 1. 5. 4. 1.]
#  [1. 3. 1. 0. 2. 1. 1. 3.]
#  [3. 1. 1. 2. 3. 4. 5. 5.]
#  [1. 0. 5. 1. 4. 3. 5. 5.]
#  [3. 4. 4. 1. 5. 5. 4. 3.]
#  [5. 1. 1. 3. 5. 5. 3. 4.]]
#
# 	Brute Force
# 		Solution = 11001100 [00110011].
# 		Maxcut = 50.0.
# 		Time: 0.017525489995023236 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11001100 [00110011].
# 		Maxcut = 50.0.
# 		Optimizer Time: 16.199334621429443 seconds.
#
#
# Test Case 96:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 3. 4. 4. 5. 5. 5. 4.]
#  [3. 3. 3. 4. 3. 2. 5. 4.]
#  [4. 3. 4. 5. 1. 5. 5. 5.]
#  [4. 4. 5. 4. 4. 4. 4. 0.]
#  [5. 3. 1. 4. 4. 2. 2. 5.]
#  [5. 2. 5. 4. 2. 0. 3. 1.]
#  [5. 5. 5. 4. 2. 3. 2. 4.]
#  [4. 4. 5. 0. 5. 1. 4. 4.]]
#
# 	Brute Force
# 		Solution = 11101000 [00010111].
# 		Maxcut = 66.0.
# 		Time: 0.01759185001719743 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11101000 [00010111].
# 		Maxcut = 66.0.
# 		Optimizer Time: 15.299378633499146 seconds.
#
#
# Test Case 97:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 0. 5. 2. 2. 4. 5.]
#  [2. 4. 1. 4. 3. 5. 3. 2.]
#  [0. 1. 4. 2. 3. 2. 4. 2.]
#  [5. 4. 2. 0. 3. 5. 5. 3.]
#  [2. 3. 3. 3. 4. 2. 3. 1.]
#  [2. 5. 2. 5. 2. 4. 3. 1.]
#  [4. 3. 4. 5. 3. 3. 4. 2.]
#  [5. 2. 2. 3. 1. 1. 2. 1.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 53.0.
# 		Time: 0.016634761996101588 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 11110000 [00001111].
# 		Maxcut = 53.0.
# 		Optimizer Time: 14.954521417617798 seconds.
#
#
# Test Case 98:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 5. 2. 3. 3. 2. 4. 3.]
#  [5. 2. 2. 1. 2. 4. 5. 5.]
#  [2. 2. 5. 2. 3. 4. 5. 1.]
#  [3. 1. 2. 2. 1. 5. 2. 2.]
#  [3. 2. 3. 1. 5. 4. 3. 3.]
#  [2. 4. 4. 5. 4. 0. 5. 5.]
#  [4. 5. 5. 2. 3. 5. 3. 2.]
#  [3. 5. 1. 2. 3. 5. 2. 4.]]
#
# 	Brute Force
# 		Solution = 01011010 [10100101].
# 		Maxcut = 57.0.
# 		Time: 0.017100318014854565 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 01011010 [10100101].
# 		Maxcut = 57.0.
# 		Optimizer Time: 15.468314170837402 seconds.
#
#
# Test Case 99:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 2. 2. 0. 1. 0. 3. 4.]
#  [2. 0. 2. 2. 5. 1. 5. 3.]
#  [2. 2. 5. 5. 3. 1. 4. 2.]
#  [0. 2. 5. 1. 1. 4. 3. 5.]
#  [1. 5. 3. 1. 5. 4. 4. 1.]
#  [0. 1. 1. 4. 4. 1. 3. 3.]
#  [3. 5. 4. 3. 4. 3. 1. 3.]
#  [4. 3. 2. 5. 1. 3. 3. 5.]]
#
# 	Brute Force
# 		Solution = 10011010 [01100101].
# 		Maxcut = 52.0.
# 		Time: 0.021916008001426235 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 10011010 [01100101].
# 		Maxcut = 52.0.
# 		Optimizer Time: 15.630765914916992 seconds.

# %%
print(f'Success: {success} / {num_tests} = {(success/num_tests) * 100} %')
print(f'Fail: {failure} / {num_tests} = {(failure/num_tests) * 100} %')
# Out:
# Success: 100 / 100 = 100.0 %
# Fail: 0 / 100 = 0.0 %
