# %% [markdown]
# ## Random Graphs
#
# ### Helper Functions
#
# Randomly generate an adjancency matrix...

# %%
import timeit
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations, groupby

# TODO: Size of NxN Matrix
n = 4

# Moved to global scopee to allow for timing
bf_bit_string, bf_cost = None, None

def random_row(row_num: int):
    row = list(np.random.choice((0, 1, 2, 3, 4, 5),size=n))
    
    # No self-references
    row[row_num] = 0 
    
    # Make sure there's no isolated nodes
    if sum(row) == 0:
        row = random_row(row_num)
    return row

def random_matrix():
    rows = []
    for i in range(0, n):
        rows.append(random_row(i))
    numpy_matrix = np.matrix(rows)
    
    return numpy_matrix

def random_graph():
    np_matrix = random_matrix()
    g = nx.convert_matrix.from_numpy_matrix(
        np_matrix, 
        parallel_edges=False, 
        create_using=nx.Graph
    )
    
    # nx.draw(g, node_color='lightblue', 
    #     with_labels=True, 
    #     node_size=500)
    
    return g, np_matrix

# %% [markdown]
# ### Brute Force

# %%
def brute_force(graph, w):
    global bf_bit_string
    global bf_cost
    
    bf_bit_string = None
    bf_cost = None
    
    best_cost_brute = 0
    for b in range(2**n):
        x = [int(t) for t in reversed(list(bin(b)[2:].zfill(n)))]
        cost = 0
        for i in range(n):
            for j in range(n):
                cost = cost + w[i,j]*x[i]*(1-x[j])
        if best_cost_brute < cost:
            best_cost_brute = cost
            xbest_brute = x
    bf_bit_string = xbest_brute
    bf_cost = best_cost_brute
    return xbest_brute, best_cost_brute

# %% [markdown]
# ### Quantum Apporximation Optimization Algorithm

# %%
import networkx as nx
import numpy as np
import plotly.graph_objects as go
import matplotlib as mpl
import pandas as pd
from IPython.display import clear_output
from plotly.subplots import make_subplots
from matplotlib import pyplot as plt
from qiskit import Aer
from qiskit import QuantumCircuit
from qiskit.visualization import plot_state_city
from qiskit.algorithms.optimizers import COBYLA, SLSQP, ADAM
from time import time
from copy import copy
from typing import List
from qc_grader.graph_util import display_maxcut_widget, QAOA_widget, graphs
from qiskit.circuit import Parameter, ParameterVector
from qiskit_optimization import QuadraticProgram
from qiskit.algorithms import QAOA
from qiskit_optimization.algorithms import MinimumEigenOptimizer

def maxcut_cost_fn(graph: nx.Graph, bitstring: List[int]) -> float:
    """
    Computes the maxcut cost function value for a given graph and cut represented by some bitstring
    Args:
        graph: The graph to compute cut values for
        bitstring: A list of integer values '0' or '1' specifying a cut of the graph
    Returns:
        The value of the cut
    """
    #Get the weight matrix of the graph
    weight_matrix = nx.adjacency_matrix(graph).toarray()
    size = weight_matrix.shape[0]
    value = 0.
    for i in range(size):
        for j in range(size):
            value = value + weight_matrix[i][j] * bitstring[i] * (1-bitstring[j])

    return value

def quadratic_program_from_graph(graph: nx.Graph) -> QuadraticProgram:
    """Constructs a quadratic program from a given graph for a MaxCut problem instance.
    Args:
        graph: Underlying graph of the problem.
    Returns:
        QuadraticProgram
    """
    #Get weight matrix of graph
    weight_matrix = nx.adjacency_matrix(graph)
    shape = weight_matrix.shape
    size = shape[0]
    
    #Build qubo matrix Q from weight matrix W
    qubo_matrix = np.zeros((size, size))
    qubo_vector = np.zeros(size)
    for i in range(size):
        for j in range(size):
            qubo_matrix[i, j] -= weight_matrix[i, j]
    for i in range(size):
        for j in range(size):
            qubo_vector[i] += weight_matrix[i,j]

    quadratic_program = QuadraticProgram('MaxCut as QUBO')
    for i in range(size):
        quadratic_program.binary_var(name = f'x_{i}')

    quadratic_program.maximize(quadratic = qubo_matrix, linear = qubo_vector)
    
    return quadratic_program

def qaoa_circuit(qubo: QuadraticProgram, p: int = 1, params: dict = []) -> QuantumCircuit:
    """
    Given a QUBO instance and the number of layers p, constructs the corresponding parameterized QAOA circuit with p layers.
    Args:
        qubo: The quadratic program instance
        p: The number of layers in the QAOA circuit
    Returns:
        The parameterized QAOA circuit
    """
    size = len(qubo.variables)
    qubo_matrix = qubo.objective.quadratic.to_array(symmetric=True)
    qubo_linearity = qubo.objective.linear.to_array()

    #Prepare the quantum and classical registers
    qaoa_circuit = QuantumCircuit(size,size)
    #Apply the initial layer of Hadamard gates to all qubits
    qaoa_circuit.h(range(size))

    #Create the parameters to be used in the circuit
    if not params:
        gammas = ParameterVector('gamma', p)
        betas = ParameterVector('beta', p)
    else:
        gammas = [params[1]]
        betas = [params[0]]

    #Outer loop to create each layer
    for i in range(p):

        #Apply R_Z rotational gates from cost layer
        for qubit in range(size):
            sum =0
            for col in range(size):
                sum += qubo_matrix[qubit][col]
            theta = (qubo_linearity[qubit] + sum) * gammas[i]
            qaoa_circuit.rz(theta, qubit)

        #Apply R_ZZ rotational gates for entangled qubit rotations from cost layer
        for j in range(size):
            for k in range(size):
                if j != k:
                    theta = qubo_matrix[j][k] * gammas[i] / 2
                    qaoa_circuit.rzz(theta, j, k)

        # Apply single qubit X - rotations with angle 2*beta_i to all qubits
        for qubit in range(size):
            qaoa_circuit.rx(2 * betas[i], qubit)
    return qaoa_circuit

def plot_qaoa_energy_landscape(graph: nx.Graph, cvar: float = None, plot: bool = True):
    num_shots = 1000
    seed = 42
    simulator = Aer.get_backend('qasm_simulator')
    simulator.set_options(seed_simulator = 42)

    #Generate circuit
    circuit = qaoa_circuit(qubo = quadratic_program_from_graph(graph), p=1)
    circuit.measure(range(graph.number_of_nodes()),range(graph.number_of_nodes()))

    #Create dictionary with precomputed cut values for all bitstrings 
    cut_values = {}
    size = graph.number_of_nodes()
    for i in range(2**size):
        bitstr = '{:b}'.format(i).rjust(size, '0')[::-1]
        x = [int(bit) for bit in bitstr]
        cut_values[bitstr] = maxcut_cost_fn(graph, x)

    #Perform grid search over all parameters
    data_points = []
    max_energy = None
    for beta in np.linspace(0,np.pi, 50):
        for gamma in np.linspace(0, 4*np.pi, 50):
            bound_circuit = circuit.assign_parameters([beta, gamma])
            result = simulator.run(bound_circuit, shots = num_shots).result()
            statevector = result.get_counts(bound_circuit)
            energy = 0
            measured_cuts = []
            for bitstring, count in statevector.items():
                measured_cuts =  measured_cuts + [cut_values[bitstring]]*count

            if cvar is None:
                # Calculate the mean of all cut values
                energy = sum(measured_cuts)/num_shots
            else:
                alpha_n = cvar*num_shots
                measured_cuts.sort(reverse=True)
                energy = sum(measured_cuts[:int(alpha_n)])/alpha_n

            #Update optimal parameters
            if max_energy is None or energy > max_energy:
                max_energy = energy
                optimum = {'beta': beta, 'gamma': gamma, 'energy': energy}

            #Update data
            data_points.append({'beta': beta, 'gamma': gamma, 'energy': energy})

    if plot:
        #Create and display surface plot from data_points
        df = pd.DataFrame(data_points)
        df = df.pivot(index='beta', columns='gamma', values='energy')
        matrix = df.to_numpy()
        beta_values = df.index.tolist()
        gamma_values = df.columns.tolist()

        surface_plot = go.Surface(
            x=gamma_values, 
            y=beta_values,
            z=matrix,
            coloraxis = 'coloraxis'
        )
        fig = go.Figure(data = surface_plot)
        fig.show()

    #Return optimum
    return optimum

def qaoa(nx_g):
    """
    Outline of how to use the QAOA class
        problem = QuadraticProgram()
        # specify problem here
        # specify minimum eigen solver to be used, e.g., QAOA
        qaoa = QAOA(...)
        optimizer = MinimumEigenOptimizer(qaoa)
        result = optimizer.solve(problem)
    
    """
    backend = Aer.get_backend('statevector_simulator')
    qaoa = QAOA(optimizer = ADAM(), quantum_instance = backend, reps=1, initial_point = [0.1,0.1])
    eigen_optimizer = MinimumEigenOptimizer(min_eigen_solver = qaoa)
    quadratic_program = quadratic_program_from_graph(nx_g)
    result = eigen_optimizer.solve(quadratic_program)
    
    # print results
    bit_string = map(int, result.x)
    return bit_string, result.fval, result.min_eigen_solver_result.optimizer_time

# %% [markdown]
# ### Variatonal Quantum EignSolver

# %%
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram
from qiskit.circuit.library import TwoLocal
from qiskit_optimization.applications import Maxcut, Tsp
from qiskit.algorithms import VQE, NumPyMinimumEigensolver
from qiskit.algorithms.optimizers import SPSA, COBYLA
from qiskit.utils import algorithm_globals, QuantumInstance
from qiskit_optimization.algorithms import MinimumEigenOptimizer

def vqe(w):
    
    # Define our Qiskit Maxcut Instance
    max_cut = Maxcut(w)
    
    # Now Accounting for weights
    qp = quadratic_program_from_graph(graph)

    # Translate to Ising Hamiltonian
    qubitOp, offset = qp.to_ising()

    # Setup our simulator
    algorithm_globals.random_seed = 123
    seed = 10598
    backend = Aer.get_backend('aer_simulator_statevector')
    quantum_instance = QuantumInstance(backend, seed_simulator=seed, seed_transpiler=seed)

    # Construct VQE
    spsa = SPSA(maxiter=300)
    cobyla = COBYLA(maxiter=300)
    ry = TwoLocal(qubitOp.num_qubits, 'ry', 'cz', reps=5, entanglement='linear')
    vqe = VQE(ry, optimizer=spsa, quantum_instance=quantum_instance)

    # Run VQE
    result = vqe.compute_minimum_eigenvalue(qubitOp)
    # print results
    bit_string = list(max_cut.sample_most_likely(result.eigenstate))
    bit_string = map(int, bit_string)
    # print('energy:', result.eigenvalue.real)
    # print('time:', result.optimizer_time)
    # print('max-cut objective:', result.eigenvalue.real + offset)
    # print('solution:', bit_string)
    # print('solution objective:', qp.objective.evaluate(bit_string))
    
    return bit_string, (result.eigenvalue.real + offset), result.optimizer_time

# %% [markdown]
# ## Tests

# %%
# Generate 1,000 graphs
qaoa_success = 0
vqe_success = 0
qaoa_failure = 0
vqe_failure = 0

# TODO: Change the number of tests, ad hoc
num_tests: int = 50

# Initialize list from 0 - num_tests for x axis of graph
x_axis = list(range(0, num_tests))

# List of execution times to graph
qaoa_execution_times = []
vqe_execution_times = []
numpy_execution_times = []
bf_execution_times = []

for graph_id in range(num_tests):
    global bf_bit_string
    global bf_cost
    
    # Generate Random Graph
    graph, matrix = random_graph()
    
    # Computing the weight matrix from the random graph
    w = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            temp = graph.get_edge_data(i,j,default=0)
            if temp != 0:
                w[i,j] = temp['weight']
    
    print(f'\nTest Case {graph_id}: ')
    print('------------' + '-' * (len(str(graph_id)) * 2))
    print()
    print(w)
    
    # Brute Force Approach
    #
    # Time brute force algorithm
    bf_time: float = timeit.timeit(lambda: brute_force(graph, w), number=1)
    # Add execution time to list for output ot graph
    bf_execution_times.append(bf_time)
    
    # Parse the bit sting answer
    bf_x = ''.join(str(e) for e in bf_bit_string)
    bf_x_inverse = ''.join('1' if x == '0' else '0' for x in bf_x)
    
    # Print results
    print('\n\tBrute Force')
    print(f'\t\tSolution = {bf_x} [{bf_x_inverse}].')
    print(f'\t\tMaxcut = {str(bf_cost)}.')
    print(f'\t\tTime: {bf_time} seconds.')
    
    # QAOA Approach
    #
    # Run QAOA
    qaoa_bit_string, qaoa_cost, qaoa_optimizer_time = qaoa(graph)
    
    # Parse the bit sting answer
    qaoa_x = ''.join(str(e) for e in qaoa_bit_string)
    qaoa_x_inverse = ''.join('1' if x == '0' else '0' for x in qaoa_x)
    
    # Add execution time to list for output to graph
    qaoa_execution_times.append(qaoa_optimizer_time)
    
    # Print results
    print('\n\tQuantum Approximation Optimization Algorithm (QAOA):')
    print(f'\t\tSolution = {qaoa_x} [{qaoa_x_inverse}].')
    print(f'\t\tMaxcut = {str(qaoa_cost)}.')
    print(f'\t\tOptimizer Time: {str(qaoa_optimizer_time)} seconds.')
    # print(f'\t\tCompmute Minimum Eigenvalue Time: {str(optimizer_time)} seconds.')
    
    # Check validity
    if bf_x == qaoa_x or bf_x == qaoa_x_inverse or qaoa_x == bf_x_inverse:
        qaoa_success += 1
        print('\n\t\tQAOA PASSED!')
    else:
        qaoa_failure += 1
        print('\n\t\tQAOA FAILED!')
    
    # VQE Approach
    #
    # Run VQE
    vqe_bit_string, vqe_cost, vqe_optimizer_time = vqe(graph)
    vqe_x = ''.join(str(e) for e in vqe_bit_string)
    vqe_x_inverse = ''.join('1' if x == '0' else '0' for x in vqe_x)
    print('\n\tVariational Quantum Eigensolver (VQE):')
    print(f'\t\tSolution = {vqe_x} [{vqe_x_inverse}].')
    print(f'\t\tMaxcut = {str(vqe_cost)}.')
    print(f'\t\tOptimizer Time: {str(vqe_optimizer_time)} seconds.')
    print()
    
    # Add execution time to list for output to graph
    vqe_execution_times.append(vqe_optimizer_time)
        
    # Check validity
    if bf_x == vqe_x or bf_x == vqe_x_inverse or vqe_x == bf_x_inverse:
        vqe_success += 1
        print(f'\n\t\tVQE PASSED!')
    else:
        vqe_failure += 1
        print(f'\n\t\tVQE FAILED!')

print(f"""
---------------------------------------------------------
Test Results:
---------------------------------------------------------
qaoa_success = {qaoa_success} / {num_tests} * 100 = {qaoa_success / num_tests * 100}%
qaoa_failure = {qaoa_failure} / {num_tests} * 100 = {qaoa_failure / num_tests * 100}%
vqe_success = {vqe_success} / {num_tests} * 100 = {vqe_success / num_tests * 100}%
vqe_failure ={vqe_failure} / {num_tests} * 100 = {vqe_failure / num_tests * 100}%
""")

# Graph of Execution Times
plt.plot(x_axis, bf_execution_times, label = "Brute Force")
plt.plot(x_axis, qaoa_execution_times, label = "QAOA")
plt.plot(x_axis, vqe_execution_times, label = "VQE")
plt.legend()
plt.show()
# Out:
# Test Case 0:
# --------------
#
# [[0. 1. 1. 5.]
#  [1. 0. 4. 1.]
#  [1. 4. 0. 3.]
#  [5. 1. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 13.0.
# 		Time: 0.0004278679843991995 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 13.0.
# 		Optimizer Time: 19.830986738204956 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0101 [1010].
# 		Maxcut = -12.998830674958398.
# 		Optimizer Time: 4.0762434005737305 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 1:
# --------------
#
# [[0. 1. 4. 4.]
#  [1. 0. 4. 5.]
#  [4. 4. 0. 4.]
#  [4. 5. 4. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Time: 0.0002156129921786487 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Optimizer Time: 13.233232498168945 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0110 [1001].
# 		Maxcut = -13.994913594546187.
# 		Optimizer Time: 5.2186548709869385 seconds.
#
#
# 		VQE FAILED!
#
# Test Case 2:
# --------------
#
# [[0. 5. 3. 5.]
#  [5. 0. 4. 5.]
#  [3. 4. 0. 3.]
#  [5. 5. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Time: 0.00020791200222447515 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Optimizer Time: 12.367632865905762 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -16.99658070141967.
# 		Optimizer Time: 3.8402061462402344 seconds.
#
#
# 		VQE FAILED!
#
# Test Case 3:
# --------------
#
# [[0. 3. 4. 4.]
#  [3. 0. 1. 3.]
#  [4. 1. 0. 1.]
#  [4. 3. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Time: 0.000431126041803509 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Optimizer Time: 14.0207200050354 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1100 [0011].
# 		Maxcut = -11.99858437274867.
# 		Optimizer Time: 3.0854530334472656 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 4:
# --------------
#
# [[0. 1. 1. 3.]
#  [1. 0. 4. 3.]
#  [1. 4. 0. 1.]
#  [3. 3. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Time: 0.0004018389736302197 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Optimizer Time: 11.208994626998901 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1100 [0011].
# 		Maxcut = -10.995526093387596.
# 		Optimizer Time: 3.3794708251953125 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 5:
# --------------
#
# [[0. 2. 2. 2.]
#  [2. 0. 4. 3.]
#  [2. 4. 0. 4.]
#  [2. 3. 4. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Time: 0.0006499220035038888 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 12.0.
# 		Optimizer Time: 13.142988920211792 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0101 [1010].
# 		Maxcut = -11.992053998214693.
# 		Optimizer Time: 4.878862619400024 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 6:
# --------------
#
# [[0. 2. 1. 1.]
#  [2. 0. 4. 5.]
#  [1. 4. 0. 1.]
#  [1. 5. 1. 0.]]
#
# 	Brute Force
# 		Solution = 0100 [1011].
# 		Maxcut = 11.0.
# 		Time: 0.00020168197806924582 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0100 [1011].
# 		Maxcut = 11.0.
# 		Optimizer Time: 13.05650782585144 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -10.997880724817039.
# 		Optimizer Time: 4.252386808395386 seconds.
#
#
# 		VQE FAILED!
#
# Test Case 7:
# --------------
#
# [[0. 1. 3. 4.]
#  [1. 0. 2. 3.]
#  [3. 2. 0. 1.]
#  [4. 3. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Time: 0.00021203799406066537 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Optimizer Time: 13.82967734336853 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1100 [0011].
# 		Maxcut = -11.995529312707362.
# 		Optimizer Time: 3.477860450744629 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 8:
# --------------
#
# [[0. 3. 4. 2.]
#  [3. 0. 3. 2.]
#  [4. 3. 0. 4.]
#  [2. 2. 4. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 13.0.
# 		Time: 0.0003891760134138167 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 13.0.
# 		Optimizer Time: 14.3433198928833 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1001 [0110].
# 		Maxcut = -12.975124029769537.
# 		Optimizer Time: 4.723947048187256 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 9:
# --------------
#
# [[0. 0. 2. 4.]
#  [0. 0. 4. 2.]
#  [2. 4. 0. 2.]
#  [4. 2. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Time: 0.00021081097656860948 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Optimizer Time: 13.199735403060913 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -11.997243742038002.
# 		Optimizer Time: 2.986654043197632 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 10:
# ----------------
#
# [[0. 2. 2. 2.]
#  [2. 0. 3. 4.]
#  [2. 3. 0. 3.]
#  [2. 4. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Time: 0.00026193499797955155 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Optimizer Time: 15.946522951126099 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -10.980108643820914.
# 		Optimizer Time: 3.7573471069335938 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 11:
# ----------------
#
# [[0. 1. 2. 1.]
#  [1. 0. 4. 3.]
#  [2. 4. 0. 2.]
#  [1. 3. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Time: 0.0004350640228949487 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 10.0.
# 		Optimizer Time: 8.255040884017944 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1100 [0011].
# 		Maxcut = -9.99373078935992.
# 		Optimizer Time: 2.622562885284424 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 12:
# ----------------
#
# [[0. 5. 0. 1.]
#  [5. 0. 1. 4.]
#  [0. 1. 0. 4.]
#  [1. 4. 4. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 13.0.
# 		Time: 0.00020845100516453385 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 13.0.
# 		Optimizer Time: 9.297050952911377 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0110 [1001].
# 		Maxcut = -12.999800837149838.
# 		Optimizer Time: 3.3218677043914795 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 13:
# ----------------
#
# [[0. 5. 4. 3.]
#  [5. 0. 3. 2.]
#  [4. 3. 0. 4.]
#  [3. 2. 4. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Time: 0.00020838604541495442 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Optimizer Time: 12.679142236709595 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -14.99879062277288.
# 		Optimizer Time: 3.901742458343506 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 14:
# ----------------
#
# [[0. 2. 4. 1.]
#  [2. 0. 1. 3.]
#  [4. 1. 0. 3.]
#  [1. 3. 3. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Time: 0.0008114959928207099 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 12.0.
# 		Optimizer Time: 15.333049297332764 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1001 [0110].
# 		Maxcut = -11.994998229006114.
# 		Optimizer Time: 3.614095449447632 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 15:
# ----------------
#
# [[0. 3. 2. 4.]
#  [3. 0. 0. 5.]
#  [2. 0. 0. 1.]
#  [4. 5. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Time: 0.00021033099619671702 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 11.0.
# 		Optimizer Time: 12.626233577728271 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0110 [1001].
# 		Maxcut = -10.997945839435816.
# 		Optimizer Time: 3.1490979194641113 seconds.
#
#
# 		VQE FAILED!
#
# Test Case 16:
# ----------------
#
# [[0. 5. 4. 3.]
#  [5. 0. 3. 3.]
#  [4. 3. 0. 1.]
#  [3. 3. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Time: 0.00021152303088456392 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Optimizer Time: 11.472962141036987 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1100 [0011].
# 		Maxcut = -12.992864457523291.
# 		Optimizer Time: 4.566804885864258 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 17:
# ----------------
#
# [[0. 5. 2. 3.]
#  [5. 0. 3. 3.]
#  [2. 3. 0. 4.]
#  [3. 3. 4. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Time: 0.0003801639541052282 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Optimizer Time: 12.552379369735718 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -14.982629193954992.
# 		Optimizer Time: 3.9596850872039795 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 18:
# ----------------
#
# [[0. 3. 4. 5.]
#  [3. 0. 3. 3.]
#  [4. 3. 0. 2.]
#  [5. 3. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Time: 0.00020896497881039977 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Optimizer Time: 15.212037324905396 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -14.983891278179554.
# 		Optimizer Time: 3.9131033420562744 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 19:
# ----------------
#
# [[0. 4. 4. 4.]
#  [4. 0. 5. 2.]
#  [4. 5. 0. 1.]
#  [4. 2. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Time: 0.00021016999380663037 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Optimizer Time: 11.412269592285156 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -14.946294482240893.
# 		Optimizer Time: 3.546220541000366 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 20:
# ----------------
#
# [[0. 4. 1. 1.]
#  [4. 0. 5. 0.]
#  [1. 5. 0. 5.]
#  [1. 0. 5. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Time: 0.00023752800188958645 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Optimizer Time: 11.528728723526001 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -14.992593850639675.
# 		Optimizer Time: 3.1709227561950684 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 21:
# ----------------
#
# [[0. 1. 4. 4.]
#  [1. 0. 5. 4.]
#  [4. 5. 0. 5.]
#  [4. 4. 5. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Time: 0.00020858499919995666 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Optimizer Time: 14.475871801376343 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0101 [1010].
# 		Maxcut = -15.017451220224347.
# 		Optimizer Time: 5.6233086585998535 seconds.
#
#
# 		VQE FAILED!
#
# Test Case 22:
# ----------------
#
# [[0. 1. 4. 4.]
#  [1. 0. 5. 2.]
#  [4. 5. 0. 4.]
#  [4. 2. 4. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Time: 0.00021001900313422084 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 15.0.
# 		Optimizer Time: 11.682009935379028 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -14.927265130603926.
# 		Optimizer Time: 5.817622423171997 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 23:
# ----------------
#
# [[0. 1. 1. 2.]
#  [1. 0. 5. 1.]
#  [1. 5. 0. 3.]
#  [2. 1. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 11.0.
# 		Time: 0.0009788230527192354 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 11.0.
# 		Optimizer Time: 14.947235107421875 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0101 [1010].
# 		Maxcut = -10.999493092583892.
# 		Optimizer Time: 4.491664886474609 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 24:
# ----------------
#
# [[0. 5. 4. 2.]
#  [5. 0. 4. 2.]
#  [4. 4. 0. 5.]
#  [2. 2. 5. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Time: 0.00021065102191641927 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Optimizer Time: 15.02577543258667 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -15.992463287072558.
# 		Optimizer Time: 2.968949794769287 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 25:
# ----------------
#
# [[0. 1. 1. 1.]
#  [1. 0. 3. 3.]
#  [1. 3. 0. 5.]
#  [1. 3. 5. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 10.0.
# 		Time: 0.00021103996550664306 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 10.0.
# 		Optimizer Time: 7.67101526260376 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -9.991219222951958.
# 		Optimizer Time: 2.5021865367889404 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 26:
# ----------------
#
# [[0. 3. 4. 1.]
#  [3. 0. 3. 5.]
#  [4. 3. 0. 4.]
#  [1. 5. 4. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Time: 0.00037951802369207144 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 16.0.
# 		Optimizer Time: 12.347899913787842 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0110 [1001].
# 		Maxcut = -15.998720180492636.
# 		Optimizer Time: 3.339406728744507 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 27:
# ----------------
#
# [[0. 2. 5. 2.]
#  [2. 0. 3. 2.]
#  [5. 3. 0. 2.]
#  [2. 2. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Time: 0.0004052399890497327 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 12.0.
# 		Optimizer Time: 13.39622187614441 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1100 [0011].
# 		Maxcut = -11.997268801121145.
# 		Optimizer Time: 2.9295918941497803 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 28:
# ----------------
#
# [[0. 2. 3. 4.]
#  [2. 0. 1. 5.]
#  [3. 1. 0. 5.]
#  [4. 5. 5. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.0002056920202448964 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 10.701347827911377 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1001 [0110].
# 		Maxcut = -14.910907017510265.
# 		Optimizer Time: 4.305171012878418 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 29:
# ----------------
#
# [[0. 1. 4. 5.]
#  [1. 0. 2. 1.]
#  [4. 2. 0. 5.]
#  [5. 1. 5. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 13.0.
# 		Time: 0.00020850199507549405 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 13.0.
# 		Optimizer Time: 11.951110124588013 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -12.997863733269.
# 		Optimizer Time: 3.544621229171753 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 30:
# ----------------
#
# [[0. 3. 4. 1.]
#  [3. 0. 3. 3.]
#  [4. 3. 0. 5.]
#  [1. 3. 5. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.000368645996786654 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 8.350094556808472 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0110 [1001].
# 		Maxcut = -14.996858144259576.
# 		Optimizer Time: 3.4892406463623047 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 31:
# ----------------
#
# [[0. 2. 3. 5.]
#  [2. 0. 4. 2.]
#  [3. 4. 0. 2.]
#  [5. 2. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.00021373899653553963 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 13.633559942245483 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -13.952384208089825.
# 		Optimizer Time: 4.718917608261108 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 32:
# ----------------
#
# [[0. 3. 3. 3.]
#  [3. 0. 1. 5.]
#  [3. 1. 0. 3.]
#  [3. 5. 3. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Time: 0.00024495902471244335 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 14.0.
# 		Optimizer Time: 12.643522262573242 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1001 [0110].
# 		Maxcut = -13.97979789434116.
# 		Optimizer Time: 3.201904296875 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 33:
# ----------------
#
# [[0. 3. 3. 4.]
#  [3. 0. 2. 5.]
#  [3. 2. 0. 3.]
#  [4. 5. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.00020890001906082034 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 11.245609283447266 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0110 [1001].
# 		Maxcut = -13.996955585117371.
# 		Optimizer Time: 4.314239501953125 seconds.
#
#
# 		VQE FAILED!
#
# Test Case 34:
# ----------------
#
# [[0. 5. 4. 5.]
#  [5. 0. 5. 3.]
#  [4. 5. 0. 5.]
#  [5. 3. 5. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 20.0.
# 		Time: 0.00021254498278722167 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 20.0.
# 		Optimizer Time: 13.009214162826538 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -19.99323855905236.
# 		Optimizer Time: 3.9050045013427734 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 35:
# ----------------
#
# [[0. 2. 5. 2.]
#  [2. 0. 1. 3.]
#  [5. 1. 0. 5.]
#  [2. 3. 5. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.0002104380400851369 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 15.096178770065308 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0110 [1001].
# 		Maxcut = -14.998678762481962.
# 		Optimizer Time: 4.760982990264893 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 36:
# ----------------
#
# [[0. 5. 1. 4.]
#  [5. 0. 2. 5.]
#  [1. 2. 0. 1.]
#  [4. 5. 1. 0.]]
#
# 	Brute Force
# 		Solution = 0100 [1011].
# 		Maxcut = 12.0.
# 		Time: 0.00030844303546473384 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0100 [1011].
# 		Maxcut = 12.0.
# 		Optimizer Time: 9.499643325805664 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -11.998416147601883.
# 		Optimizer Time: 3.5721147060394287 seconds.
#
#
# 		VQE FAILED!
#
# Test Case 37:
# ----------------
#
# [[0. 3. 1. 5.]
#  [3. 0. 5. 2.]
#  [1. 5. 0. 3.]
#  [5. 2. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Time: 0.00021513196406885982 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 16.0.
# 		Optimizer Time: 11.65664029121399 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0101 [1010].
# 		Maxcut = -15.995352889875068.
# 		Optimizer Time: 3.238801956176758 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 38:
# ----------------
#
# [[0. 1. 3. 3.]
#  [1. 0. 1. 1.]
#  [3. 1. 0. 4.]
#  [3. 1. 4. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 9.0.
# 		Time: 0.00023388699628412724 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 9.0.
# 		Optimizer Time: 12.211122035980225 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -8.999696422180143.
# 		Optimizer Time: 4.710409879684448 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 39:
# ----------------
#
# [[0. 2. 5. 5.]
#  [2. 0. 3. 4.]
#  [5. 3. 0. 2.]
#  [5. 4. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Time: 0.00021049700444564223 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 17.0.
# 		Optimizer Time: 11.974218606948853 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -16.996881213731093.
# 		Optimizer Time: 3.609966993331909 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 40:
# ----------------
#
# [[0. 3. 2. 3.]
#  [3. 0. 3. 5.]
#  [2. 3. 0. 2.]
#  [3. 5. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Time: 0.00044965901179239154 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Optimizer Time: 12.365160465240479 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -12.989593468744678.
# 		Optimizer Time: 3.29494571685791 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 41:
# ----------------
#
# [[0. 5. 2. 1.]
#  [5. 0. 4. 5.]
#  [2. 4. 0. 2.]
#  [1. 5. 2. 0.]]
#
# 	Brute Force
# 		Solution = 0100 [1011].
# 		Maxcut = 14.0.
# 		Time: 0.00021097902208566666 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0100 [1011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 13.296921014785767 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0100 [1011].
# 		Maxcut = -13.97896752856548.
# 		Optimizer Time: 4.604273796081543 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 42:
# ----------------
#
# [[0. 4. 5. 3.]
#  [4. 0. 2. 4.]
#  [5. 2. 0. 1.]
#  [3. 4. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Time: 0.0002113789669238031 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 14.0.
# 		Optimizer Time: 11.243727922439575 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1100 [0011].
# 		Maxcut = -13.995770288687183.
# 		Optimizer Time: 3.196676254272461 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 43:
# ----------------
#
# [[0. 5. 4. 3.]
#  [5. 0. 2. 5.]
#  [4. 2. 0. 1.]
#  [3. 5. 1. 0.]]
#
# 	Brute Force
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Time: 0.0003415929968468845 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 0110 [1001].
# 		Maxcut = 15.0.
# 		Optimizer Time: 10.197821378707886 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0110 [1001].
# 		Maxcut = -14.98946145557539.
# 		Optimizer Time: 3.2002036571502686 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 44:
# ----------------
#
# [[0. 5. 4. 4.]
#  [5. 0. 3. 3.]
#  [4. 3. 0. 3.]
#  [4. 3. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Time: 0.0002066830056719482 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 15.0.
# 		Optimizer Time: 7.470771789550781 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -14.999649467565469.
# 		Optimizer Time: 3.1984286308288574 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 45:
# ----------------
#
# [[0. 3. 2. 5.]
#  [3. 0. 4. 1.]
#  [2. 4. 0. 5.]
#  [5. 1. 5. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 17.0.
# 		Time: 0.00020694895647466183 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 17.0.
# 		Optimizer Time: 13.073711633682251 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -16.998311091928517.
# 		Optimizer Time: 2.9236156940460205 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 46:
# ----------------
#
# [[0. 1. 2. 3.]
#  [1. 0. 5. 3.]
#  [2. 5. 0. 3.]
#  [3. 3. 3. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Time: 0.0002111590001732111 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Optimizer Time: 10.152085781097412 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0011 [1100].
# 		Maxcut = -12.93168084146273.
# 		Optimizer Time: 3.328338384628296 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 47:
# ----------------
#
# [[0. 3. 2. 5.]
#  [3. 0. 4. 2.]
#  [2. 4. 0. 0.]
#  [5. 2. 0. 0.]]
#
# 	Brute Force
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Time: 0.00020786799723282456 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1100 [0011].
# 		Maxcut = 13.0.
# 		Optimizer Time: 10.778532266616821 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1100 [0011].
# 		Maxcut = -12.997991684134695.
# 		Optimizer Time: 3.6498239040374756 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 48:
# ----------------
#
# [[0. 3. 5. 4.]
#  [3. 0. 2. 0.]
#  [5. 2. 0. 1.]
#  [4. 0. 1. 0.]]
#
# 	Brute Force
# 		Solution = 1000 [0111].
# 		Maxcut = 12.0.
# 		Time: 0.0005177229759283364 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1000 [0111].
# 		Maxcut = 12.0.
# 		Optimizer Time: 14.14547348022461 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 0111 [1000].
# 		Maxcut = -11.896358082270606.
# 		Optimizer Time: 4.065782308578491 seconds.
#
#
# 		VQE PASSED!
#
# Test Case 49:
# ----------------
#
# [[0. 2. 2. 2.]
#  [2. 0. 5. 1.]
#  [2. 5. 0. 2.]
#  [2. 1. 2. 0.]]
#
# 	Brute Force
# 		Solution = 1010 [0101].
# 		Maxcut = 11.0.
# 		Time: 0.00020878197392448783 seconds.
#
# 	Quantum Approximation Optimization Algorithm (QAOA):
# 		Solution = 1010 [0101].
# 		Maxcut = 11.0.
# 		Optimizer Time: 13.09715223312378 seconds.
#
# 		QAOA PASSED!
#
# 	Variational Quantum Eigensolver (VQE):
# 		Solution = 1010 [0101].
# 		Maxcut = -10.998924919001487.
# 		Optimizer Time: 4.24631142616272 seconds.
#
#
# 		VQE PASSED!
#
# ---------------------------------------------------------
# Test Results:
# ---------------------------------------------------------
# qaoa_success = 50 / 50 * 100 = 100.0%
# qaoa_failure = 0 / 50 * 100 = 0.0%
# vqe_success = 43 / 50 * 100 = 86.0%
# vqe_failure =7 / 50 * 100 = 14.000000000000002%
