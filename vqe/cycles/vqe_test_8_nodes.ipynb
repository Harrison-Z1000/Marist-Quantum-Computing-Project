# %% [markdown]
# ## Random Graphs
#
# ### Helper Functions
#
# Randomly generate an adjancency matrix...

# %%
import timeit
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations, groupby

# Size of NxN Matrix
n = 8

# Moved to global scopee to allow for timing
bf_bit_string, bf_cost = None, None

def random_row():
    row = list(np.random.choice((0, 1, 2, 3, 4, 5),size=n))
    
    # Make sure there's no isolated nodes
    if sum(row) == 0:
        row = random_row()
    return row

def random_matrix():
    rows = []
    for i in range(0, n):
        rows.append(random_row())
    numpy_matrix = np.matrix(rows)
    
    return numpy_matrix

def random_graph():
    np_matrix = random_matrix()
    g = nx.convert_matrix.from_numpy_matrix(
        np_matrix, 
        parallel_edges=False, 
        create_using=nx.Graph
    )
    
    # nx.draw(g, node_color='lightblue', 
    #     with_labels=True, 
    #     node_size=500)
    
    return g, np_matrix

# %% [markdown]
# ### Brute Force

# %%
def brute_force(graph, w):
    global bf_bit_string
    global bf_cost
    
    bf_bit_string = None
    bf_cost = None
    
    best_cost_brute = 0
    for b in range(2**n):
        x = [int(t) for t in reversed(list(bin(b)[2:].zfill(n)))]
        cost = 0
        for i in range(n):
            for j in range(n):
                cost = cost + w[i,j]*x[i]*(1-x[j])
        if best_cost_brute < cost:
            best_cost_brute = cost
            xbest_brute = x
    bf_bit_string = xbest_brute
    bf_cost = best_cost_brute
    return xbest_brute, best_cost_brute

# %% [markdown]
# ### Variatonal Quantum EignSolver

# %%
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram
from qiskit.circuit.library import TwoLocal
from qiskit_optimization.applications import Maxcut, Tsp
from qiskit.algorithms import VQE, NumPyMinimumEigensolver
from qiskit.algorithms.optimizers import SPSA, COBYLA
from qiskit.utils import algorithm_globals, QuantumInstance
from qiskit_optimization.algorithms import MinimumEigenOptimizer

def vqe(w):
    # Define our Qiskit Maxcut Instance
    max_cut = Maxcut(w)
    qp = max_cut.to_quadratic_program()

    # Translate to Ising Hamiltonian
    qubitOp, offset = qp.to_ising()

    # Setup our simulator
    algorithm_globals.random_seed = 123
    seed = 10598
    backend = Aer.get_backend('aer_simulator_statevector')
    quantum_instance = QuantumInstance(backend, seed_simulator=seed, seed_transpiler=seed)

    # Construct VQE
    spsa = SPSA(maxiter=300)
    cobyla = COBYLA(maxiter=300)
    ry = TwoLocal(qubitOp.num_qubits, 'ry', 'cz', reps=5, entanglement='linear')
    vqe = VQE(ry, optimizer=spsa, quantum_instance=quantum_instance)

    # Run VQE
    compute_min_eigenval_time = timeit.timeit(lambda: vqe.compute_minimum_eigenvalue(qubitOp), number=1)
    result = vqe.compute_minimum_eigenvalue(qubitOp)

    # print results
    bit_string = list(max_cut.sample_most_likely(result.eigenstate))
    bit_string = map(int, bit_string)
    # print('energy:', result.eigenvalue.real)
    # print('time:', result.optimizer_time)
    # print('max-cut objective:', result.eigenvalue.real + offset)
    # print('solution:', bit_string)
    # print('solution objective:', qp.objective.evaluate(bit_string))
    
    return bit_string, (result.eigenvalue.real + offset), result.optimizer_time, compute_min_eigenval_time
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# ## Tests

# %%
# Generate 1,000 graphs
success = 0
failure = 0

# TODO: Change the number of tests, ad hoc
num_tests: int = 100

for graph_id in range(num_tests):
    global bf_bit_string
    global bf_cost
    
    # Generate Random Graph
    graph, matrix = random_graph()
    
    # Computing the weight matrix from the random graph
    w = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            temp = graph.get_edge_data(i,j,default=0)
            if temp != 0:
                w[i,j] = temp['weight']
    
    print(f'\nTest Case {graph_id}: ')
    print('------------' + '-' * (graph_id * 2))
    print()
    print(w)
    
    # Brute Force Approach
    #
    # Time brute force algorithm
    bf_time: float = timeit.timeit(lambda: brute_force(graph, w), number=1)
    
    # Parse the bit sting answer
    bf_x = ''.join(str(e) for e in bf_bit_string)
    bf_x_inverse = ''.join('1' if x == '0' else '0' for x in bf_x)
    
    # Print results
    print('\n\tBrute Force')
    print(f'\t\tSolution = {bf_x} [{bf_x_inverse}].')
    print(f'\t\tMaxcut = {str(bf_cost)}.')
    print(f'\t\tTime: {bf_time} seconds.')
    
    # VQE Approach
    #
    #
    vqe_bit_string, vqe_cost, optimizer_time, compute_minimum_eigenvalue_time = vqe(w)
    
    # Parse the bit sting answer
    vqe_x = ''.join(str(e) for e in vqe_bit_string)
    vqe_x_inverse = ''.join('1' if x == '0' else '0' for x in vqe_x)
    
    # Print results
    print('\n\tVariation Quantum Eignsolver (VQE):')
    print(f'\t\tSolution = {vqe_x} [{vqe_x_inverse}].')
    print(f'\t\tMaxcut = {str(vqe_cost)}.')
    print(f'\t\tOptimizer Time: {str(optimizer_time)} seconds.')
    print(f'\t\tCompmute Minimum Eigenvalue Time: {str(optimizer_time)} seconds.')
    print()
    
    # Check validity
    if bf_x == vqe_x or bf_x == vqe_x_inverse or vqe_x == bf_x_inverse:
        success += 1
    else:
        failure += 1
# Out:
# Test Case 0:
# ------------
#
# [[4. 3. 3. 1. 2. 4. 4. 5.]
#  [3. 1. 1. 4. 2. 3. 1. 5.]
#  [3. 1. 0. 2. 3. 2. 1. 2.]
#  [1. 4. 2. 1. 4. 4. 4. 4.]
#  [2. 2. 3. 4. 5. 1. 4. 2.]
#  [4. 3. 2. 4. 1. 3. 4. 4.]
#  [4. 1. 1. 4. 4. 4. 2. 4.]
#  [5. 5. 2. 4. 2. 4. 4. 2.]]
#
# 	Brute Force
# 		Solution = 10011100 [01100011].
# 		Maxcut = 53.0.
# 		Time: 0.009471814963035285 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100011 [10011100].
# 		Maxcut = -52.97166192978911.
# 		Optimizer Time: 3.7796528339385986 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.7796528339385986 seconds.
#
#
# Test Case 1:
# --------------
#
# [[1. 2. 5. 4. 3. 2. 3. 2.]
#  [2. 1. 5. 4. 4. 1. 5. 2.]
#  [5. 5. 5. 5. 1. 5. 4. 3.]
#  [4. 4. 5. 3. 2. 5. 2. 3.]
#  [3. 4. 1. 2. 1. 2. 1. 2.]
#  [2. 1. 5. 5. 2. 2. 4. 4.]
#  [3. 5. 4. 2. 1. 4. 5. 1.]
#  [2. 2. 3. 3. 2. 4. 1. 3.]]
#
# 	Brute Force
# 		Solution = 00111010 [11000101].
# 		Maxcut = 58.0.
# 		Time: 0.044518029084429145 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000101 [00111010].
# 		Maxcut = -57.84553248601291.
# 		Optimizer Time: 3.9945075511932373 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.9945075511932373 seconds.
#
#
# Test Case 2:
# ----------------
#
# [[1. 4. 4. 3. 2. 2. 5. 3.]
#  [4. 1. 3. 5. 1. 2. 3. 3.]
#  [4. 3. 4. 3. 5. 1. 5. 1.]
#  [3. 5. 3. 1. 4. 1. 3. 3.]
#  [2. 1. 5. 4. 4. 3. 3. 2.]
#  [2. 2. 1. 1. 3. 2. 3. 1.]
#  [5. 3. 5. 3. 3. 3. 2. 4.]
#  [3. 3. 1. 3. 2. 1. 4. 5.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 54.0.
# 		Time: 0.01709627907257527 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10011010 [01100101].
# 		Maxcut = -50.852794299748375.
# 		Optimizer Time: 4.262412071228027 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.262412071228027 seconds.
#
#
# Test Case 3:
# ------------------
#
# [[1. 2. 3. 1. 4. 3. 3. 5.]
#  [2. 3. 3. 2. 3. 5. 5. 4.]
#  [3. 3. 2. 3. 1. 4. 1. 2.]
#  [1. 2. 3. 0. 2. 5. 5. 4.]
#  [4. 3. 1. 2. 5. 3. 5. 2.]
#  [3. 5. 4. 5. 3. 4. 1. 5.]
#  [3. 5. 1. 5. 5. 1. 5. 4.]
#  [5. 4. 2. 4. 2. 5. 4. 4.]]
#
# 	Brute Force
# 		Solution = 11011000 [00100111].
# 		Maxcut = 59.0.
# 		Time: 0.01710377202834934 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11010000 [00101111].
# 		Maxcut = -57.429350716600545.
# 		Optimizer Time: 3.915600538253784 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.915600538253784 seconds.
#
#
# Test Case 4:
# --------------------
#
# [[4. 1. 4. 2. 3. 4. 5. 4.]
#  [1. 5. 1. 0. 1. 3. 5. 2.]
#  [4. 1. 4. 4. 4. 3. 1. 5.]
#  [2. 0. 4. 5. 1. 0. 4. 1.]
#  [3. 1. 4. 1. 2. 3. 3. 4.]
#  [4. 3. 3. 0. 3. 5. 4. 3.]
#  [5. 5. 1. 4. 3. 4. 4. 3.]
#  [4. 2. 5. 1. 4. 3. 3. 5.]]
#
# 	Brute Force
# 		Solution = 11011000 [00100111].
# 		Maxcut = 51.0.
# 		Time: 0.015624028048478067 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00100110 [11011001].
# 		Maxcut = -50.75914570830598.
# 		Optimizer Time: 4.061132431030273 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.061132431030273 seconds.
#
#
# Test Case 5:
# ----------------------
#
# [[0. 0. 3. 3. 3. 3. 0. 2.]
#  [0. 2. 2. 2. 2. 4. 5. 4.]
#  [3. 2. 0. 2. 3. 3. 5. 4.]
#  [3. 2. 2. 5. 5. 2. 3. 1.]
#  [3. 2. 3. 5. 5. 4. 5. 3.]
#  [3. 4. 3. 2. 4. 4. 5. 2.]
#  [0. 5. 5. 3. 5. 5. 4. 5.]
#  [2. 4. 4. 1. 3. 2. 5. 1.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 56.0.
# 		Time: 0.01609600696247071 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001010 [00110101].
# 		Maxcut = -55.90073753942052.
# 		Optimizer Time: 4.03617262840271 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.03617262840271 seconds.
#
#
# Test Case 6:
# ------------------------
#
# [[4. 2. 3. 1. 4. 3. 5. 4.]
#  [2. 3. 4. 3. 2. 5. 4. 5.]
#  [3. 4. 4. 5. 1. 3. 4. 4.]
#  [1. 3. 5. 4. 1. 3. 5. 2.]
#  [4. 2. 1. 1. 3. 2. 4. 2.]
#  [3. 5. 3. 3. 2. 1. 2. 2.]
#  [5. 4. 4. 5. 4. 2. 1. 4.]
#  [4. 5. 4. 2. 2. 2. 4. 2.]]
#
# 	Brute Force
# 		Solution = 11011000 [00100111].
# 		Maxcut = 57.0.
# 		Time: 0.016273787012323737 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100110 [01011001].
# 		Maxcut = -53.87442961576751.
# 		Optimizer Time: 4.489397048950195 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.489397048950195 seconds.
#
#
# Test Case 7:
# --------------------------
#
# [[4. 2. 4. 1. 4. 5. 1. 1.]
#  [2. 5. 4. 4. 3. 2. 3. 5.]
#  [4. 4. 1. 3. 2. 3. 3. 3.]
#  [1. 4. 3. 1. 1. 2. 4. 3.]
#  [4. 3. 2. 1. 1. 4. 3. 3.]
#  [5. 2. 3. 2. 4. 2. 1. 4.]
#  [1. 3. 3. 4. 3. 1. 2. 5.]
#  [1. 5. 3. 3. 3. 4. 5. 5.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 54.0.
# 		Time: 0.01567943103145808 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000110 [00111001].
# 		Maxcut = -53.84984657550201.
# 		Optimizer Time: 4.330039739608765 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.330039739608765 seconds.
#
#
# Test Case 8:
# ----------------------------
#
# [[4. 5. 4. 4. 3. 4. 4. 3.]
#  [5. 2. 5. 4. 4. 1. 5. 4.]
#  [4. 5. 0. 4. 5. 3. 1. 4.]
#  [4. 4. 4. 0. 2. 2. 3. 4.]
#  [3. 4. 5. 2. 2. 1. 0. 5.]
#  [4. 1. 3. 2. 1. 4. 2. 2.]
#  [4. 5. 1. 3. 0. 2. 1. 4.]
#  [3. 4. 4. 4. 5. 2. 4. 5.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 58.0.
# 		Time: 0.015463944058865309 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101010 [01010101].
# 		Maxcut = -57.67661957897297.
# 		Optimizer Time: 4.0710248947143555 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.0710248947143555 seconds.
#
#
# Test Case 9:
# ------------------------------
#
# [[5. 2. 5. 3. 4. 5. 1. 4.]
#  [2. 1. 1. 4. 0. 3. 2. 5.]
#  [5. 1. 3. 4. 3. 4. 2. 3.]
#  [3. 4. 4. 2. 4. 5. 1. 3.]
#  [4. 0. 3. 4. 5. 1. 2. 4.]
#  [5. 3. 4. 5. 1. 4. 4. 4.]
#  [1. 2. 2. 1. 2. 4. 0. 4.]
#  [4. 5. 3. 3. 4. 4. 4. 0.]]
#
# 	Brute Force
# 		Solution = 01101100 [10010011].
# 		Maxcut = 59.0.
# 		Time: 0.01444491499569267 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010010 [01101101].
# 		Maxcut = -53.68766184042891.
# 		Optimizer Time: 4.143970966339111 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.143970966339111 seconds.
#
#
# Test Case 10:
# --------------------------------
#
# [[2. 5. 1. 5. 3. 5. 2. 3.]
#  [5. 5. 1. 3. 3. 5. 4. 1.]
#  [1. 1. 2. 1. 5. 4. 3. 0.]
#  [5. 3. 1. 5. 0. 4. 4. 1.]
#  [3. 3. 5. 0. 4. 2. 3. 5.]
#  [5. 5. 4. 4. 2. 2. 5. 2.]
#  [2. 4. 3. 4. 3. 5. 5. 4.]
#  [3. 1. 0. 1. 5. 2. 4. 2.]]
#
# 	Brute Force
# 		Solution = 10001110 [01110001].
# 		Maxcut = 57.0.
# 		Time: 0.016796726966276765 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100101 [10011010].
# 		Maxcut = -53.613868744169054.
# 		Optimizer Time: 4.246816635131836 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.246816635131836 seconds.
#
#
# Test Case 11:
# ----------------------------------
#
# [[2. 2. 3. 4. 3. 5. 3. 3.]
#  [2. 2. 4. 2. 3. 5. 3. 3.]
#  [3. 4. 5. 5. 3. 0. 3. 3.]
#  [4. 2. 5. 0. 3. 1. 4. 2.]
#  [3. 3. 3. 3. 1. 1. 1. 5.]
#  [5. 5. 0. 1. 1. 2. 2. 2.]
#  [3. 3. 3. 4. 1. 2. 5. 2.]
#  [3. 3. 3. 2. 5. 2. 2. 2.]]
#
# 	Brute Force
# 		Solution = 00101110 [11010001].
# 		Maxcut = 54.0.
# 		Time: 0.012458030018024147 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010001 [10101110].
# 		Maxcut = -48.73716818897231.
# 		Optimizer Time: 4.095385313034058 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.095385313034058 seconds.
#
#
# Test Case 12:
# ------------------------------------
#
# [[5. 4. 3. 5. 4. 2. 3. 2.]
#  [4. 3. 4. 4. 5. 3. 1. 2.]
#  [3. 4. 2. 4. 2. 3. 5. 1.]
#  [5. 4. 4. 2. 1. 2. 1. 1.]
#  [4. 5. 2. 1. 3. 4. 2. 2.]
#  [2. 3. 3. 2. 4. 2. 1. 1.]
#  [3. 1. 5. 1. 2. 1. 2. 1.]
#  [2. 2. 1. 1. 2. 1. 1. 0.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 48.0.
# 		Time: 0.01520509400870651 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101001 [01010110].
# 		Maxcut = -46.73728912192497.
# 		Optimizer Time: 3.9776885509490967 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.9776885509490967 seconds.
#
#
# Test Case 13:
# --------------------------------------
#
# [[2. 1. 4. 3. 5. 3. 5. 5.]
#  [1. 4. 5. 2. 0. 1. 3. 3.]
#  [4. 5. 5. 1. 2. 4. 3. 5.]
#  [3. 2. 1. 4. 5. 2. 5. 4.]
#  [5. 0. 2. 5. 2. 1. 3. 5.]
#  [3. 1. 4. 2. 1. 5. 5. 3.]
#  [5. 3. 3. 5. 3. 5. 0. 3.]
#  [5. 3. 5. 4. 5. 3. 3. 5.]]
#
# 	Brute Force
# 		Solution = 11001100 [00110011].
# 		Maxcut = 59.0.
# 		Time: 0.015322557999752462 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00110011 [11001100].
# 		Maxcut = -55.95851077754875.
# 		Optimizer Time: 4.171536922454834 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.171536922454834 seconds.
#
#
# Test Case 14:
# ----------------------------------------
#
# [[0. 3. 4. 2. 1. 4. 2. 3.]
#  [3. 1. 4. 4. 2. 5. 5. 4.]
#  [4. 4. 0. 2. 4. 5. 1. 2.]
#  [2. 4. 2. 2. 4. 4. 1. 1.]
#  [1. 2. 4. 4. 1. 5. 2. 2.]
#  [4. 5. 5. 4. 5. 0. 4. 1.]
#  [2. 5. 1. 1. 2. 4. 1. 4.]
#  [3. 4. 2. 1. 2. 1. 4. 4.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 55.0.
# 		Time: 0.016889691003598273 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001101 [10110010].
# 		Maxcut = -53.4271994853982.
# 		Optimizer Time: 3.9307990074157715 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.9307990074157715 seconds.
#
#
# Test Case 15:
# ------------------------------------------
#
# [[0. 1. 2. 2. 2. 5. 4. 4.]
#  [1. 0. 1. 4. 1. 5. 3. 4.]
#  [2. 1. 5. 3. 0. 2. 4. 1.]
#  [2. 4. 3. 4. 3. 1. 2. 5.]
#  [2. 1. 0. 3. 1. 0. 4. 1.]
#  [5. 5. 2. 1. 0. 0. 5. 5.]
#  [4. 3. 4. 2. 4. 5. 5. 4.]
#  [4. 4. 1. 5. 1. 5. 4. 2.]]
#
# 	Brute Force
# 		Solution = 11010010 [00101101].
# 		Maxcut = 53.0.
# 		Time: 0.015346422092989087 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11010010 [00101101].
# 		Maxcut = -52.93555211436019.
# 		Optimizer Time: 3.9806222915649414 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.9806222915649414 seconds.
#
#
# Test Case 16:
# --------------------------------------------
#
# [[0. 1. 3. 5. 2. 4. 1. 5.]
#  [1. 0. 4. 3. 5. 1. 4. 3.]
#  [3. 4. 5. 4. 4. 2. 4. 3.]
#  [5. 3. 4. 0. 5. 3. 2. 4.]
#  [2. 5. 4. 5. 0. 5. 3. 2.]
#  [4. 1. 2. 3. 5. 3. 5. 2.]
#  [1. 4. 4. 2. 3. 5. 3. 1.]
#  [5. 3. 3. 4. 2. 2. 1. 1.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 59.0.
# 		Time: 0.016894264961592853 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010101 [10101010].
# 		Maxcut = -56.90502831895127.
# 		Optimizer Time: 3.7620339393615723 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.7620339393615723 seconds.
#
#
# Test Case 17:
# ----------------------------------------------
#
# [[4. 2. 3. 3. 3. 2. 2. 2.]
#  [2. 5. 3. 1. 5. 3. 5. 4.]
#  [3. 3. 5. 2. 4. 1. 4. 2.]
#  [3. 1. 2. 0. 3. 1. 5. 5.]
#  [3. 5. 4. 3. 0. 1. 3. 1.]
#  [2. 3. 1. 1. 1. 2. 1. 2.]
#  [2. 5. 4. 5. 3. 1. 2. 4.]
#  [2. 4. 2. 5. 1. 2. 4. 2.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 51.0.
# 		Time: 0.016762970946729183 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11010010 [00101101].
# 		Maxcut = -47.9560537601992.
# 		Optimizer Time: 4.041682481765747 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.041682481765747 seconds.
#
#
# Test Case 18:
# ------------------------------------------------
#
# [[5. 2. 1. 3. 5. 4. 1. 5.]
#  [2. 3. 1. 5. 4. 5. 1. 5.]
#  [1. 1. 0. 5. 4. 0. 3. 1.]
#  [3. 5. 5. 1. 4. 3. 4. 1.]
#  [5. 4. 4. 4. 0. 1. 5. 5.]
#  [4. 5. 0. 3. 1. 2. 1. 5.]
#  [1. 1. 3. 4. 5. 1. 3. 3.]
#  [5. 5. 1. 1. 5. 5. 3. 3.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 59.0.
# 		Time: 0.01702872000169009 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11100010 [00011101].
# 		Maxcut = -58.81476389490982.
# 		Optimizer Time: 4.018393278121948 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.018393278121948 seconds.
#
#
# Test Case 19:
# --------------------------------------------------
#
# [[4. 2. 4. 4. 4. 4. 3. 2.]
#  [2. 5. 3. 1. 1. 4. 2. 5.]
#  [4. 3. 1. 4. 4. 2. 0. 5.]
#  [4. 1. 4. 4. 5. 1. 1. 2.]
#  [4. 1. 4. 5. 4. 1. 1. 2.]
#  [4. 4. 2. 1. 1. 0. 4. 1.]
#  [3. 2. 0. 1. 1. 4. 4. 5.]
#  [2. 5. 5. 2. 2. 1. 5. 5.]]
#
# 	Brute Force
# 		Solution = 01110010 [10001101].
# 		Maxcut = 52.0.
# 		Time: 0.01689030707348138 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10001101 [01110010].
# 		Maxcut = -51.94390782762666.
# 		Optimizer Time: 3.7217516899108887 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.7217516899108887 seconds.
#
#
# Test Case 20:
# ----------------------------------------------------
#
# [[3. 4. 3. 4. 5. 5. 1. 1.]
#  [4. 1. 3. 1. 3. 2. 5. 0.]
#  [3. 3. 5. 4. 3. 2. 1. 3.]
#  [4. 1. 4. 1. 2. 3. 2. 4.]
#  [5. 3. 3. 2. 4. 3. 1. 2.]
#  [5. 2. 2. 3. 3. 5. 2. 1.]
#  [1. 5. 1. 2. 1. 2. 0. 1.]
#  [1. 0. 3. 4. 2. 1. 1. 4.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 47.0.
# 		Time: 0.017300831037573516 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110010 [01001101].
# 		Maxcut = -44.93052160676956.
# 		Optimizer Time: 4.076441049575806 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.076441049575806 seconds.
#
#
# Test Case 21:
# ------------------------------------------------------
#
# [[1. 5. 1. 2. 5. 2. 5. 4.]
#  [5. 0. 2. 4. 2. 3. 4. 3.]
#  [1. 2. 2. 1. 4. 5. 2. 4.]
#  [2. 4. 1. 2. 1. 4. 5. 2.]
#  [5. 2. 4. 1. 2. 3. 5. 1.]
#  [2. 3. 5. 4. 3. 4. 2. 2.]
#  [5. 4. 2. 5. 5. 2. 4. 1.]
#  [4. 3. 4. 2. 1. 2. 1. 3.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 55.0.
# 		Time: 0.014989449991844594 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110010 [01001101].
# 		Maxcut = -53.87694035594075.
# 		Optimizer Time: 4.06213903427124 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.06213903427124 seconds.
#
#
# Test Case 22:
# --------------------------------------------------------
#
# [[4. 1. 1. 4. 3. 5. 5. 1.]
#  [1. 3. 2. 2. 3. 2. 1. 1.]
#  [1. 2. 3. 1. 3. 5. 2. 5.]
#  [4. 2. 1. 0. 5. 2. 4. 3.]
#  [3. 3. 3. 5. 1. 5. 3. 5.]
#  [5. 2. 5. 2. 5. 5. 2. 2.]
#  [5. 1. 2. 4. 3. 2. 0. 1.]
#  [1. 1. 5. 3. 5. 2. 1. 2.]]
#
# 	Brute Force
# 		Solution = 10111000 [01000111].
# 		Maxcut = 53.0.
# 		Time: 0.015395662048831582 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01000111 [10111000].
# 		Maxcut = -52.97456546712711.
# 		Optimizer Time: 4.021536350250244 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.021536350250244 seconds.
#
#
# Test Case 23:
# ----------------------------------------------------------
#
# [[5. 1. 4. 0. 4. 1. 5. 4.]
#  [1. 1. 3. 2. 5. 5. 3. 5.]
#  [4. 3. 0. 1. 1. 5. 4. 4.]
#  [0. 2. 1. 2. 2. 3. 5. 1.]
#  [4. 5. 1. 2. 3. 2. 5. 4.]
#  [1. 5. 5. 3. 2. 3. 4. 3.]
#  [5. 3. 4. 5. 5. 4. 1. 2.]
#  [4. 5. 4. 1. 4. 3. 2. 5.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 57.0.
# 		Time: 0.014793519978411496 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -54.98392926369654.
# 		Optimizer Time: 3.8403775691986084 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.8403775691986084 seconds.
#
#
# Test Case 24:
# ------------------------------------------------------------
#
# [[5. 5. 1. 3. 2. 3. 3. 3.]
#  [5. 0. 5. 1. 1. 1. 2. 4.]
#  [1. 5. 1. 3. 3. 5. 5. 5.]
#  [3. 1. 3. 3. 5. 4. 1. 3.]
#  [2. 1. 3. 5. 4. 0. 3. 5.]
#  [3. 1. 5. 4. 0. 1. 3. 5.]
#  [3. 2. 5. 1. 3. 3. 4. 1.]
#  [3. 4. 5. 3. 5. 5. 1. 4.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 59.0.
# 		Time: 0.015301088918931782 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001110 [10110001].
# 		Maxcut = -56.80478814683006.
# 		Optimizer Time: 4.133703947067261 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.133703947067261 seconds.
#
#
# Test Case 25:
# --------------------------------------------------------------
#
# [[4. 2. 2. 3. 5. 4. 3. 1.]
#  [2. 3. 2. 3. 5. 2. 3. 4.]
#  [2. 2. 2. 4. 1. 4. 3. 4.]
#  [3. 3. 4. 0. 2. 2. 2. 3.]
#  [5. 5. 1. 2. 5. 2. 1. 3.]
#  [4. 2. 4. 2. 2. 4. 2. 3.]
#  [3. 3. 3. 2. 1. 2. 0. 4.]
#  [1. 4. 4. 3. 3. 3. 4. 4.]]
#
# 	Brute Force
# 		Solution = 00011110 [11100001].
# 		Maxcut = 53.0.
# 		Time: 0.013785633025690913 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01101010 [10010101].
# 		Maxcut = -47.52218789552422.
# 		Optimizer Time: 4.179230451583862 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.179230451583862 seconds.
#
#
# Test Case 26:
# ----------------------------------------------------------------
#
# [[0. 4. 2. 4. 5. 4. 5. 3.]
#  [4. 5. 4. 5. 4. 3. 4. 2.]
#  [2. 4. 3. 5. 1. 4. 1. 0.]
#  [4. 5. 5. 2. 2. 3. 1. 1.]
#  [5. 4. 1. 2. 0. 5. 2. 4.]
#  [4. 3. 4. 3. 5. 5. 1. 4.]
#  [5. 4. 1. 1. 2. 1. 4. 5.]
#  [3. 2. 0. 1. 4. 4. 5. 4.]]
#
# 	Brute Force
# 		Solution = 00011110 [11100001].
# 		Maxcut = 59.0.
# 		Time: 0.015241522109135985 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100001 [01011110].
# 		Maxcut = -53.2413144807171.
# 		Optimizer Time: 4.13105583190918 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.13105583190918 seconds.
#
#
# Test Case 27:
# ------------------------------------------------------------------
#
# [[3. 5. 2. 3. 5. 5. 3. 4.]
#  [5. 3. 5. 3. 5. 1. 1. 2.]
#  [2. 5. 0. 3. 3. 2. 5. 2.]
#  [3. 3. 3. 5. 5. 3. 3. 4.]
#  [5. 5. 3. 5. 3. 3. 1. 3.]
#  [5. 1. 2. 3. 3. 1. 1. 3.]
#  [3. 1. 5. 3. 1. 1. 1. 1.]
#  [4. 2. 2. 4. 3. 3. 1. 2.]]
#
# 	Brute Force
# 		Solution = 10110000 [01001111].
# 		Maxcut = 57.0.
# 		Time: 0.015546970069408417 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110001 [01001110].
# 		Maxcut = -55.616360037705874.
# 		Optimizer Time: 3.8578011989593506 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.8578011989593506 seconds.
#
#
# Test Case 28:
# --------------------------------------------------------------------
#
# [[4. 4. 2. 5. 4. 2. 2. 3.]
#  [4. 5. 3. 2. 4. 4. 3. 1.]
#  [2. 3. 0. 3. 5. 4. 3. 5.]
#  [5. 2. 3. 3. 1. 4. 3. 4.]
#  [4. 4. 5. 1. 2. 3. 5. 5.]
#  [2. 4. 4. 4. 3. 4. 4. 5.]
#  [2. 3. 3. 3. 5. 4. 1. 3.]
#  [3. 1. 5. 4. 5. 5. 3. 5.]]
#
# 	Brute Force
# 		Solution = 10100110 [01011001].
# 		Maxcut = 62.0.
# 		Time: 0.015251514036208391 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100011 [01011100].
# 		Maxcut = -59.984343402727404.
# 		Optimizer Time: 4.186312198638916 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.186312198638916 seconds.
#
#
# Test Case 29:
# ----------------------------------------------------------------------
#
# [[0. 1. 3. 3. 1. 4. 5. 1.]
#  [1. 2. 2. 5. 4. 4. 2. 2.]
#  [3. 2. 1. 4. 5. 4. 3. 5.]
#  [3. 5. 4. 2. 5. 5. 3. 3.]
#  [1. 4. 5. 5. 0. 5. 1. 1.]
#  [4. 4. 4. 5. 5. 3. 3. 4.]
#  [5. 2. 3. 3. 1. 3. 2. 5.]
#  [1. 2. 5. 3. 1. 4. 5. 3.]]
#
# 	Brute Force
# 		Solution = 01100110 [10011001].
# 		Maxcut = 61.0.
# 		Time: 0.016752209048718214 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00110100 [11001011].
# 		Maxcut = -56.15095179728802.
# 		Optimizer Time: 4.009495973587036 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.009495973587036 seconds.
#
#
# Test Case 30:
# ------------------------------------------------------------------------
#
# [[1. 2. 2. 4. 2. 3. 1. 4.]
#  [2. 2. 5. 4. 3. 3. 2. 4.]
#  [2. 5. 1. 1. 2. 5. 5. 4.]
#  [4. 4. 1. 3. 2. 4. 1. 5.]
#  [2. 3. 2. 2. 5. 5. 2. 2.]
#  [3. 3. 5. 4. 5. 4. 4. 2.]
#  [1. 2. 5. 1. 2. 4. 4. 4.]
#  [4. 4. 4. 5. 2. 2. 4. 2.]]
#
# 	Brute Force
# 		Solution = 00111010 [11000101].
# 		Maxcut = 56.0.
# 		Time: 0.01687558996491134 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000110 [00111001].
# 		Maxcut = -55.85879798702932.
# 		Optimizer Time: 3.938059091567993 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.938059091567993 seconds.
#
#
# Test Case 31:
# --------------------------------------------------------------------------
#
# [[4. 1. 2. 5. 4. 3. 4. 3.]
#  [1. 0. 5. 1. 4. 4. 2. 1.]
#  [2. 5. 5. 4. 1. 5. 5. 4.]
#  [5. 1. 4. 5. 2. 3. 3. 4.]
#  [4. 4. 1. 2. 2. 5. 0. 1.]
#  [3. 4. 5. 3. 5. 1. 2. 1.]
#  [4. 2. 5. 3. 0. 2. 0. 1.]
#  [3. 1. 4. 4. 1. 1. 1. 2.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 52.0.
# 		Time: 0.016831677057780325 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11010100 [00101011].
# 		Maxcut = -50.92519618417785.
# 		Optimizer Time: 4.118171691894531 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.118171691894531 seconds.
#
#
# Test Case 32:
# ----------------------------------------------------------------------------
#
# [[0. 5. 4. 3. 0. 2. 1. 4.]
#  [5. 4. 3. 5. 5. 4. 2. 2.]
#  [4. 3. 5. 1. 1. 2. 2. 3.]
#  [3. 5. 1. 3. 4. 0. 5. 1.]
#  [0. 5. 1. 4. 4. 1. 4. 4.]
#  [2. 4. 2. 0. 1. 2. 3. 1.]
#  [1. 2. 2. 5. 4. 3. 2. 3.]
#  [4. 2. 3. 1. 4. 1. 3. 4.]]
#
# 	Brute Force
# 		Solution = 10011100 [01100011].
# 		Maxcut = 50.0.
# 		Time: 0.015296995989046991 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101010 [01010101].
# 		Maxcut = -49.96459582612553.
# 		Optimizer Time: 4.14074182510376 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.14074182510376 seconds.
#
#
# Test Case 33:
# ------------------------------------------------------------------------------
#
# [[1. 3. 5. 0. 4. 2. 5. 4.]
#  [3. 5. 3. 4. 3. 5. 3. 1.]
#  [5. 3. 1. 1. 5. 4. 5. 5.]
#  [0. 4. 1. 0. 2. 4. 4. 1.]
#  [4. 3. 5. 2. 1. 4. 3. 4.]
#  [2. 5. 4. 4. 4. 1. 5. 3.]
#  [5. 3. 5. 4. 3. 5. 4. 5.]
#  [4. 1. 5. 1. 4. 3. 5. 3.]]
#
# 	Brute Force
# 		Solution = 10110100 [01001011].
# 		Maxcut = 62.0.
# 		Time: 0.01542110403534025 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000101 [00111010].
# 		Maxcut = -58.91696651304571.
# 		Optimizer Time: 4.116353511810303 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.116353511810303 seconds.
#
#
# Test Case 34:
# --------------------------------------------------------------------------------
#
# [[3. 0. 4. 2. 4. 3. 3. 2.]
#  [0. 5. 5. 4. 5. 3. 2. 3.]
#  [4. 5. 1. 2. 4. 4. 5. 2.]
#  [2. 4. 2. 4. 3. 5. 4. 3.]
#  [4. 5. 4. 3. 1. 5. 0. 3.]
#  [3. 3. 4. 5. 5. 1. 1. 2.]
#  [3. 2. 5. 4. 0. 1. 3. 3.]
#  [2. 3. 2. 3. 3. 2. 3. 5.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 57.0.
# 		Time: 0.017625835025683045 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110001 [01001110].
# 		Maxcut = -53.946892188748265.
# 		Optimizer Time: 3.849824905395508 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.849824905395508 seconds.
#
#
# Test Case 35:
# ----------------------------------------------------------------------------------
#
# [[1. 0. 1. 4. 5. 5. 5. 4.]
#  [0. 3. 2. 3. 1. 4. 5. 3.]
#  [1. 2. 4. 4. 3. 4. 3. 1.]
#  [4. 3. 4. 5. 1. 3. 2. 1.]
#  [5. 1. 3. 1. 2. 2. 4. 2.]
#  [5. 4. 4. 3. 2. 3. 2. 3.]
#  [5. 5. 3. 2. 4. 2. 3. 3.]
#  [4. 3. 1. 1. 2. 3. 3. 0.]]
#
# 	Brute Force
# 		Solution = 00011110 [11100001].
# 		Maxcut = 55.0.
# 		Time: 0.01650103006977588 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11100001 [00011110].
# 		Maxcut = -54.97223767906347.
# 		Optimizer Time: 4.28374981880188 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.28374981880188 seconds.
#
#
# Test Case 36:
# ------------------------------------------------------------------------------------
#
# [[2. 2. 0. 3. 4. 3. 2. 4.]
#  [2. 5. 5. 5. 3. 4. 2. 1.]
#  [0. 5. 0. 1. 4. 2. 4. 5.]
#  [3. 5. 1. 5. 2. 4. 5. 4.]
#  [4. 3. 4. 2. 5. 3. 4. 1.]
#  [3. 4. 2. 4. 3. 1. 1. 5.]
#  [2. 2. 4. 5. 4. 1. 5. 1.]
#  [4. 1. 5. 4. 1. 5. 1. 3.]]
#
# 	Brute Force
# 		Solution = 10110100 [01001011].
# 		Maxcut = 59.0.
# 		Time: 0.016986047965474427 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001011 [10110100].
# 		Maxcut = -58.872704361170605.
# 		Optimizer Time: 4.097042560577393 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.097042560577393 seconds.
#
#
# Test Case 37:
# --------------------------------------------------------------------------------------
#
# [[1. 2. 1. 5. 3. 3. 4. 3.]
#  [2. 3. 0. 1. 1. 4. 1. 0.]
#  [1. 0. 5. 5. 5. 3. 1. 4.]
#  [5. 1. 5. 1. 1. 1. 4. 2.]
#  [3. 1. 5. 1. 5. 3. 4. 3.]
#  [3. 4. 3. 1. 3. 2. 4. 1.]
#  [4. 1. 1. 4. 4. 4. 1. 4.]
#  [3. 0. 4. 2. 3. 1. 4. 4.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 53.0.
# 		Time: 0.01704342500306666 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00011101 [11100010].
# 		Maxcut = -52.970805713040505.
# 		Optimizer Time: 4.080755233764648 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.080755233764648 seconds.
#
#
# Test Case 38:
# ----------------------------------------------------------------------------------------
#
# [[0. 2. 4. 2. 1. 1. 5. 3.]
#  [2. 5. 2. 0. 3. 3. 5. 3.]
#  [4. 2. 1. 4. 5. 0. 3. 5.]
#  [2. 0. 4. 0. 4. 1. 2. 3.]
#  [1. 3. 5. 4. 2. 0. 3. 3.]
#  [1. 3. 0. 1. 0. 3. 5. 3.]
#  [5. 5. 3. 2. 3. 5. 1. 3.]
#  [3. 3. 5. 3. 3. 3. 3. 4.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 51.0.
# 		Time: 0.021805481985211372 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01110010 [10001101].
# 		Maxcut = -50.87906550632054.
# 		Optimizer Time: 3.7731869220733643 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.7731869220733643 seconds.
#
#
# Test Case 39:
# ------------------------------------------------------------------------------------------
#
# [[4. 1. 2. 5. 2. 2. 4. 4.]
#  [1. 1. 4. 3. 3. 1. 4. 3.]
#  [2. 4. 2. 2. 4. 4. 3. 4.]
#  [5. 3. 2. 5. 1. 4. 5. 3.]
#  [2. 3. 4. 1. 4. 5. 3. 5.]
#  [2. 1. 4. 4. 5. 4. 2. 5.]
#  [4. 4. 3. 5. 3. 2. 5. 5.]
#  [4. 3. 4. 3. 5. 5. 5. 1.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 60.0.
# 		Time: 0.015673103043809533 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001100 [00110011].
# 		Maxcut = -56.87125916058514.
# 		Optimizer Time: 4.0979602336883545 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.0979602336883545 seconds.
#
#
# Test Case 40:
# --------------------------------------------------------------------------------------------
#
# [[2. 4. 3. 3. 3. 0. 2. 5.]
#  [4. 0. 1. 4. 2. 1. 2. 1.]
#  [3. 1. 2. 3. 2. 4. 2. 5.]
#  [3. 4. 3. 4. 2. 1. 0. 4.]
#  [3. 2. 2. 2. 4. 2. 2. 1.]
#  [0. 1. 4. 1. 2. 2. 1. 2.]
#  [2. 2. 2. 0. 2. 1. 0. 2.]
#  [5. 1. 5. 4. 1. 2. 2. 2.]]
#
# 	Brute Force
# 		Solution = 10010110 [01101001].
# 		Maxcut = 45.0.
# 		Time: 0.01564461993984878 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010110 [01101001].
# 		Maxcut = -44.95433058833623.
# 		Optimizer Time: 4.042223930358887 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.042223930358887 seconds.
#
#
# Test Case 41:
# ----------------------------------------------------------------------------------------------
#
# [[4. 0. 2. 2. 5. 3. 4. 1.]
#  [0. 0. 3. 5. 5. 5. 5. 4.]
#  [2. 3. 3. 1. 5. 2. 4. 3.]
#  [2. 5. 1. 1. 5. 1. 4. 2.]
#  [5. 5. 5. 5. 2. 5. 4. 1.]
#  [3. 5. 2. 1. 5. 5. 5. 2.]
#  [4. 5. 4. 4. 4. 5. 4. 2.]
#  [1. 4. 3. 2. 1. 2. 2. 4.]]
#
# 	Brute Force
# 		Solution = 11110100 [00001011].
# 		Maxcut = 59.0.
# 		Time: 0.018891533953137696 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001010 [00110101].
# 		Maxcut = -56.318753174271016.
# 		Optimizer Time: 4.123092412948608 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.123092412948608 seconds.
#
#
# Test Case 42:
# ------------------------------------------------------------------------------------------------
#
# [[0. 1. 2. 4. 5. 5. 2. 4.]
#  [1. 1. 1. 4. 2. 3. 4. 1.]
#  [2. 1. 3. 4. 3. 3. 4. 2.]
#  [4. 4. 4. 4. 4. 1. 4. 4.]
#  [5. 2. 3. 4. 1. 4. 3. 4.]
#  [5. 3. 3. 1. 4. 3. 5. 5.]
#  [2. 4. 4. 4. 3. 5. 3. 2.]
#  [4. 1. 2. 4. 4. 5. 2. 5.]]
#
# 	Brute Force
# 		Solution = 00011100 [11100011].
# 		Maxcut = 58.0.
# 		Time: 0.010195689974352717 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00011100 [11100011].
# 		Maxcut = -56.04909929987226.
# 		Optimizer Time: 4.000463485717773 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.000463485717773 seconds.
#
#
# Test Case 43:
# --------------------------------------------------------------------------------------------------
#
# [[2. 5. 1. 1. 4. 2. 2. 1.]
#  [5. 4. 3. 4. 1. 1. 3. 3.]
#  [1. 3. 2. 5. 3. 1. 1. 1.]
#  [1. 4. 5. 5. 4. 5. 1. 5.]
#  [4. 1. 3. 4. 1. 4. 2. 3.]
#  [2. 1. 1. 5. 4. 4. 4. 4.]
#  [2. 3. 1. 1. 2. 4. 1. 3.]
#  [1. 3. 1. 5. 3. 4. 3. 0.]]
#
# 	Brute Force
# 		Solution = 01011010 [10100101].
# 		Maxcut = 52.0.
# 		Time: 0.02244289591908455 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01011010 [10100101].
# 		Maxcut = -51.90141530936776.
# 		Optimizer Time: 4.095730304718018 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.095730304718018 seconds.
#
#
# Test Case 44:
# ----------------------------------------------------------------------------------------------------
#
# [[1. 5. 2. 3. 2. 2. 3. 5.]
#  [5. 3. 2. 5. 4. 4. 5. 5.]
#  [2. 2. 2. 1. 1. 2. 1. 4.]
#  [3. 5. 1. 0. 4. 2. 5. 4.]
#  [2. 4. 1. 4. 2. 2. 2. 1.]
#  [2. 4. 2. 2. 2. 3. 4. 3.]
#  [3. 5. 1. 5. 2. 4. 4. 4.]
#  [5. 5. 4. 4. 1. 3. 4. 0.]]
#
# 	Brute Force
# 		Solution = 10110100 [01001011].
# 		Maxcut = 54.0.
# 		Time: 0.016704094945453107 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01101010 [10010101].
# 		Maxcut = -52.99897013058067.
# 		Optimizer Time: 4.270700931549072 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.270700931549072 seconds.
#
#
# Test Case 45:
# ------------------------------------------------------------------------------------------------------
#
# [[1. 4. 4. 1. 5. 2. 2. 2.]
#  [4. 4. 0. 1. 4. 1. 4. 3.]
#  [4. 0. 0. 4. 1. 5. 0. 5.]
#  [1. 1. 4. 0. 2. 0. 3. 4.]
#  [5. 4. 1. 2. 2. 2. 5. 2.]
#  [2. 1. 5. 0. 2. 4. 1. 3.]
#  [2. 4. 0. 3. 5. 1. 1. 4.]
#  [2. 3. 5. 4. 2. 3. 4. 1.]]
#
# 	Brute Force
# 		Solution = 10010110 [01101001].
# 		Maxcut = 50.0.
# 		Time: 0.016808256041258574 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -47.11298353427567.
# 		Optimizer Time: 4.715771675109863 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.715771675109863 seconds.
#
#
# Test Case 46:
# --------------------------------------------------------------------------------------------------------
#
# [[5. 3. 4. 2. 3. 4. 0. 5.]
#  [3. 3. 3. 1. 5. 1. 1. 3.]
#  [4. 3. 4. 4. 5. 4. 3. 3.]
#  [2. 1. 4. 3. 2. 4. 5. 2.]
#  [3. 5. 5. 2. 3. 3. 3. 0.]
#  [4. 1. 4. 4. 3. 0. 2. 5.]
#  [0. 1. 3. 5. 3. 2. 0. 5.]
#  [5. 3. 3. 2. 0. 5. 5. 1.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 58.0.
# 		Time: 0.010035106912255287 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10011001 [01100110].
# 		Maxcut = -56.840131696817664.
# 		Optimizer Time: 3.881284713745117 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.881284713745117 seconds.
#
#
# Test Case 47:
# ----------------------------------------------------------------------------------------------------------
#
# [[3. 1. 2. 5. 3. 4. 3. 4.]
#  [1. 1. 2. 5. 3. 3. 3. 1.]
#  [2. 2. 4. 5. 5. 1. 3. 5.]
#  [5. 5. 5. 2. 4. 2. 1. 3.]
#  [3. 3. 5. 4. 5. 3. 0. 1.]
#  [4. 3. 1. 2. 3. 5. 1. 4.]
#  [3. 3. 3. 1. 0. 1. 2. 4.]
#  [4. 1. 5. 3. 1. 4. 4. 1.]]
#
# 	Brute Force
# 		Solution = 11100100 [00011011].
# 		Maxcut = 55.0.
# 		Time: 0.015267498092725873 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11100001 [00011110].
# 		Maxcut = -54.90737117817673.
# 		Optimizer Time: 4.166574716567993 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.166574716567993 seconds.
#
#
# Test Case 48:
# ------------------------------------------------------------------------------------------------------------
#
# [[5. 3. 3. 2. 4. 2. 3. 0.]
#  [3. 1. 3. 1. 3. 3. 2. 4.]
#  [3. 3. 4. 4. 5. 2. 3. 2.]
#  [2. 1. 4. 0. 2. 5. 3. 3.]
#  [4. 3. 5. 2. 5. 0. 4. 2.]
#  [2. 3. 2. 5. 0. 3. 0. 3.]
#  [3. 2. 3. 3. 4. 0. 1. 1.]
#  [0. 4. 2. 3. 2. 3. 1. 3.]]
#
# 	Brute Force
# 		Solution = 01011000 [10100111].
# 		Maxcut = 47.0.
# 		Time: 0.017408092971891165 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100111 [01011000].
# 		Maxcut = -46.44220485668568.
# 		Optimizer Time: 4.0898942947387695 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.0898942947387695 seconds.
#
#
# Test Case 49:
# --------------------------------------------------------------------------------------------------------------
#
# [[0. 2. 1. 2. 5. 5. 3. 3.]
#  [2. 2. 1. 2. 5. 5. 4. 5.]
#  [1. 1. 0. 3. 3. 2. 4. 3.]
#  [2. 2. 3. 0. 3. 3. 1. 3.]
#  [5. 5. 3. 3. 5. 2. 1. 1.]
#  [5. 5. 2. 3. 2. 0. 4. 4.]
#  [3. 4. 4. 1. 1. 4. 0. 1.]
#  [3. 5. 3. 3. 1. 4. 1. 1.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 57.0.
# 		Time: 0.01736266096122563 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00011011 [11100100].
# 		Maxcut = -54.88035534502031.
# 		Optimizer Time: 3.897390127182007 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.897390127182007 seconds.
#
#
# Test Case 50:
# ----------------------------------------------------------------------------------------------------------------
#
# [[5. 1. 1. 4. 4. 5. 2. 2.]
#  [1. 3. 2. 4. 2. 2. 3. 5.]
#  [1. 2. 4. 1. 4. 4. 4. 4.]
#  [4. 4. 1. 4. 4. 3. 5. 1.]
#  [4. 2. 4. 4. 2. 4. 5. 1.]
#  [5. 2. 4. 3. 4. 5. 3. 4.]
#  [2. 3. 4. 5. 5. 3. 2. 4.]
#  [2. 5. 4. 1. 1. 4. 4. 1.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 58.0.
# 		Time: 0.017501114052720368 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00111001 [11000110].
# 		Maxcut = -56.74055949901596.
# 		Optimizer Time: 4.094142436981201 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.094142436981201 seconds.
#
#
# Test Case 51:
# ------------------------------------------------------------------------------------------------------------------
#
# [[4. 2. 0. 3. 2. 5. 3. 2.]
#  [2. 4. 3. 4. 2. 1. 2. 3.]
#  [0. 3. 2. 4. 3. 4. 4. 3.]
#  [3. 4. 4. 1. 3. 3. 0. 5.]
#  [2. 2. 3. 3. 2. 1. 4. 3.]
#  [5. 1. 4. 3. 1. 2. 1. 4.]
#  [3. 2. 4. 0. 4. 1. 5. 2.]
#  [2. 3. 3. 5. 3. 4. 2. 0.]]
#
# 	Brute Force
# 		Solution = 01010110 [10101001].
# 		Maxcut = 52.0.
# 		Time: 0.017589512979611754 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010110 [10101001].
# 		Maxcut = -51.91203729247271.
# 		Optimizer Time: 4.0816991329193115 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.0816991329193115 seconds.
#
#
# Test Case 52:
# --------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 2. 2. 4. 3. 4. 3.]
#  [5. 0. 4. 0. 5. 2. 4. 3.]
#  [2. 4. 0. 2. 3. 4. 2. 1.]
#  [2. 0. 2. 3. 3. 2. 2. 5.]
#  [4. 5. 3. 3. 0. 5. 4. 5.]
#  [3. 2. 4. 2. 5. 4. 5. 3.]
#  [4. 4. 2. 2. 4. 5. 4. 2.]
#  [3. 3. 1. 5. 5. 3. 2. 4.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 58.0.
# 		Time: 0.016415491001680493 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101001 [01010110].
# 		Maxcut = -55.76930102873696.
# 		Optimizer Time: 4.074018955230713 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.074018955230713 seconds.
#
#
# Test Case 53:
# ----------------------------------------------------------------------------------------------------------------------
#
# [[3. 1. 3. 1. 4. 2. 1. 1.]
#  [1. 5. 4. 3. 1. 4. 4. 3.]
#  [3. 4. 3. 4. 3. 5. 2. 5.]
#  [1. 3. 4. 1. 2. 5. 2. 4.]
#  [4. 1. 3. 2. 4. 5. 3. 4.]
#  [2. 4. 5. 5. 5. 2. 4. 1.]
#  [1. 4. 2. 2. 3. 4. 3. 3.]
#  [1. 3. 5. 4. 4. 1. 3. 3.]]
#
# 	Brute Force
# 		Solution = 00111010 [11000101].
# 		Maxcut = 56.0.
# 		Time: 0.01705632300581783 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000101 [00111010].
# 		Maxcut = -55.93477905803829.
# 		Optimizer Time: 3.8932015895843506 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.8932015895843506 seconds.
#
#
# Test Case 54:
# ------------------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 4. 4. 3. 3. 2. 5.]
#  [2. 4. 4. 4. 3. 4. 1. 4.]
#  [4. 4. 0. 3. 4. 4. 3. 1.]
#  [4. 4. 3. 3. 4. 1. 2. 3.]
#  [3. 3. 4. 4. 0. 0. 2. 4.]
#  [3. 4. 4. 1. 0. 5. 3. 1.]
#  [2. 1. 3. 2. 2. 3. 5. 5.]
#  [5. 4. 1. 3. 4. 1. 5. 5.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 57.0.
# 		Time: 0.0338462230283767 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11010010 [00101101].
# 		Maxcut = -53.94132693662996.
# 		Optimizer Time: 4.122972011566162 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.122972011566162 seconds.
#
#
# Test Case 55:
# --------------------------------------------------------------------------------------------------------------------------
#
# [[3. 5. 3. 1. 3. 1. 2. 4.]
#  [5. 0. 5. 3. 3. 3. 5. 5.]
#  [3. 5. 3. 2. 4. 5. 2. 4.]
#  [1. 3. 2. 3. 2. 5. 3. 1.]
#  [3. 3. 4. 2. 1. 1. 1. 2.]
#  [1. 3. 5. 5. 1. 3. 2. 1.]
#  [2. 5. 2. 3. 1. 2. 0. 5.]
#  [4. 5. 4. 1. 2. 1. 5. 1.]]
#
# 	Brute Force
# 		Solution = 10110010 [01001101].
# 		Maxcut = 55.0.
# 		Time: 0.01718536193948239 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110010 [01001101].
# 		Maxcut = -54.91307238852275.
# 		Optimizer Time: 4.154977560043335 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.154977560043335 seconds.
#
#
# Test Case 56:
# ----------------------------------------------------------------------------------------------------------------------------
#
# [[1. 1. 1. 1. 4. 2. 3. 5.]
#  [1. 1. 4. 2. 3. 2. 2. 1.]
#  [1. 4. 0. 3. 2. 4. 5. 4.]
#  [1. 2. 3. 3. 5. 3. 1. 3.]
#  [4. 3. 2. 5. 1. 4. 2. 1.]
#  [2. 2. 4. 3. 4. 2. 4. 4.]
#  [3. 2. 5. 1. 2. 4. 2. 5.]
#  [5. 1. 4. 3. 1. 4. 5. 4.]]
#
# 	Brute Force
# 		Solution = 10110100 [01001011].
# 		Maxcut = 53.0.
# 		Time: 0.01638394605834037 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001011 [10110100].
# 		Maxcut = -52.76511881137177.
# 		Optimizer Time: 4.058211088180542 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.058211088180542 seconds.
#
#
# Test Case 57:
# ------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 5. 4. 4. 2. 3. 2. 0.]
#  [5. 4. 4. 1. 2. 2. 3. 4.]
#  [4. 4. 0. 3. 1. 5. 2. 4.]
#  [4. 1. 3. 0. 1. 3. 3. 1.]
#  [2. 2. 1. 1. 2. 0. 2. 3.]
#  [3. 2. 5. 3. 0. 0. 2. 2.]
#  [2. 3. 2. 3. 2. 2. 4. 4.]
#  [0. 4. 4. 1. 3. 2. 4. 5.]]
#
# 	Brute Force
# 		Solution = 01111000 [10000111].
# 		Maxcut = 47.0.
# 		Time: 0.016260589007288218 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101010 [01010101].
# 		Maxcut = -45.8538938530764.
# 		Optimizer Time: 3.889671802520752 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.889671802520752 seconds.
#
#
# Test Case 58:
# --------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 3. 4. 4. 5. 2. 0. 1.]
#  [3. 1. 4. 2. 3. 1. 4. 5.]
#  [4. 4. 3. 1. 4. 4. 0. 1.]
#  [4. 2. 1. 4. 5. 2. 1. 5.]
#  [5. 3. 4. 5. 5. 2. 5. 3.]
#  [2. 1. 4. 2. 2. 3. 3. 5.]
#  [0. 4. 0. 1. 5. 3. 0. 2.]
#  [1. 5. 1. 5. 3. 5. 2. 3.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 58.0.
# 		Time: 0.01586995297111571 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001100 [10110011].
# 		Maxcut = -56.01027145958899.
# 		Optimizer Time: 4.157992839813232 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.157992839813232 seconds.
#
#
# Test Case 59:
# ----------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 3. 2. 1. 2. 2. 5. 2.]
#  [3. 4. 1. 1. 4. 5. 1. 4.]
#  [2. 1. 4. 1. 2. 4. 2. 2.]
#  [1. 1. 1. 2. 5. 1. 5. 2.]
#  [2. 4. 2. 5. 0. 5. 2. 3.]
#  [2. 5. 4. 1. 5. 5. 4. 3.]
#  [5. 1. 2. 5. 2. 4. 3. 2.]
#  [2. 4. 2. 2. 3. 3. 2. 5.]]
#
# 	Brute Force
# 		Solution = 01101010 [10010101].
# 		Maxcut = 53.0.
# 		Time: 0.044857142958790064 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01101010 [10010101].
# 		Maxcut = -52.94916354315559.
# 		Optimizer Time: 4.032047510147095 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.032047510147095 seconds.
#
#
# Test Case 60:
# ------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 5. 1. 1. 1. 5. 3. 4.]
#  [5. 1. 4. 4. 2. 5. 1. 2.]
#  [1. 4. 1. 4. 2. 3. 4. 4.]
#  [1. 4. 4. 2. 3. 1. 1. 5.]
#  [1. 2. 2. 3. 4. 2. 5. 4.]
#  [5. 5. 3. 1. 2. 2. 4. 4.]
#  [3. 1. 4. 1. 5. 4. 0. 5.]
#  [4. 2. 4. 5. 4. 4. 5. 2.]]
#
# 	Brute Force
# 		Solution = 10111100 [01000011].
# 		Maxcut = 58.0.
# 		Time: 0.015423557022586465 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110010 [01001101].
# 		Maxcut = -55.824919411658406.
# 		Optimizer Time: 3.95837664604187 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.95837664604187 seconds.
#
#
# Test Case 61:
# --------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 3. 5. 1. 3. 2. 3. 1.]
#  [3. 3. 5. 4. 1. 3. 5. 5.]
#  [5. 5. 0. 1. 4. 3. 4. 4.]
#  [1. 4. 1. 4. 4. 3. 4. 3.]
#  [3. 1. 4. 4. 1. 5. 3. 3.]
#  [2. 3. 3. 3. 5. 2. 2. 5.]
#  [3. 5. 4. 4. 3. 2. 0. 2.]
#  [1. 5. 4. 3. 3. 5. 2. 4.]]
#
# 	Brute Force
# 		Solution = 00110110 [11001001].
# 		Maxcut = 58.0.
# 		Time: 0.016528313979506493 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110100 [01001011].
# 		Maxcut = -55.82936028766602.
# 		Optimizer Time: 3.814523220062256 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.814523220062256 seconds.
#
#
# Test Case 62:
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 3. 2. 1. 2. 3. 4.]
#  [5. 1. 4. 1. 5. 5. 3. 1.]
#  [3. 4. 0. 4. 4. 5. 3. 3.]
#  [2. 1. 4. 1. 5. 5. 4. 5.]
#  [1. 5. 4. 5. 5. 3. 3. 2.]
#  [2. 5. 5. 5. 3. 2. 2. 1.]
#  [3. 3. 3. 4. 3. 2. 0. 4.]
#  [4. 1. 3. 5. 2. 1. 4. 5.]]
#
# 	Brute Force
# 		Solution = 01110010 [10001101].
# 		Maxcut = 60.0.
# 		Time: 0.016775664989836514 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01110010 [10001101].
# 		Maxcut = -59.97883265379573.
# 		Optimizer Time: 4.061825752258301 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.061825752258301 seconds.
#
#
# Test Case 63:
# ------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 4. 1. 4. 2. 4. 4. 2.]
#  [4. 5. 2. 5. 4. 5. 3. 1.]
#  [1. 2. 2. 2. 4. 4. 2. 3.]
#  [4. 5. 2. 1. 2. 1. 2. 4.]
#  [2. 4. 4. 2. 3. 3. 2. 5.]
#  [4. 5. 4. 1. 3. 0. 1. 4.]
#  [4. 3. 2. 2. 2. 1. 4. 4.]
#  [2. 1. 3. 4. 5. 4. 4. 2.]]
#
# 	Brute Force
# 		Solution = 00011110 [11100001].
# 		Maxcut = 60.0.
# 		Time: 0.04518421401735395 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01000111 [10111000].
# 		Maxcut = -50.73547176929277.
# 		Optimizer Time: 4.437972784042358 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.437972784042358 seconds.
#
#
# Test Case 64:
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 3. 2. 4. 1. 1. 5.]
#  [2. 5. 5. 1. 5. 5. 5. 3.]
#  [3. 5. 4. 5. 5. 3. 4. 5.]
#  [2. 1. 5. 0. 3. 1. 1. 4.]
#  [4. 5. 5. 3. 3. 3. 1. 3.]
#  [1. 5. 3. 1. 3. 1. 2. 2.]
#  [1. 5. 4. 1. 1. 2. 2. 5.]
#  [5. 3. 5. 4. 3. 2. 5. 2.]]
#
# 	Brute Force
# 		Solution = 10011110 [01100001].
# 		Maxcut = 57.0.
# 		Time: 0.015159985050559044 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00101101 [11010010].
# 		Maxcut = -55.242533728665755.
# 		Optimizer Time: 3.934626579284668 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.934626579284668 seconds.
#
#
# Test Case 65:
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 4. 1. 0. 2. 2. 3. 2.]
#  [4. 2. 2. 5. 0. 1. 4. 5.]
#  [1. 2. 5. 3. 3. 5. 1. 4.]
#  [0. 5. 3. 1. 4. 3. 4. 4.]
#  [2. 0. 3. 4. 4. 3. 1. 2.]
#  [2. 1. 5. 3. 3. 4. 3. 2.]
#  [3. 4. 1. 4. 1. 3. 4. 4.]
#  [2. 5. 4. 4. 2. 2. 4. 5.]]
#
# 	Brute Force
# 		Solution = 01101010 [10010101].
# 		Maxcut = 53.0.
# 		Time: 0.02733896696008742 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01101010 [10010101].
# 		Maxcut = -52.89506538536595.
# 		Optimizer Time: 3.9537267684936523 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.9537267684936523 seconds.
#
#
# Test Case 66:
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 3. 2. 5. 1. 1. 5. 5.]
#  [3. 4. 5. 4. 3. 2. 5. 5.]
#  [2. 5. 5. 2. 1. 3. 3. 3.]
#  [5. 4. 2. 3. 3. 5. 4. 2.]
#  [1. 3. 1. 3. 3. 3. 5. 3.]
#  [1. 2. 3. 5. 3. 0. 1. 2.]
#  [5. 5. 3. 4. 5. 1. 2. 1.]
#  [5. 5. 3. 2. 3. 2. 1. 2.]]
#
# 	Brute Force
# 		Solution = 11001100 [00110011].
# 		Maxcut = 59.0.
# 		Time: 0.02075781300663948 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001100 [00110011].
# 		Maxcut = -58.139457073761015.
# 		Optimizer Time: 4.242480278015137 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.242480278015137 seconds.
#
#
# Test Case 67:
# --------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 5. 5. 3. 1. 1. 3. 3.]
#  [5. 2. 4. 4. 3. 4. 3. 5.]
#  [5. 4. 0. 4. 3. 2. 1. 3.]
#  [3. 4. 4. 3. 5. 2. 2. 1.]
#  [1. 3. 3. 5. 1. 1. 1. 1.]
#  [1. 4. 2. 2. 1. 4. 0. 2.]
#  [3. 3. 1. 2. 1. 0. 3. 3.]
#  [3. 5. 3. 1. 1. 2. 3. 5.]]
#
# 	Brute Force
# 		Solution = 01110010 [10001101].
# 		Maxcut = 48.0.
# 		Time: 0.017181267961859703 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010001 [10101110].
# 		Maxcut = -46.655698660468786.
# 		Optimizer Time: 4.208740711212158 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.208740711212158 seconds.
#
#
# Test Case 68:
# ----------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 5. 4. 4. 3. 5. 1.]
#  [2. 0. 2. 2. 3. 1. 5. 5.]
#  [5. 2. 1. 4. 5. 5. 3. 2.]
#  [4. 2. 4. 3. 4. 1. 1. 5.]
#  [4. 3. 5. 4. 3. 2. 3. 4.]
#  [3. 1. 5. 1. 2. 2. 1. 1.]
#  [5. 5. 3. 1. 3. 1. 1. 4.]
#  [1. 5. 2. 5. 4. 1. 4. 1.]]
#
# 	Brute Force
# 		Solution = 00011110 [11100001].
# 		Maxcut = 58.0.
# 		Time: 0.017369539942592382 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010110 [10101001].
# 		Maxcut = -53.936757051087156.
# 		Optimizer Time: 3.952730655670166 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.952730655670166 seconds.
#
#
# Test Case 69:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 1. 4. 5. 2. 2. 2.]
#  [5. 0. 2. 4. 3. 1. 3. 4.]
#  [1. 2. 1. 4. 1. 3. 1. 1.]
#  [4. 4. 4. 1. 1. 1. 2. 5.]
#  [5. 3. 1. 1. 5. 3. 5. 3.]
#  [2. 1. 3. 1. 3. 2. 2. 5.]
#  [2. 3. 1. 2. 5. 2. 2. 2.]
#  [2. 4. 1. 5. 3. 5. 2. 0.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 55.0.
# 		Time: 0.01844753697514534 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010110 [10101001].
# 		Maxcut = -50.744783272706556.
# 		Optimizer Time: 3.954794406890869 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.954794406890869 seconds.
#
#
# Test Case 70:
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 3. 1. 2. 1. 2. 4. 1.]
#  [3. 5. 5. 2. 5. 3. 5. 4.]
#  [1. 5. 0. 2. 3. 1. 1. 5.]
#  [2. 2. 2. 2. 2. 5. 3. 1.]
#  [1. 5. 3. 2. 1. 2. 1. 1.]
#  [2. 3. 1. 5. 2. 0. 2. 5.]
#  [4. 5. 1. 3. 1. 2. 3. 1.]
#  [1. 4. 5. 1. 1. 5. 1. 4.]]
#
# 	Brute Force
# 		Solution = 00101110 [11010001].
# 		Maxcut = 50.0.
# 		Time: 0.017233620048500597 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101110 [01010001].
# 		Maxcut = -47.871327451011446.
# 		Optimizer Time: 4.242791414260864 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.242791414260864 seconds.
#
#
# Test Case 71:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 4. 3. 4. 5. 1. 4. 2.]
#  [4. 3. 5. 2. 2. 5. 4. 2.]
#  [3. 5. 1. 3. 1. 5. 5. 4.]
#  [4. 2. 3. 4. 3. 4. 5. 1.]
#  [5. 2. 1. 3. 1. 1. 5. 3.]
#  [1. 5. 5. 4. 1. 1. 5. 0.]
#  [4. 4. 5. 5. 5. 5. 5. 4.]
#  [2. 2. 4. 1. 3. 0. 4. 0.]]
#
# 	Brute Force
# 		Solution = 01111000 [10000111].
# 		Maxcut = 60.0.
# 		Time: 0.01546981104183942 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100010 [01011101].
# 		Maxcut = -56.73019903154224.
# 		Optimizer Time: 3.9106266498565674 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.9106266498565674 seconds.
#
#
# Test Case 72:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 2. 1. 4. 2. 2. 2. 1.]
#  [2. 2. 1. 4. 5. 4. 2. 2.]
#  [1. 1. 5. 3. 1. 4. 1. 1.]
#  [4. 4. 3. 4. 2. 3. 4. 3.]
#  [2. 5. 1. 2. 5. 0. 1. 1.]
#  [2. 4. 4. 3. 0. 3. 4. 5.]
#  [2. 2. 1. 4. 1. 4. 4. 0.]
#  [1. 2. 1. 3. 1. 5. 0. 2.]]
#
# 	Brute Force
# 		Solution = 00011100 [11100011].
# 		Maxcut = 47.0.
# 		Time: 0.044162972015328705 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100011 [10011100].
# 		Maxcut = -44.96399429233385.
# 		Optimizer Time: 4.006512403488159 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.006512403488159 seconds.
#
#
# Test Case 73:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 1. 3. 4. 5. 3. 1. 4.]
#  [1. 0. 4. 3. 5. 5. 4. 5.]
#  [3. 4. 2. 2. 4. 2. 3. 0.]
#  [4. 3. 2. 4. 3. 3. 4. 5.]
#  [5. 5. 4. 3. 1. 3. 3. 5.]
#  [3. 5. 2. 3. 3. 3. 2. 2.]
#  [1. 4. 3. 4. 3. 2. 3. 2.]
#  [4. 5. 0. 5. 5. 2. 2. 4.]]
#
# 	Brute Force
# 		Solution = 11011000 [00100111].
# 		Maxcut = 58.0.
# 		Time: 0.01598966692108661 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100111 [01011000].
# 		Maxcut = -56.858308997625365.
# 		Optimizer Time: 4.161867141723633 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.161867141723633 seconds.
#
#
# Test Case 74:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 2. 5. 2. 4. 3. 1. 5.]
#  [2. 2. 5. 3. 4. 5. 2. 2.]
#  [5. 5. 5. 5. 2. 1. 2. 4.]
#  [2. 3. 5. 4. 1. 2. 2. 5.]
#  [4. 4. 2. 1. 2. 2. 4. 5.]
#  [3. 5. 1. 2. 2. 4. 3. 1.]
#  [1. 2. 2. 2. 4. 3. 1. 3.]
#  [5. 2. 4. 5. 5. 1. 3. 0.]]
#
# 	Brute Force
# 		Solution = 11010010 [00101101].
# 		Maxcut = 58.0.
# 		Time: 0.016655345098115504 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00100111 [11011000].
# 		Maxcut = -54.89800099643752.
# 		Optimizer Time: 4.114856481552124 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.114856481552124 seconds.
#
#
# Test Case 75:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 3. 5. 3. 5. 1. 2.]
#  [1. 0. 1. 0. 0. 4. 1. 4.]
#  [3. 1. 4. 2. 3. 3. 1. 5.]
#  [5. 0. 2. 2. 5. 4. 1. 1.]
# ...
#  [1. 0. 2. 3. 0. 3. 5. 5.]
#  [3. 1. 1. 0. 4. 1. 5. 4.]
#  [4. 4. 3. 3. 1. 1. 2. 3.]
#  [5. 2. 1. 5. 5. 2. 3. 3.]
#  [4. 3. 3. 5. 4. 3. 3. 0.]]
#
# 	Brute Force
# 		Solution = 11111000 [00000111].
# 		Maxcut = 52.0.
# 		Time: 0.017215213971212506 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11111000 [00000111].
# 		Maxcut = -51.47375812667323.
# 		Optimizer Time: 4.042139530181885 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.042139530181885 seconds.
#
#
# Test Case 79:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 4. 0. 2. 1. 4. 3. 1.]
#  [4. 3. 5. 3. 2. 1. 2. 1.]
#  [0. 5. 0. 1. 5. 2. 4. 3.]
#  [2. 3. 1. 0. 5. 2. 4. 3.]
#  [1. 2. 5. 5. 3. 2. 4. 4.]
#  [4. 1. 2. 2. 2. 3. 3. 2.]
#  [3. 2. 4. 4. 4. 3. 3. 3.]
#  [1. 1. 3. 3. 4. 2. 3. 4.]]
#
# 	Brute Force
# 		Solution = 01001110 [10110001].
# 		Maxcut = 52.0.
# 		Time: 0.017192149069160223 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001010 [10110101].
# 		Maxcut = -47.625805447469844.
# 		Optimizer Time: 3.9247915744781494 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.9247915744781494 seconds.
#
#
# Test Case 80:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 2. 5. 5. 5. 3. 5. 1.]
#  [2. 2. 5. 1. 2. 2. 1. 4.]
#  [5. 5. 3. 4. 4. 3. 3. 5.]
#  [5. 1. 4. 5. 3. 4. 4. 3.]
#  [5. 2. 4. 3. 2. 5. 4. 0.]
#  [3. 2. 3. 4. 5. 0. 4. 4.]
#  [5. 1. 3. 4. 4. 4. 0. 1.]
#  [1. 4. 5. 3. 0. 4. 1. 5.]]
#
# 	Brute Force
# 		Solution = 10100100 [01011011].
# 		Maxcut = 58.0.
# 		Time: 0.017179662943817675 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000110 [00111001].
# 		Maxcut = -55.85819952696666.
# 		Optimizer Time: 4.059399843215942 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.059399843215942 seconds.
#
#
# Test Case 81:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 1. 1. 5. 3. 4. 3. 2.]
#  [1. 4. 3. 3. 3. 2. 0. 5.]
#  [1. 3. 1. 2. 2. 2. 2. 3.]
#  [5. 3. 2. 4. 1. 2. 4. 3.]
#  [3. 3. 2. 1. 3. 3. 1. 1.]
#  [4. 2. 2. 2. 3. 2. 4. 3.]
#  [3. 0. 2. 4. 1. 4. 3. 5.]
#  [2. 5. 3. 3. 1. 3. 5. 3.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 50.0.
# 		Time: 0.017468585981987417 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100110 [10011001].
# 		Maxcut = -45.00463002183673.
# 		Optimizer Time: 4.25489616394043 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.25489616394043 seconds.
#
#
# Test Case 82:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 1. 3. 5. 1. 2. 1.]
#  [5. 0. 1. 2. 5. 3. 3. 1.]
#  [1. 1. 4. 2. 1. 2. 2. 3.]
#  [3. 2. 2. 2. 4. 4. 1. 5.]
#  [5. 5. 1. 4. 0. 1. 4. 3.]
#  [1. 3. 2. 4. 1. 1. 1. 4.]
#  [2. 3. 2. 1. 4. 1. 4. 2.]
#  [1. 1. 3. 5. 3. 4. 2. 5.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 47.0.
# 		Time: 0.01671005692332983 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010110 [01101001].
# 		Maxcut = -45.63985891094208.
# 		Optimizer Time: 4.068668842315674 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.068668842315674 seconds.
#
#
# Test Case 83:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 1. 2. 2. 4. 5. 3. 5.]
#  [1. 2. 2. 1. 5. 4. 4. 4.]
#  [2. 2. 1. 5. 1. 5. 5. 3.]
#  [2. 1. 5. 0. 5. 1. 4. 4.]
#  [4. 5. 1. 5. 1. 5. 4. 1.]
#  [5. 4. 5. 1. 5. 4. 2. 2.]
#  [3. 4. 5. 4. 4. 2. 5. 5.]
#  [5. 4. 3. 4. 1. 2. 5. 4.]]
#
# 	Brute Force
# 		Solution = 11110000 [00001111].
# 		Maxcut = 62.0.
# 		Time: 0.01657021197024733 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01101001 [10010110].
# 		Maxcut = -60.29944192350611.
# 		Optimizer Time: 3.8206210136413574 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.8206210136413574 seconds.
#
#
# Test Case 84:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 3. 2. 3. 5. 2. 5. 5.]
#  [3. 0. 4. 5. 4. 5. 2. 1.]
#  [2. 4. 4. 3. 4. 4. 3. 1.]
#  [3. 5. 3. 4. 2. 1. 1. 5.]
#  [5. 4. 4. 2. 0. 1. 1. 3.]
#  [2. 5. 4. 1. 1. 1. 5. 2.]
#  [5. 2. 3. 1. 1. 5. 3. 1.]
#  [5. 1. 1. 5. 3. 2. 1. 4.]]
#
# 	Brute Force
# 		Solution = 10011100 [01100011].
# 		Maxcut = 57.0.
# 		Time: 0.016090053948573768 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001011 [10110100].
# 		Maxcut = -55.829173003895505.
# 		Optimizer Time: 4.153197288513184 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.153197288513184 seconds.
#
#
# Test Case 85:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 1. 1. 4. 2. 1. 2. 2.]
#  [1. 3. 5. 3. 4. 5. 4. 5.]
#  [1. 5. 2. 4. 1. 5. 5. 3.]
#  [4. 3. 4. 2. 4. 3. 1. 5.]
#  [2. 4. 1. 4. 2. 4. 1. 3.]
#  [1. 5. 5. 3. 4. 1. 3. 4.]
#  [2. 4. 5. 1. 1. 3. 3. 3.]
#  [2. 5. 3. 5. 3. 4. 3. 1.]]
#
# 	Brute Force
# 		Solution = 01010110 [10101001].
# 		Maxcut = 57.0.
# 		Time: 0.01713508495595306 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101001 [01010110].
# 		Maxcut = -56.9408825208751.
# 		Optimizer Time: 4.15987491607666 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.15987491607666 seconds.
#
#
# Test Case 86:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 5. 5. 5. 5. 1. 3. 1.]
#  [5. 5. 1. 4. 2. 2. 2. 1.]
#  [5. 1. 0. 2. 5. 1. 1. 4.]
#  [5. 4. 2. 2. 1. 4. 4. 5.]
#  [5. 2. 5. 1. 5. 3. 4. 3.]
#  [1. 2. 1. 4. 3. 5. 2. 2.]
#  [3. 2. 1. 4. 4. 2. 3. 2.]
#  [1. 1. 4. 5. 3. 2. 2. 5.]]
#
# 	Brute Force
# 		Solution = 01111000 [10000111].
# 		Maxcut = 54.0.
# 		Time: 0.017347931978292763 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10011001 [01100110].
# 		Maxcut = -50.883585947182596.
# 		Optimizer Time: 3.949829578399658 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.949829578399658 seconds.
#
#
# Test Case 87:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 1. 5. 5. 1. 3. 5. 5.]
#  [1. 0. 4. 5. 5. 5. 3. 4.]
#  [5. 4. 2. 3. 1. 1. 5. 2.]
#  [5. 5. 3. 0. 3. 2. 1. 1.]
#  [1. 5. 1. 3. 0. 1. 3. 2.]
#  [3. 5. 1. 2. 1. 1. 5. 4.]
#  [5. 3. 5. 1. 3. 5. 1. 3.]
#  [5. 4. 2. 1. 2. 4. 3. 5.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 59.0.
# 		Time: 0.01759489404503256 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000010 [00111101].
# 		Maxcut = -58.95301797928089.
# 		Optimizer Time: 3.778249979019165 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.778249979019165 seconds.
#
#
# Test Case 88:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 5. 4. 5. 1. 5. 2. 2.]
#  [5. 5. 2. 2. 4. 3. 5. 5.]
#  [4. 2. 4. 2. 2. 1. 1. 0.]
#  [5. 2. 2. 1. 5. 2. 4. 1.]
#  [1. 4. 2. 5. 2. 5. 3. 3.]
#  [5. 3. 1. 2. 5. 1. 4. 4.]
#  [2. 5. 1. 4. 3. 4. 0. 5.]
#  [2. 5. 0. 1. 3. 4. 5. 1.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 59.0.
# 		Time: 0.01693849195726216 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01110101 [10001010].
# 		Maxcut = -58.98012429180427.
# 		Optimizer Time: 4.1461710929870605 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.1461710929870605 seconds.
#
#
# Test Case 89:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 1. 1. 5. 4. 1. 2.]
#  [1. 1. 3. 1. 2. 4. 4. 2.]
#  [1. 3. 1. 5. 2. 1. 4. 2.]
#  [1. 1. 5. 0. 1. 1. 2. 4.]
#  [5. 2. 2. 1. 3. 3. 4. 1.]
#  [4. 4. 1. 1. 3. 2. 3. 5.]
#  [1. 4. 4. 2. 4. 3. 0. 5.]
#  [2. 2. 2. 4. 1. 5. 5. 1.]]
#
# 	Brute Force
# 		Solution = 11010010 [00101101].
# 		Maxcut = 50.0.
# 		Time: 0.01755036599934101 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010110 [01101001].
# 		Maxcut = -49.902204323551466.
# 		Optimizer Time: 4.106549263000488 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.106549263000488 seconds.
#
#
# Test Case 90:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 2. 3. 5. 5. 5. 0. 2.]
#  [2. 4. 2. 5. 4. 1. 1. 2.]
#  [3. 2. 3. 3. 5. 4. 5. 3.]
#  [5. 5. 3. 3. 4. 2. 0. 2.]
#  [5. 4. 5. 4. 5. 4. 1. 5.]
#  [5. 1. 4. 2. 4. 3. 5. 3.]
#  [0. 1. 5. 0. 1. 5. 0. 3.]
#  [2. 2. 3. 2. 5. 3. 3. 4.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 56.0.
# 		Time: 0.017056101001799107 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01110100 [10001011].
# 		Maxcut = -52.547575756748614.
# 		Optimizer Time: 4.1012115478515625 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.1012115478515625 seconds.
#
#
# Test Case 91:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 5. 1. 5. 5. 0. 2. 0.]
#  [5. 1. 5. 5. 5. 4. 3. 5.]
#  [1. 5. 5. 1. 3. 1. 4. 2.]
#  [5. 5. 1. 5. 5. 5. 4. 3.]
#  [5. 5. 3. 5. 1. 3. 1. 3.]
#  [0. 4. 1. 5. 3. 0. 2. 5.]
#  [2. 3. 4. 4. 1. 2. 4. 2.]
#  [0. 5. 2. 3. 3. 5. 2. 2.]]
#
# 	Brute Force
# 		Solution = 01001110 [10110001].
# 		Maxcut = 59.0.
# 		Time: 0.01703299500513822 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110100 [01001011].
# 		Maxcut = -56.68240773938664.
# 		Optimizer Time: 3.9371087551116943 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.9371087551116943 seconds.
#
#
# Test Case 92:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 1. 5. 4. 3. 2. 4. 2.]
#  [1. 4. 2. 4. 2. 3. 3. 1.]
#  [5. 2. 1. 3. 5. 4. 1. 2.]
#  [4. 4. 3. 2. 4. 3. 5. 1.]
#  [3. 2. 5. 4. 3. 1. 4. 2.]
#  [2. 3. 4. 3. 1. 0. 1. 5.]
#  [4. 3. 1. 5. 4. 1. 3. 1.]
#  [2. 1. 2. 1. 2. 5. 1. 5.]]
#
# 	Brute Force
# 		Solution = 11001100 [00110011].
# 		Maxcut = 53.0.
# 		Time: 0.0172968179685995 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100110 [10011001].
# 		Maxcut = -47.85506808675356.
# 		Optimizer Time: 4.358531475067139 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.358531475067139 seconds.
#
#
# Test Case 93:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 1. 4. 5. 5. 4. 4. 1.]
#  [1. 3. 4. 2. 1. 4. 2. 1.]
#  [4. 4. 0. 1. 1. 2. 3. 1.]
#  [5. 2. 1. 5. 4. 2. 1. 1.]
#  [5. 1. 1. 4. 0. 5. 2. 1.]
#  [4. 4. 2. 2. 5. 2. 3. 5.]
#  [4. 2. 3. 1. 2. 3. 5. 5.]
#  [1. 1. 1. 1. 1. 5. 5. 2.]]
#
# 	Brute Force
# 		Solution = 00110110 [11001001].
# 		Maxcut = 53.0.
# 		Time: 0.01710888696834445 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001001 [00110110].
# 		Maxcut = -52.76834171853609.
# 		Optimizer Time: 4.2000157833099365 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.2000157833099365 seconds.
#
#
# Test Case 94:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 1. 4. 4. 1. 4. 4. 5.]
#  [1. 1. 4. 2. 3. 1. 2. 2.]
#  [4. 4. 1. 3. 3. 0. 2. 2.]
#  [4. 2. 3. 1. 4. 3. 1. 3.]
#  [1. 3. 3. 4. 0. 1. 4. 4.]
#  [4. 1. 0. 3. 1. 0. 1. 2.]
#  [4. 2. 2. 1. 4. 1. 1. 5.]
#  [5. 2. 2. 3. 4. 2. 5. 0.]]
#
# 	Brute Force
# 		Solution = 11010010 [00101101].
# 		Maxcut = 49.0.
# 		Time: 0.01846573199145496 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00110110 [11001001].
# 		Maxcut = -48.888981921145586.
# 		Optimizer Time: 3.85134220123291 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.85134220123291 seconds.
#
#
# Test Case 95:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 3. 5. 4. 3. 1. 3. 1.]
#  [3. 5. 0. 1. 2. 2. 4. 5.]
#  [5. 0. 4. 5. 0. 2. 5. 4.]
#  [4. 1. 5. 0. 5. 3. 5. 1.]
#  [3. 2. 0. 5. 3. 5. 3. 4.]
#  [1. 2. 2. 3. 5. 1. 3. 2.]
#  [3. 4. 5. 5. 3. 3. 2. 4.]
#  [1. 5. 4. 1. 4. 2. 4. 1.]]
#
# 	Brute Force
# 		Solution = 01101010 [10010101].
# 		Maxcut = 59.0.
# 		Time: 0.044969592010602355 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -58.92829290738233.
# 		Optimizer Time: 4.071293830871582 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.071293830871582 seconds.
#
#
# Test Case 96:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 2. 3. 3. 4. 4. 1. 5.]
#  [2. 0. 4. 5. 3. 4. 2. 5.]
#  [3. 4. 1. 2. 2. 1. 1. 1.]
#  [3. 5. 2. 1. 1. 4. 3. 1.]
#  [4. 3. 2. 1. 5. 2. 3. 5.]
#  [4. 4. 1. 4. 2. 4. 4. 0.]
#  [1. 2. 1. 3. 3. 4. 2. 4.]
#  [5. 5. 1. 1. 5. 0. 4. 3.]]
#
# 	Brute Force
# 		Solution = 11000010 [00111101].
# 		Maxcut = 55.0.
# 		Time: 0.016756884986534715 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000010 [00111101].
# 		Maxcut = -54.821515996707014.
# 		Optimizer Time: 3.9858763217926025 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.9858763217926025 seconds.
#
#
# Test Case 97:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 1. 3. 5. 2. 2. 1. 4.]
#  [1. 3. 0. 3. 5. 2. 5. 2.]
#  [3. 0. 5. 0. 3. 1. 3. 1.]
#  [5. 3. 0. 5. 5. 3. 5. 1.]
#  [2. 5. 3. 5. 3. 1. 4. 2.]
#  [2. 2. 1. 3. 1. 2. 4. 4.]
#  [1. 5. 3. 5. 4. 4. 1. 0.]
#  [4. 2. 1. 1. 2. 4. 0. 0.]]
#
# 	Brute Force
# 		Solution = 10001110 [01110001].
# 		Maxcut = 51.0.
# 		Time: 0.016978972009383142 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00110011 [11001100].
# 		Maxcut = -48.947199673484526.
# 		Optimizer Time: 4.080688714981079 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.080688714981079 seconds.
#
#
# Test Case 98:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 1. 1. 3. 3. 1. 5. 3.]
#  [1. 0. 2. 1. 2. 0. 4. 1.]
#  [1. 2. 0. 3. 2. 1. 4. 4.]
#  [3. 1. 3. 1. 5. 1. 2. 5.]
#  [3. 2. 2. 5. 0. 1. 4. 3.]
#  [1. 0. 1. 1. 1. 4. 2. 4.]
#  [5. 4. 4. 2. 4. 2. 2. 5.]
#  [3. 1. 4. 5. 3. 4. 5. 3.]]
#
# 	Brute Force
# 		Solution = 11110100 [00001011].
# 		Maxcut = 47.0.
# 		Time: 0.018129070987924933 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101001 [01010110].
# 		Maxcut = -46.904249187954036.
# 		Optimizer Time: 3.867760419845581 seconds.
# 		Compmute Minimum Eigenvalue Time: 3.867760419845581 seconds.
#
#
# Test Case 99:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 2. 3. 4. 5. 5. 0. 4.]
#  [2. 1. 3. 1. 2. 1. 5. 3.]
#  [3. 3. 1. 5. 3. 5. 5. 2.]
#  [4. 1. 5. 0. 3. 1. 0. 3.]
#  [5. 2. 3. 3. 1. 0. 2. 3.]
#  [5. 1. 5. 1. 0. 4. 5. 1.]
#  [0. 5. 5. 0. 2. 5. 5. 1.]
#  [4. 3. 2. 3. 3. 1. 1. 5.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 54.0.
# 		Time: 0.017308201058767736 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01011100 [10100011].
# 		Maxcut = -53.043584513440265.
# 		Optimizer Time: 4.0367138385772705 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.0367138385772705 seconds.

# %%
print(f'Success: {success} / {num_tests} = {(success/num_tests) * 100} %')
print(f'Fail: {failure} / {num_tests} = {(failure/num_tests) * 100} %')
# Out:
# Success: 32 / 100 = 32.0 %
# Fail: 68 / 100 = 68.0 %
