# %% [markdown]
# ## Random Graphs
#
# ### Helper Functions
#
# Randomly generate an adjancency matrix...

# %%
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations, groupby

n = 4

def random_row():
    row = list(np.random.choice((0, 1, 2, 3, 4, 5),size=n))
    
    # No self-references
    row[row_num] = 0 
    
    # Make sure there's no isolated nodes
    if sum(row) == 0:
        row = random_row()
    return row

def random_matrix():
    rows = []
    for i in range(0, n):
        rows.append(random_row())
    numpy_matrix = np.matrix(rows)
    
    return numpy_matrix

def random_graph():
    np_matrix = random_matrix()
    g = nx.convert_matrix.from_numpy_matrix(
        np_matrix, 
        parallel_edges=False, 
        create_using=nx.Graph
    )
    
    # nx.draw(g, node_color='lightblue', 
    #     with_labels=True, 
    #     node_size=500)
    
    return g, np_matrix

# %% [markdown]
# ### Brute Force

# %%
def brute_force(graph, w):

    best_cost_brute = 0
    for b in range(2**n):
        x = [int(t) for t in reversed(list(bin(b)[2:].zfill(n)))]
        cost = 0
        for i in range(n):
            for j in range(n):
                cost = cost + w[i,j]*x[i]*(1-x[j])
        if best_cost_brute < cost:
            best_cost_brute = cost
            xbest_brute = x
        #print('case = ' + str(x)+ ' cost = ' + str(cost))

    return xbest_brute, best_cost_brute

# %% [markdown]
# ### Variatonal Quantum EignSolver

# %%
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram
from qiskit.circuit.library import TwoLocal
from qiskit_optimization.applications import Maxcut, Tsp
from qiskit.algorithms import VQE, NumPyMinimumEigensolver
from qiskit.algorithms.optimizers import SPSA, COBYLA
from qiskit.utils import algorithm_globals, QuantumInstance
from qiskit_optimization.algorithms import MinimumEigenOptimizer

def vqe(w):
    
    # Define our Qiskit Maxcut Instance
    max_cut = Maxcut(w)
    qp = max_cut.to_quadratic_program()

    # Translate to Ising Hamiltonian
    qubitOp, offset = qp.to_ising()

    # Setup our simulator
    algorithm_globals.random_seed = 123
    seed = 10598
    backend = Aer.get_backend('aer_simulator_statevector')
    quantum_instance = QuantumInstance(backend, seed_simulator=seed, seed_transpiler=seed)

    # Construct VQE
    spsa = SPSA(maxiter=300)
    cobyla = COBYLA(maxiter=300)
    ry = TwoLocal(qubitOp.num_qubits, 'ry', 'cz', reps=5, entanglement='linear')
    vqe = VQE(ry, optimizer=spsa, quantum_instance=quantum_instance)

    # Run VQE
    result = vqe.compute_minimum_eigenvalue(qubitOp)

    # print results
    bit_string = list(max_cut.sample_most_likely(result.eigenstate))
    bit_string = map(int, bit_string)
    # print('energy:', result.eigenvalue.real)
    # print('time:', result.optimizer_time)
    # print('max-cut objective:', result.eigenvalue.real + offset)
    # print('solution:', bit_string)
    # print('solution objective:', qp.objective.evaluate(bit_string))
    
    return bit_string, (result.eigenvalue.real + offset)

# %%
# Generate 1,000 graphs
success = 0
failure = 0

# TODO: Change the number of tests, ad hoc
num_tests: int = 100

for graph_id in range(num_tests):
    # Generate Random Graph
    graph, matrix = random_graph()
    
    # Computing the weight matrix from the random graph
    w = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            temp = graph.get_edge_data(i,j,default=0)
            if temp != 0:
                w[i,j] = temp['weight']
    
    bf_bit_string, bf_cost = brute_force(graph, w)
    bf_x = ''.join(str(e) for e in bf_bit_string)
    bf_x_inverse = ''.join('1' if x == '0' else '0' for x in bf_x)
    print(f'\nBrute Force: Best solution = {bf_x} | inverse[{bf_x_inverse}]  cost = {str(bf_cost)}')
    
    vqe_bit_string, vqe_cost = vqe(w)
    vqe_x = ''.join(str(e) for e in vqe_bit_string)
    vqe_x_inverse = ''.join('1' if x == '0' else '0' for x in vqe_x)
    print(f'VQE: Best solution = {vqe_x} | inverse[{vqe_x_inverse}]  cost = {str(vqe_cost)}')
    print()
    print(w)
    print()
    print()
    
    # Check validity
    if bf_x == vqe_x or bf_x == vqe_x_inverse or vqe_x == bf_x_inverse:
        success += 1
    else:
        failure += 1
# Out:
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 14.0
# /opt/conda/lib/python3.8/site-packages/sympy/core/expr.py:3949: SymPyDeprecationWarning:
#
# expr_free_symbols method has been deprecated since SymPy 1.9. See
# https://github.com/sympy/sympy/issues/21494 for more info.
#
#   SymPyDeprecationWarning(feature="expr_free_symbols method",
# VQE: Best solution = 1010 | inverse[0101]  cost = -13.997335459387635
#
# [[4. 5. 1. 1.]
#  [5. 3. 3. 1.]
#  [1. 3. 1. 5.]
#  [1. 1. 5. 4.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -14.999488493849027
#
# [[2. 4. 5. 2.]
#  [4. 4. 3. 5.]
#  [5. 3. 0. 1.]
#  [2. 5. 1. 3.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 11.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -10.996171436998972
#
# [[3. 1. 1. 5.]
#  [1. 2. 2. 2.]
#  [1. 2. 3. 3.]
#  [5. 2. 3. 2.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -12.998223145533768
#
# [[2. 1. 3. 2.]
#  [1. 4. 3. 5.]
#  [3. 3. 2. 1.]
#  [2. 5. 1. 0.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 15.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -14.99554840126562
#
# [[1. 3. 3. 2.]
#  [3. 2. 2. 4.]
#  [3. 2. 3. 5.]
#  [2. 4. 5. 0.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 12.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -11.14736079513845
#
# [[3. 1. 3. 2.]
#  [1. 2. 4. 3.]
#  [3. 4. 5. 2.]
#  [2. 3. 2. 1.]]
#
#
#
# Brute Force: Best solution = 0100 | inverse[1011]  cost = 11.0
# VQE: Best solution = 1011 | inverse[0100]  cost = -10.998364093712572
#
# [[4. 2. 1. 1.]
#  [2. 0. 4. 5.]
#  [1. 4. 3. 2.]
#  [1. 5. 2. 3.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 15.0
# VQE: Best solution = 1001 | inverse[0110]  cost = -14.998305756301757
#
# [[5. 5. 4. 1.]
#  [5. 4. 2. 5.]
#  [4. 2. 4. 1.]
#  [1. 5. 1. 5.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 16.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -15.997476895970557
#
# [[5. 1. 4. 5.]
#  [1. 4. 4. 3.]
#  [4. 4. 3. 1.]
#  [5. 3. 1. 5.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 12.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -11.997844598587818
#
# [[3. 4. 1. 1.]
#  [4. 2. 3. 3.]
#  [1. 3. 5. 4.]
#  [1. 3. 4. 5.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 16.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -15.93045666725396
#
# [[5. 5. 4. 2.]
#  [5. 1. 4. 1.]
#  [4. 4. 0. 5.]
#  [2. 1. 5. 0.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 16.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -15.998907058346195
#
# [[4. 5. 4. 5.]
#  [5. 1. 3. 2.]
#  [4. 3. 3. 3.]
#  [5. 2. 3. 4.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 17.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -15.992527537650158
#
# [[0. 5. 5. 2.]
#  [5. 1. 5. 5.]
#  [5. 5. 2. 1.]
#  [2. 5. 1. 3.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 10.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -9.98928443976151
#
# [[2. 1. 1. 3.]
#  [1. 1. 3. 3.]
#  [1. 3. 1. 1.]
#  [3. 3. 1. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -14.999583607187784
#
# [[1. 2. 1. 4.]
#  [2. 2. 5. 5.]
#  [1. 5. 2. 4.]
#  [4. 5. 4. 3.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 18.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -17.995039259893037
#
# [[2. 4. 2. 4.]
#  [4. 0. 5. 5.]
#  [2. 5. 4. 5.]
#  [4. 5. 5. 4.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 15.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -14.989657546698751
#
# [[4. 5. 4. 1.]
#  [5. 5. 3. 5.]
#  [4. 3. 0. 1.]
#  [1. 5. 1. 1.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 13.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -12.962943241313614
#
# [[5. 3. 2. 2.]
#  [3. 2. 3. 5.]
#  [2. 3. 3. 3.]
#  [2. 5. 3. 3.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -11.99990764994799
#
# [[3. 2. 5. 5.]
#  [2. 3. 1. 4.]
#  [5. 1. 0. 1.]
#  [5. 4. 1. 1.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 14.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -13.995889262368918
#
# [[4. 3. 0. 4.]
#  [3. 5. 4. 3.]
#  [0. 4. 2. 3.]
#  [4. 3. 3. 1.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 9.0
# VQE: Best solution = 1001 | inverse[0110]  cost = -8.971505176903793
#
# [[3. 2. 4. 2.]
#  [2. 5. 1. 1.]
#  [4. 1. 4. 2.]
#  [2. 1. 2. 5.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 17.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -16.999496781812187
#
# [[4. 5. 4. 4.]
#  [5. 0. 3. 3.]
#  [4. 3. 5. 5.]
#  [4. 3. 5. 1.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 15.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -14.998052181379855
#
# [[4. 1. 1. 4.]
#  [1. 4. 5. 1.]
#  [1. 5. 3. 5.]
#  [4. 1. 5. 2.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 15.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -14.998036054971312
#
# [[5. 4. 0. 1.]
#  [4. 1. 5. 2.]
#  [0. 5. 2. 5.]
#  [1. 2. 5. 0.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 14.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -13.998360566227808
#
# [[5. 1. 5. 5.]
#  [1. 0. 2. 2.]
#  [5. 2. 5. 2.]
#  [5. 2. 2. 0.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 17.0
# VQE: Best solution = 1001 | inverse[0110]  cost = -16.311908304698864
#
# [[5. 5. 4. 1.]
#  [5. 1. 4. 4.]
#  [4. 4. 2. 4.]
#  [1. 4. 4. 3.]]
#
#
#
# Brute Force: Best solution = 1110 | inverse[0001]  cost = 13.0
# VQE: Best solution = 0001 | inverse[1110]  cost = -12.977919328326811
#
# [[3. 2. 1. 4.]
#  [2. 5. 2. 5.]
#  [1. 2. 0. 4.]
#  [4. 5. 4. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -12.395681715309252
#
# [[3. 2. 1. 4.]
#  [2. 1. 3. 5.]
#  [1. 3. 4. 3.]
#  [4. 5. 3. 0.]]
#
#
#
# Brute Force: Best solution = 0100 | inverse[1011]  cost = 11.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -10.996225451731044
#
# [[4. 5. 3. 1.]
#  [5. 4. 4. 2.]
#  [3. 4. 3. 1.]
#  [1. 2. 1. 2.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 9.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -8.999184977795089
#
# [[5. 1. 2. 3.]
#  [1. 5. 2. 1.]
#  [2. 2. 4. 3.]
#  [3. 1. 3. 2.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 8.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -7.997627311664718
#
# [[3. 1. 1. 1.]
#  [1. 1. 5. 1.]
#  [1. 5. 4. 1.]
#  [1. 1. 1. 3.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 16.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -15.773962490541349
#
# [[2. 4. 4. 3.]
#  [4. 2. 3. 3.]
#  [4. 3. 5. 5.]
#  [3. 3. 5. 2.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -14.985109119570687
#
# [[4. 4. 3. 5.]
#  [4. 2. 3. 4.]
#  [3. 3. 5. 2.]
#  [5. 4. 2. 5.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -14.997283976498979
#
# [[4. 1. 4. 2.]
#  [1. 2. 5. 4.]
#  [4. 5. 5. 1.]
#  [2. 4. 1. 5.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -12.991932460239658
#
# [[0. 1. 2. 5.]
#  [1. 0. 4. 2.]
#  [2. 4. 5. 1.]
#  [5. 2. 1. 0.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 13.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -12.995291994908156
#
# [[0. 4. 4. 1.]
#  [4. 3. 2. 1.]
#  [4. 2. 3. 4.]
#  [1. 1. 4. 5.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 10.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -9.996328811155418
#
# [[0. 1. 2. 4.]
#  [1. 4. 1. 3.]
#  [2. 1. 5. 1.]
#  [4. 3. 1. 0.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 11.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -10.996149287360703
#
# [[4. 1. 3. 5.]
#  [1. 5. 2. 1.]
#  [3. 2. 0. 2.]
#  [5. 1. 2. 0.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 14.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -13.999303061696732
#
# [[0. 5. 4. 3.]
#  [5. 0. 5. 1.]
#  [4. 5. 4. 1.]
#  [3. 1. 1. 0.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 15.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -14.998013974614501
#
# [[5. 3. 3. 4.]
#  [3. 4. 1. 4.]
#  [3. 1. 4. 5.]
#  [4. 4. 5. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 11.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -10.981429068270277
#
# [[5. 1. 3. 2.]
#  [1. 1. 5. 1.]
#  [3. 5. 0. 2.]
#  [2. 1. 2. 2.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 14.0
# VQE: Best solution = 1001 | inverse[0110]  cost = -13.996543248507084
#
# [[3. 3. 3. 1.]
#  [3. 5. 1. 4.]
#  [3. 1. 2. 4.]
#  [1. 4. 4. 2.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 14.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -13.998652028188943
#
# [[1. 3. 1. 5.]
#  [3. 3. 4. 2.]
#  [1. 4. 2. 2.]
#  [5. 2. 2. 4.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 9.0
# VQE: Best solution = 0001 | inverse[1110]  cost = -8.998842615371027
#
# [[5. 1. 2. 4.]
#  [1. 2. 1. 2.]
#  [2. 1. 4. 3.]
#  [4. 2. 3. 3.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 15.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -14.999554009941964
#
# [[1. 2. 5. 1.]
#  [2. 1. 2. 5.]
#  [5. 2. 0. 3.]
#  [1. 5. 3. 5.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 14.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -13.948673043348876
#
# [[1. 5. 1. 0.]
#  [5. 3. 3. 4.]
#  [1. 3. 0. 4.]
#  [0. 4. 4. 2.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 1101 | inverse[0010]  cost = -12.964514870955073
#
# [[3. 2. 5. 2.]
#  [2. 0. 4. 2.]
#  [5. 4. 2. 4.]
#  [2. 2. 4. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 11.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -10.999271145661005
#
# [[0. 1. 4. 3.]
#  [1. 3. 2. 2.]
#  [4. 2. 5. 1.]
#  [3. 2. 1. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 12.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -11.994356461012615
#
# [[4. 1. 3. 4.]
#  [1. 5. 1. 4.]
#  [3. 1. 0. 0.]
#  [4. 4. 0. 4.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 15.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -14.957031037900855
#
# [[5. 3. 4. 3.]
#  [3. 4. 4. 2.]
#  [4. 4. 3. 5.]
#  [3. 2. 5. 5.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 10.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -9.90158417020249
#
# [[0. 3. 1. 2.]
#  [3. 2. 1. 3.]
#  [1. 1. 2. 3.]
#  [2. 3. 3. 5.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 12.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -11.994362692781051
#
# [[5. 1. 3. 4.]
#  [1. 2. 4. 1.]
#  [3. 4. 5. 3.]
#  [4. 1. 3. 2.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 12.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -11.996631450093105
#
# [[4. 4. 1. 1.]
#  [4. 1. 5. 1.]
#  [1. 5. 3. 2.]
#  [1. 1. 2. 2.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -12.995601280663733
#
# [[3. 1. 4. 2.]
#  [1. 4. 4. 3.]
#  [4. 4. 5. 5.]
#  [2. 3. 5. 3.]]
#
#
#
# Brute Force: Best solution = 0100 | inverse[1011]  cost = 14.0
# VQE: Best solution = 0100 | inverse[1011]  cost = -13.997173693834762
#
# [[2. 4. 1. 1.]
#  [4. 1. 5. 5.]
#  [1. 5. 2. 2.]
#  [1. 5. 2. 5.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -11.999563194289816
#
# [[2. 1. 4. 2.]
#  [1. 1. 2. 5.]
#  [4. 2. 1. 2.]
#  [2. 5. 2. 2.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 10.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -9.990118761588167
#
# [[2. 2. 1. 5.]
#  [2. 5. 1. 3.]
#  [1. 1. 3. 2.]
#  [5. 3. 2. 0.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -14.98563236291901
#
# [[5. 4. 2. 5.]
#  [4. 5. 3. 5.]
#  [2. 3. 3. 1.]
#  [5. 5. 1. 5.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 16.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -15.994162656612726
#
# [[5. 1. 5. 5.]
#  [1. 1. 3. 3.]
#  [5. 3. 2. 1.]
#  [5. 3. 1. 4.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 13.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -12.985126111694518
#
# [[4. 4. 2. 1.]
#  [4. 5. 4. 2.]
#  [2. 4. 5. 4.]
#  [1. 2. 4. 3.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 16.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -15.775831268958072
#
# [[4. 5. 1. 2.]
#  [5. 5. 3. 5.]
#  [1. 3. 0. 5.]
#  [2. 5. 5. 3.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 10.0
# VQE: Best solution = 1001 | inverse[0110]  cost = -9.705514086765255
#
# [[2. 3. 4. 2.]
#  [3. 1. 2. 1.]
#  [4. 2. 2. 2.]
#  [2. 1. 2. 3.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 12.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -11.998957928287084
#
# [[1. 2. 3. 1.]
#  [2. 1. 2. 4.]
#  [3. 2. 3. 3.]
#  [1. 4. 3. 4.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 16.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -15.9990659176507
#
# [[5. 5. 5. 4.]
#  [5. 4. 4. 1.]
#  [5. 4. 3. 3.]
#  [4. 1. 3. 0.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 18.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -16.95425379707007
#
# [[2. 2. 5. 3.]
#  [2. 0. 5. 5.]
#  [5. 5. 5. 5.]
#  [3. 5. 5. 3.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 11.0
# VQE: Best solution = 1001 | inverse[0110]  cost = -10.978964515574113
#
# [[2. 3. 3. 3.]
#  [3. 4. 1. 2.]
#  [3. 1. 3. 3.]
#  [3. 2. 3. 2.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 14.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -13.995483919743561
#
# [[1. 3. 4. 1.]
#  [3. 2. 4. 5.]
#  [4. 4. 0. 1.]
#  [1. 5. 1. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 10.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -9.99857884393451
#
# [[5. 1. 2. 3.]
#  [1. 1. 3. 2.]
#  [2. 3. 2. 3.]
#  [3. 2. 3. 4.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 16.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -15.99681266748219
#
# [[4. 2. 5. 2.]
#  [2. 5. 4. 5.]
#  [5. 4. 1. 4.]
#  [2. 5. 4. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -14.962313122820348
#
# [[4. 4. 3. 5.]
#  [4. 1. 3. 4.]
#  [3. 3. 5. 1.]
#  [5. 4. 1. 1.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 15.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -14.999499569642225
#
# [[5. 2. 2. 3.]
#  [2. 4. 5. 4.]
#  [2. 5. 3. 5.]
#  [3. 4. 5. 4.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -12.995026256784088
#
# [[0. 1. 1. 4.]
#  [1. 0. 4. 4.]
#  [1. 4. 2. 2.]
#  [4. 4. 2. 0.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 17.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -14.940742191537876
#
# [[2. 5. 5. 1.]
#  [5. 1. 5. 4.]
#  [5. 5. 1. 3.]
#  [1. 4. 3. 4.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 13.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -12.962408279057568
#
# [[0. 3. 3. 3.]
#  [3. 2. 2. 1.]
#  [3. 2. 5. 5.]
#  [3. 1. 5. 5.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 15.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -14.999789567597908
#
# [[4. 4. 4. 5.]
#  [4. 0. 1. 2.]
#  [4. 1. 5. 5.]
#  [5. 2. 5. 2.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 12.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -11.999535849452254
#
# [[4. 3. 2. 2.]
#  [3. 1. 5. 1.]
#  [2. 5. 1. 2.]
#  [2. 1. 2. 5.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -12.994031718674213
#
# [[4. 2. 2. 2.]
#  [2. 2. 4. 5.]
#  [2. 4. 3. 4.]
#  [2. 5. 4. 0.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 12.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -10.998438044005605
#
# [[2. 2. 5. 3.]
#  [2. 4. 1. 3.]
#  [5. 1. 2. 1.]
#  [3. 3. 1. 1.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 15.0
# VQE: Best solution = 1010 | inverse[0101]  cost = -14.998685401597823
#
# [[2. 3. 5. 4.]
#  [3. 0. 3. 1.]
#  [5. 3. 5. 5.]
#  [4. 1. 5. 5.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 15.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -14.995598711446833
#
# [[1. 3. 4. 4.]
#  [3. 3. 3. 0.]
#  [4. 3. 5. 5.]
#  [4. 0. 5. 0.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 16.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -15.9987017898219
#
# [[3. 3. 2. 5.]
#  [3. 5. 5. 3.]
#  [2. 5. 3. 3.]
#  [5. 3. 3. 4.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 16.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -15.998074292446136
#
# [[3. 0. 5. 4.]
#  [0. 0. 4. 3.]
#  [5. 4. 0. 2.]
#  [4. 3. 2. 4.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 16.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -15.995420014345124
#
# [[2. 1. 4. 3.]
#  [1. 0. 4. 5.]
#  [4. 4. 3. 2.]
#  [3. 5. 2. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 12.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -11.995424441843657
#
# [[4. 0. 2. 1.]
#  [0. 5. 4. 5.]
#  [2. 4. 5. 1.]
#  [1. 5. 1. 2.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 16.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -15.995987857765153
#
# [[4. 2. 4. 3.]
#  [2. 1. 3. 5.]
#  [4. 3. 2. 5.]
#  [3. 5. 5. 0.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 11.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -10.997841476182419
#
# [[5. 0. 3. 4.]
#  [0. 2. 2. 2.]
#  [3. 2. 2. 2.]
#  [4. 2. 2. 4.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 16.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -14.998571723563323
#
# [[5. 4. 4. 4.]
#  [4. 2. 3. 4.]
#  [4. 3. 4. 4.]
#  [4. 4. 4. 2.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 14.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -13.983160638002207
#
# [[3. 2. 5. 1.]
#  [2. 3. 2. 2.]
#  [5. 2. 5. 5.]
#  [1. 2. 5. 3.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 1001 | inverse[0110]  cost = -13.989961521859604
#
# [[5. 2. 4. 1.]
#  [2. 0. 5. 5.]
#  [4. 5. 4. 3.]
#  [1. 5. 3. 3.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -12.989807862895118
#
# [[3. 1. 2. 5.]
#  [1. 3. 1. 5.]
#  [2. 1. 0. 2.]
#  [5. 5. 2. 3.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 11.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -10.973355443932611
#
# [[4. 3. 1. 3.]
#  [3. 1. 4. 2.]
#  [1. 4. 3. 1.]
#  [3. 2. 1. 0.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 17.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -16.986322461448154
#
# [[3. 5. 4. 5.]
#  [5. 4. 4. 4.]
#  [4. 4. 5. 1.]
#  [5. 4. 1. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -14.988675196197518
#
# [[2. 2. 4. 5.]
#  [2. 3. 2. 4.]
#  [4. 2. 3. 1.]
#  [5. 4. 1. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 17.0
# VQE: Best solution = 0011 | inverse[1100]  cost = -16.99619977693047
#
# [[5. 5. 4. 4.]
#  [5. 2. 4. 5.]
#  [4. 4. 3. 0.]
#  [4. 5. 0. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -12.995457854683554
#
# [[0. 0. 4. 4.]
#  [0. 4. 0. 5.]
#  [4. 0. 4. 1.]
#  [4. 5. 1. 1.]]
#
#
#
# Brute Force: Best solution = 0110 | inverse[1001]  cost = 13.0
# VQE: Best solution = 0110 | inverse[1001]  cost = -12.998882759908813
#
# [[2. 5. 3. 1.]
#  [5. 0. 1. 4.]
#  [3. 1. 0. 1.]
#  [1. 4. 1. 1.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 12.0
# VQE: Best solution = 1001 | inverse[0110]  cost = -11.998457886339617
#
# [[5. 1. 3. 1.]
#  [1. 0. 3. 5.]
#  [3. 3. 3. 3.]
#  [1. 5. 3. 4.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 13.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -12.998766016048481
#
# [[0. 1. 2. 4.]
#  [1. 5. 3. 4.]
#  [2. 3. 4. 2.]
#  [4. 4. 2. 4.]]
#
#
#
# Brute Force: Best solution = 1010 | inverse[0101]  cost = 17.0
# VQE: Best solution = 0101 | inverse[1010]  cost = -16.99797042158554
#
# [[1. 5. 1. 5.]
#  [5. 2. 5. 2.]
#  [1. 5. 3. 2.]
#  [5. 2. 2. 3.]]
#
#
#
# Brute Force: Best solution = 1100 | inverse[0011]  cost = 15.0
# VQE: Best solution = 1100 | inverse[0011]  cost = -14.996745246732324
#
# [[1. 2. 5. 3.]
#  [2. 4. 3. 4.]
#  [5. 3. 0. 2.]
#  [3. 4. 2. 4.]]

# %%
print(f"Success = {success}")
print(f"Failures = {failure}")
# Out:
# Success = 80
# Failures = 20
