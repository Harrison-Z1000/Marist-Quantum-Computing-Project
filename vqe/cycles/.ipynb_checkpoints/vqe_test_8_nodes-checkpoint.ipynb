# %% [markdown]
# ## Random Graphs
#
# ### Helper Functions
#
# Randomly generate an adjancency matrix...

# %%
import timeit
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations, groupby

# Size of NxN Matrix
n = 8

# Moved to global scopee to allow for timing
bf_bit_string, bf_cost = None, None

def random_row():
    row = list(np.random.choice((0, 1, 2, 3, 4, 5),size=n))
    
    # Make sure there's no isolated nodes
    if sum(row) == 0:
        row = random_row()
    return row

def random_matrix():
    rows = []
    for i in range(0, n):
        rows.append(random_row())
    numpy_matrix = np.matrix(rows)
    
    return numpy_matrix

def random_graph():
    np_matrix = random_matrix()
    g = nx.convert_matrix.from_numpy_matrix(
        np_matrix, 
        parallel_edges=False, 
        create_using=nx.Graph
    )
    
    # nx.draw(g, node_color='lightblue', 
    #     with_labels=True, 
    #     node_size=500)
    
    return g, np_matrix

# %% [markdown]
# ### Brute Force

# %%
def brute_force(graph, w):
    global bf_bit_string
    global bf_cost
    
    bf_bit_string = None
    bf_cost = None
    
    best_cost_brute = 0
    for b in range(2**n):
        x = [int(t) for t in reversed(list(bin(b)[2:].zfill(n)))]
        cost = 0
        for i in range(n):
            for j in range(n):
                cost = cost + w[i,j]*x[i]*(1-x[j])
        if best_cost_brute < cost:
            best_cost_brute = cost
            xbest_brute = x
    bf_bit_string = xbest_brute
    bf_cost = best_cost_brute
    return xbest_brute, best_cost_brute

# %% [markdown]
# ### Variatonal Quantum EignSolver

# %%
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram
from qiskit.circuit.library import TwoLocal
from qiskit_optimization.applications import Maxcut, Tsp
from qiskit.algorithms import VQE, NumPyMinimumEigensolver
from qiskit.algorithms.optimizers import SPSA, COBYLA
from qiskit.utils import algorithm_globals, QuantumInstance
from qiskit_optimization.algorithms import MinimumEigenOptimizer

def vqe(w):
    # Define our Qiskit Maxcut Instance
    max_cut = Maxcut(w)
    qp = max_cut.to_quadratic_program()

    # Translate to Ising Hamiltonian
    qubitOp, offset = qp.to_ising()

    # Setup our simulator
    algorithm_globals.random_seed = 123
    seed = 10598
    backend = Aer.get_backend('aer_simulator_statevector')
    quantum_instance = QuantumInstance(backend, seed_simulator=seed, seed_transpiler=seed)

    # Construct VQE
    spsa = SPSA(maxiter=300)
    cobyla = COBYLA(maxiter=300)
    ry = TwoLocal(qubitOp.num_qubits, 'ry', 'cz', reps=5, entanglement='linear')
    vqe = VQE(ry, optimizer=spsa, quantum_instance=quantum_instance)

    # Run VQE
    compute_min_eigenval_time = timeit.timeit(lambda: vqe.compute_minimum_eigenvalue(qubitOp), number=1)
    result = vqe.compute_minimum_eigenvalue(qubitOp)

    # print results
    bit_string = list(max_cut.sample_most_likely(result.eigenstate))
    bit_string = map(int, bit_string)
    # print('energy:', result.eigenvalue.real)
    # print('time:', result.optimizer_time)
    # print('max-cut objective:', result.eigenvalue.real + offset)
    # print('solution:', bit_string)
    # print('solution objective:', qp.objective.evaluate(bit_string))
    
    return bit_string, (result.eigenvalue.real + offset), result.optimizer_time, compute_min_eigenval_time

# %% [markdown]
# ## Tests

# %%
# Generate 1,000 graphs
success = 0
failure = 0

# TODO: Change the number of tests, ad hoc
num_tests: int = 100

for graph_id in range(num_tests):
    global bf_bit_string
    global bf_cost
    
    # Generate Random Graph
    graph, matrix = random_graph()
    
    # Computing the weight matrix from the random graph
    w = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            temp = graph.get_edge_data(i,j,default=0)
            if temp != 0:
                w[i,j] = temp['weight']
    
    print(f'\nTest Case {graph_id}: ')
    print('------------' + '-' * (graph_id * 2))
    print()
    print(w)
    
    # Brute Force Approach
    #
    # Time brute force algorithm
    bf_time: float = timeit.timeit(lambda: brute_force(graph, w), number=1)
    
    # Parse the bit sting answer
    bf_x = ''.join(str(e) for e in bf_bit_string)
    bf_x_inverse = ''.join('1' if x == '0' else '0' for x in bf_x)
    
    # Print results
    print('\n\tBrute Force')
    print(f'\t\tSolution = {bf_x} [{bf_x_inverse}].')
    print(f'\t\tMaxcut = {str(bf_cost)}.')
    print(f'\t\tTime: {bf_time} seconds.')
    
    # VQE Approach
    #
    #
    vqe_bit_string, vqe_cost, optimizer_time, compute_minimum_eigenvalue_time = vqe(w)
    
    # Parse the bit sting answer
    vqe_x = ''.join(str(e) for e in vqe_bit_string)
    vqe_x_inverse = ''.join('1' if x == '0' else '0' for x in vqe_x)
    
    # Print results
    print('\n\tVariation Quantum Eignsolver (VQE):')
    print(f'\t\tSolution = {vqe_x} [{vqe_x_inverse}].')
    print(f'\t\tMaxcut = {str(vqe_cost)}.')
    print(f'\t\tOptimizer Time: {str(optimizer_time)} seconds.')
    print(f'\t\tCompmute Minimum Eigenvalue Time: {str(optimizer_time)} seconds.')
    print()
    
    # Check validity
    if bf_x == vqe_x or bf_x == vqe_x_inverse or vqe_x == bf_x_inverse:
        success += 1
    else:
        failure += 1
# Out:
# Test Case 0:
# ------------
#
# [[2. 4. 1. 3. 5. 3. 1. 5.]
#  [4. 5. 4. 3. 3. 2. 5. 0.]
#  [1. 4. 0. 1. 5. 4. 1. 4.]
#  [3. 3. 1. 4. 4. 3. 5. 3.]
#  [5. 3. 5. 4. 3. 4. 1. 2.]
#  [3. 2. 4. 3. 4. 0. 1. 1.]
#  [1. 5. 1. 5. 1. 1. 1. 5.]
#  [5. 0. 4. 3. 2. 1. 5. 3.]]
#
# 	Brute Force
# 		Solution = 10110010 [01001101].
# 		Maxcut = 59.0.
# 		Time: 0.01708267501089722 seconds.
# /opt/conda/lib/python3.8/site-packages/sympy/core/expr.py:3949: SymPyDeprecationWarning:
#
# expr_free_symbols method has been deprecated since SymPy 1.9. See
# https://github.com/sympy/sympy/issues/21494 for more info.
#
#   SymPyDeprecationWarning(feature="expr_free_symbols method",
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001101 [10110010].
# 		Maxcut = -58.92398773719656.
# 		Optimizer Time: 4.26811408996582 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.26811408996582 seconds.
#
#
# Test Case 1:
# --------------
#
# [[1. 3. 3. 2. 4. 3. 5. 3.]
#  [3. 2. 5. 1. 4. 2. 4. 1.]
#  [3. 5. 1. 2. 3. 3. 3. 3.]
#  [2. 1. 2. 2. 5. 4. 3. 5.]
#  [4. 4. 3. 5. 5. 5. 2. 1.]
#  [3. 2. 3. 4. 5. 2. 5. 1.]
#  [5. 4. 3. 3. 2. 5. 5. 1.]
#  [3. 1. 3. 5. 1. 1. 1. 0.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 58.0.
# 		Time: 0.01648011401994154 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001011 [10110100].
# 		Maxcut = -56.24219389383628.
# 		Optimizer Time: 4.356310129165649 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.356310129165649 seconds.
#
#
# Test Case 2:
# ----------------
#
# [[0. 3. 5. 4. 5. 5. 3. 1.]
#  [3. 3. 1. 3. 5. 5. 4. 4.]
#  [5. 1. 2. 4. 1. 4. 4. 0.]
#  [4. 3. 4. 2. 2. 3. 3. 2.]
#  [5. 5. 1. 2. 2. 4. 2. 3.]
#  [5. 5. 4. 3. 4. 4. 5. 5.]
#  [3. 4. 4. 3. 2. 5. 0. 2.]
#  [1. 4. 0. 2. 3. 5. 2. 3.]]
#
# 	Brute Force
# 		Solution = 00011110 [11100001].
# 		Maxcut = 59.0.
# 		Time: 0.018491577997338027 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010011 [01101100].
# 		Maxcut = -56.73004252328035.
# 		Optimizer Time: 5.054754018783569 seconds.
# 		Compmute Minimum Eigenvalue Time: 5.054754018783569 seconds.
#
#
# Test Case 3:
# ------------------
#
# [[0. 2. 1. 3. 3. 3. 1. 2.]
#  [2. 5. 2. 3. 3. 5. 4. 4.]
#  [1. 2. 2. 5. 4. 3. 2. 1.]
#  [3. 3. 5. 5. 5. 4. 3. 3.]
#  [3. 3. 4. 5. 2. 1. 3. 4.]
#  [3. 5. 3. 4. 1. 3. 3. 2.]
#  [1. 4. 2. 3. 3. 3. 4. 5.]
#  [2. 4. 1. 3. 4. 2. 5. 4.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 53.0.
# 		Time: 0.018487482011551037 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11100010 [00011101].
# 		Maxcut = -52.87806335952111.
# 		Optimizer Time: 4.523433208465576 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.523433208465576 seconds.
#
#
# Test Case 4:
# --------------------
#
# [[0. 4. 3. 1. 3. 1. 5. 5.]
#  [4. 5. 2. 5. 1. 4. 1. 1.]
#  [3. 2. 4. 3. 2. 3. 1. 4.]
#  [1. 5. 3. 3. 1. 2. 0. 2.]
#  [3. 1. 2. 1. 0. 2. 3. 4.]
#  [1. 4. 3. 2. 2. 0. 1. 1.]
#  [5. 1. 1. 0. 3. 1. 5. 5.]
#  [5. 1. 4. 2. 4. 1. 5. 2.]]
#
# 	Brute Force
# 		Solution = 01101010 [10010101].
# 		Maxcut = 48.0.
# 		Time: 0.01768230300513096 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -47.77976443676466.
# 		Optimizer Time: 4.248456239700317 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.248456239700317 seconds.
#
#
# Test Case 5:
# ----------------------
#
# [[3. 2. 1. 4. 1. 2. 2. 2.]
#  [2. 4. 0. 4. 3. 3. 1. 5.]
#  [1. 0. 4. 1. 4. 3. 4. 3.]
#  [4. 4. 1. 5. 2. 4. 3. 4.]
#  [1. 3. 4. 2. 3. 1. 5. 5.]
#  [2. 3. 3. 4. 1. 0. 5. 3.]
#  [2. 1. 4. 3. 5. 5. 3. 3.]
#  [2. 5. 3. 4. 5. 3. 3. 2.]]
#
# 	Brute Force
# 		Solution = 01110010 [10001101].
# 		Maxcut = 53.0.
# 		Time: 0.018293133995030075 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001100 [00110011].
# 		Maxcut = -49.794676491039894.
# 		Optimizer Time: 4.439590930938721 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.439590930938721 seconds.
#
#
# Test Case 6:
# ------------------------
#
# [[4. 1. 4. 1. 5. 1. 3. 3.]
#  [1. 5. 1. 3. 3. 0. 3. 1.]
#  [4. 1. 5. 2. 2. 3. 3. 1.]
#  [1. 3. 2. 5. 5. 3. 2. 4.]
#  [5. 3. 2. 5. 3. 3. 2. 5.]
#  [1. 0. 3. 3. 3. 5. 4. 3.]
#  [3. 3. 3. 2. 2. 4. 4. 3.]
#  [3. 1. 1. 4. 5. 3. 3. 3.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 49.0.
# 		Time: 0.018590834020869806 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00101011 [11010100].
# 		Maxcut = -48.440301873170014.
# 		Optimizer Time: 4.699171304702759 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.699171304702759 seconds.
#
#
# Test Case 7:
# --------------------------
#
# [[2. 1. 3. 5. 2. 3. 2. 0.]
#  [1. 1. 1. 1. 3. 4. 1. 3.]
#  [3. 1. 0. 4. 1. 1. 2. 4.]
#  [5. 1. 4. 4. 5. 4. 1. 2.]
#  [2. 3. 1. 5. 2. 3. 4. 1.]
#  [3. 4. 1. 4. 3. 0. 5. 5.]
#  [2. 1. 2. 1. 4. 5. 5. 2.]
#  [0. 3. 4. 2. 1. 5. 2. 4.]]
#
# 	Brute Force
# 		Solution = 00101100 [11010011].
# 		Maxcut = 50.0.
# 		Time: 0.02056015099515207 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101100 [01010011].
# 		Maxcut = -49.93640066453579.
# 		Optimizer Time: 4.656516075134277 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.656516075134277 seconds.
#
#
# Test Case 8:
# ----------------------------
#
# [[4. 4. 1. 3. 5. 3. 4. 4.]
#  [4. 1. 2. 4. 4. 3. 2. 1.]
#  [1. 2. 3. 2. 1. 4. 1. 5.]
#  [3. 4. 2. 1. 5. 5. 4. 3.]
#  [5. 4. 1. 5. 2. 2. 4. 3.]
#  [3. 3. 4. 5. 2. 1. 3. 3.]
#  [4. 2. 1. 4. 4. 3. 0. 2.]
#  [4. 1. 5. 3. 3. 3. 2. 1.]]
#
# 	Brute Force
# 		Solution = 10111000 [01000111].
# 		Maxcut = 56.0.
# 		Time: 0.018175268021877855 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010011 [10101100].
# 		Maxcut = -54.92604353752793.
# 		Optimizer Time: 4.397218227386475 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.397218227386475 seconds.
#
#
# Test Case 9:
# ------------------------------
#
# [[3. 1. 4. 1. 1. 5. 2. 1.]
#  [1. 5. 4. 1. 2. 4. 5. 2.]
#  [4. 4. 2. 3. 2. 1. 3. 5.]
#  [1. 1. 3. 5. 4. 4. 3. 1.]
#  [1. 2. 2. 4. 4. 3. 2. 4.]
#  [5. 4. 1. 4. 3. 4. 1. 1.]
#  [2. 5. 3. 3. 2. 1. 1. 1.]
#  [1. 2. 5. 1. 4. 1. 1. 1.]]
#
# 	Brute Force
# 		Solution = 00101110 [11010001].
# 		Maxcut = 52.0.
# 		Time: 0.016113318997668102 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101010 [01010101].
# 		Maxcut = -43.95055553311976.
# 		Optimizer Time: 4.233300685882568 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.233300685882568 seconds.
#
#
# Test Case 10:
# --------------------------------
#
# [[4. 3. 4. 2. 5. 2. 3. 1.]
#  [3. 0. 1. 5. 5. 5. 2. 3.]
#  [4. 1. 3. 3. 1. 3. 5. 3.]
#  [2. 5. 3. 4. 3. 1. 3. 2.]
#  [5. 5. 1. 3. 4. 5. 1. 1.]
#  [2. 5. 3. 1. 5. 5. 2. 1.]
#  [3. 2. 5. 3. 1. 2. 0. 2.]
#  [1. 3. 3. 2. 1. 1. 2. 3.]]
#
# 	Brute Force
# 		Solution = 01101010 [10010101].
# 		Maxcut = 53.0.
# 		Time: 0.017535046994453296 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -52.73628851482262.
# 		Optimizer Time: 4.401956796646118 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.401956796646118 seconds.
#
#
# Test Case 11:
# ----------------------------------
#
# [[0. 4. 2. 5. 5. 1. 4. 1.]
#  [4. 2. 2. 5. 4. 4. 0. 4.]
#  [2. 2. 5. 2. 4. 3. 1. 3.]
#  [5. 5. 2. 1. 2. 3. 5. 3.]
#  [5. 4. 4. 2. 2. 5. 3. 5.]
#  [1. 4. 3. 3. 5. 3. 3. 4.]
#  [4. 0. 1. 5. 3. 3. 4. 3.]
#  [1. 4. 3. 3. 5. 4. 3. 0.]]
#
# 	Brute Force
# 		Solution = 01101010 [10010101].
# 		Maxcut = 59.0.
# 		Time: 0.018439272011164576 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -58.90850359135487.
# 		Optimizer Time: 4.596900939941406 seconds.
# 		Compmute Minimum Eigenvalue Time: 4.596900939941406 seconds.
#
#
# Test Case 12:
# ------------------------------------
#
# [[0. 4. 1. 4. 2. 2. 2. 3.]
#  [4. 3. 2. 3. 1. 4. 2. 5.]
#  [1. 2. 5. 3. 4. 2. 5. 3.]
#  [4. 3. 3. 3. 5. 0. 5. 3.]
#  [2. 1. 4. 5. 3. 1. 2. 4.]
#  [2. 4. 2. 0. 1. 2. 3. 1.]
#  [2. 2. 5. 5. 2. 3. 0. 3.]
#  [3. 5. 3. 3. 4. 1. 3. 3.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 54.0.
# 		Time: 0.01795407698955387 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001010 [00110101].
# 		Maxcut = -53.12325617322786.
# 		Optimizer Time: 7.235523462295532 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.235523462295532 seconds.
#
#
# Test Case 13:
# --------------------------------------
#
# [[3. 4. 4. 5. 4. 4. 1. 4.]
#  [4. 1. 4. 1. 5. 3. 2. 3.]
#  [4. 4. 2. 2. 4. 0. 3. 2.]
#  [5. 1. 2. 0. 4. 1. 1. 3.]
#  [4. 5. 4. 4. 3. 1. 1. 2.]
#  [4. 3. 0. 1. 1. 5. 2. 5.]
#  [1. 2. 3. 1. 1. 2. 3. 3.]
#  [4. 3. 2. 3. 2. 5. 3. 2.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 52.0.
# 		Time: 0.016835338989039883 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01110001 [10001110].
# 		Maxcut = -49.58641033021143.
# 		Optimizer Time: 8.118932247161865 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.118932247161865 seconds.
#
#
# Test Case 14:
# ----------------------------------------
#
# [[0. 3. 1. 2. 1. 5. 5. 4.]
#  [3. 0. 4. 0. 3. 1. 3. 5.]
#  [1. 4. 1. 2. 3. 5. 5. 5.]
#  [2. 0. 2. 0. 5. 1. 5. 2.]
#  [1. 3. 3. 5. 4. 4. 5. 2.]
#  [5. 1. 5. 1. 4. 5. 1. 3.]
#  [5. 3. 5. 5. 5. 1. 4. 2.]
#  [4. 5. 5. 2. 2. 3. 2. 2.]]
#
# 	Brute Force
# 		Solution = 01010110 [10101001].
# 		Maxcut = 60.0.
# 		Time: 0.021778901980724186 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010110 [10101001].
# 		Maxcut = -59.88686225662956.
# 		Optimizer Time: 6.786592483520508 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.786592483520508 seconds.
#
#
# Test Case 15:
# ------------------------------------------
#
# [[3. 3. 3. 3. 1. 5. 0. 1.]
#  [3. 1. 3. 4. 1. 3. 5. 3.]
#  [3. 3. 0. 3. 5. 4. 5. 1.]
#  [3. 4. 3. 1. 3. 4. 3. 5.]
#  [1. 1. 5. 3. 3. 2. 2. 3.]
#  [5. 3. 4. 4. 2. 5. 3. 3.]
#  [0. 5. 5. 3. 2. 3. 0. 1.]
#  [1. 3. 1. 5. 3. 3. 1. 4.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 54.0.
# 		Time: 0.0444933749968186 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100011 [01011100].
# 		Maxcut = -53.92199387776193.
# 		Optimizer Time: 7.510110378265381 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.510110378265381 seconds.
#
#
# Test Case 16:
# --------------------------------------------
#
# [[0. 5. 5. 5. 5. 2. 3. 1.]
#  [5. 0. 1. 2. 2. 1. 2. 3.]
#  [5. 1. 4. 5. 1. 4. 1. 4.]
#  [5. 2. 5. 4. 1. 1. 1. 2.]
#  [5. 2. 1. 1. 5. 3. 4. 5.]
#  [2. 1. 4. 1. 3. 1. 0. 4.]
#  [3. 2. 1. 1. 4. 0. 3. 5.]
#  [1. 3. 4. 2. 5. 4. 5. 2.]]
#
# 	Brute Force
# 		Solution = 01101010 [10010101].
# 		Maxcut = 52.0.
# 		Time: 0.022614988003624603 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01101001 [10010110].
# 		Maxcut = -49.828849587157386.
# 		Optimizer Time: 7.738015174865723 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.738015174865723 seconds.
#
#
# Test Case 17:
# ----------------------------------------------
#
# [[5. 1. 5. 5. 2. 4. 5. 5.]
#  [1. 2. 2. 5. 3. 2. 4. 1.]
#  [5. 2. 5. 5. 5. 5. 3. 3.]
#  [5. 5. 5. 4. 1. 4. 2. 1.]
#  [2. 3. 5. 1. 2. 2. 4. 2.]
#  [4. 2. 5. 4. 2. 4. 3. 3.]
#  [5. 4. 3. 2. 4. 3. 4. 3.]
#  [5. 1. 3. 1. 2. 3. 3. 5.]]
#
# 	Brute Force
# 		Solution = 11001100 [00110011].
# 		Maxcut = 59.0.
# 		Time: 0.020499415026279166 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100011 [10011100].
# 		Maxcut = -55.91611738933218.
# 		Optimizer Time: 5.760503053665161 seconds.
# 		Compmute Minimum Eigenvalue Time: 5.760503053665161 seconds.
#
#
# Test Case 18:
# ------------------------------------------------
#
# [[5. 4. 1. 4. 1. 0. 4. 5.]
#  [4. 2. 3. 5. 4. 5. 1. 2.]
#  [1. 3. 5. 1. 1. 2. 5. 2.]
#  [4. 5. 1. 5. 5. 1. 5. 4.]
#  [1. 4. 1. 5. 4. 4. 4. 3.]
#  [0. 5. 2. 1. 4. 4. 2. 3.]
#  [4. 1. 5. 5. 4. 2. 0. 2.]
#  [5. 2. 2. 4. 3. 3. 2. 2.]]
#
# 	Brute Force
# 		Solution = 10110100 [01001011].
# 		Maxcut = 58.0.
# 		Time: 0.0328249650192447 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110100 [01001011].
# 		Maxcut = -57.865699257135354.
# 		Optimizer Time: 7.989754915237427 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.989754915237427 seconds.
#
#
# Test Case 19:
# --------------------------------------------------
#
# [[3. 5. 5. 5. 5. 3. 3. 1.]
#  [5. 1. 3. 3. 3. 4. 4. 3.]
#  [5. 3. 3. 1. 4. 1. 3. 2.]
#  [5. 3. 1. 0. 1. 1. 2. 3.]
#  [5. 3. 4. 1. 3. 1. 4. 1.]
#  [3. 4. 1. 1. 1. 0. 5. 2.]
#  [3. 4. 3. 2. 4. 5. 3. 2.]
#  [1. 3. 2. 3. 1. 2. 2. 5.]]
#
# 	Brute Force
# 		Solution = 00111100 [11000011].
# 		Maxcut = 53.0.
# 		Time: 0.02859326798352413 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000010 [00111101].
# 		Maxcut = -50.87996811442804.
# 		Optimizer Time: 7.41924524307251 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.41924524307251 seconds.
#
#
# Test Case 20:
# ----------------------------------------------------
#
# [[1. 1. 2. 3. 1. 2. 4. 1.]
#  [1. 3. 5. 2. 5. 4. 1. 2.]
#  [2. 5. 2. 5. 5. 2. 4. 4.]
#  [3. 2. 5. 5. 2. 3. 1. 5.]
#  [1. 5. 5. 2. 4. 0. 3. 4.]
#  [2. 4. 2. 3. 0. 5. 5. 1.]
#  [4. 1. 4. 1. 3. 5. 3. 1.]
#  [1. 2. 4. 5. 4. 1. 1. 1.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 54.0.
# 		Time: 0.01973964599892497 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010011 [10101100].
# 		Maxcut = -53.90349348342399.
# 		Optimizer Time: 8.287391662597656 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.287391662597656 seconds.
#
#
# Test Case 21:
# ------------------------------------------------------
#
# [[0. 2. 1. 4. 3. 2. 2. 5.]
#  [2. 0. 5. 5. 2. 4. 0. 3.]
#  [1. 5. 3. 4. 1. 3. 1. 1.]
#  [4. 5. 4. 0. 0. 3. 4. 2.]
#  [3. 2. 1. 0. 1. 3. 1. 1.]
#  [2. 4. 3. 3. 3. 2. 2. 5.]
#  [2. 0. 1. 4. 1. 2. 2. 0.]
#  [5. 3. 1. 2. 1. 5. 0. 3.]]
#
# 	Brute Force
# 		Solution = 11000110 [00111001].
# 		Maxcut = 48.0.
# 		Time: 0.01777505499194376 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00111001 [11000110].
# 		Maxcut = -46.613344037790824.
# 		Optimizer Time: 8.329994916915894 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.329994916915894 seconds.
#
#
# Test Case 22:
# --------------------------------------------------------
#
# [[1. 5. 3. 1. 5. 2. 5. 5.]
#  [5. 1. 1. 1. 4. 2. 1. 1.]
#  [3. 1. 2. 1. 2. 4. 2. 3.]
#  [1. 1. 1. 3. 2. 2. 5. 2.]
#  [5. 4. 2. 2. 1. 5. 3. 3.]
#  [2. 2. 4. 2. 5. 3. 4. 4.]
#  [5. 1. 2. 5. 3. 4. 0. 1.]
#  [5. 1. 3. 2. 3. 4. 1. 1.]]
#
# 	Brute Force
# 		Solution = 10010100 [01101011].
# 		Maxcut = 53.0.
# 		Time: 0.027816464978968725 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110100 [01001011].
# 		Maxcut = -52.924915181742485.
# 		Optimizer Time: 7.493319988250732 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.493319988250732 seconds.
#
#
# Test Case 23:
# ----------------------------------------------------------
#
# [[3. 4. 3. 5. 3. 2. 4. 5.]
#  [4. 1. 1. 5. 1. 2. 1. 5.]
#  [3. 1. 2. 3. 1. 1. 5. 4.]
#  [5. 5. 3. 3. 1. 1. 5. 5.]
#  [3. 1. 1. 1. 4. 3. 3. 4.]
#  [2. 2. 1. 1. 3. 3. 3. 3.]
#  [4. 1. 5. 5. 3. 3. 5. 1.]
#  [5. 5. 4. 5. 4. 3. 1. 0.]]
#
# 	Brute Force
# 		Solution = 01111100 [10000011].
# 		Maxcut = 55.0.
# 		Time: 0.016840336989844218 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01000011 [10111100].
# 		Maxcut = -53.944246023661904.
# 		Optimizer Time: 7.156220436096191 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.156220436096191 seconds.
#
#
# Test Case 24:
# ------------------------------------------------------------
#
# [[2. 5. 3. 5. 1. 4. 5. 3.]
#  [5. 3. 1. 1. 5. 1. 3. 2.]
#  [3. 1. 4. 5. 3. 1. 3. 1.]
#  [5. 1. 5. 2. 5. 5. 3. 2.]
#  [1. 5. 3. 5. 1. 1. 2. 1.]
#  [4. 1. 1. 5. 1. 4. 4. 3.]
#  [5. 3. 3. 3. 2. 4. 5. 4.]
#  [3. 2. 1. 2. 1. 3. 4. 4.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 54.0.
# 		Time: 0.017697588016744703 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100110 [10011001].
# 		Maxcut = -51.20803702008756.
# 		Optimizer Time: 5.9970009326934814 seconds.
# 		Compmute Minimum Eigenvalue Time: 5.9970009326934814 seconds.
#
#
# Test Case 25:
# --------------------------------------------------------------
#
# [[4. 2. 0. 2. 3. 2. 4. 5.]
#  [2. 4. 2. 3. 3. 1. 1. 3.]
#  [0. 2. 2. 3. 4. 5. 2. 5.]
#  [2. 3. 3. 4. 1. 3. 3. 2.]
#  [3. 3. 4. 1. 4. 4. 5. 3.]
#  [2. 1. 5. 3. 4. 2. 5. 2.]
#  [4. 1. 2. 3. 5. 5. 5. 3.]
#  [5. 3. 5. 2. 3. 2. 3. 0.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 55.0.
# 		Time: 0.018142753979191184 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11100010 [00011101].
# 		Maxcut = -54.94097771027852.
# 		Optimizer Time: 8.23614239692688 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.23614239692688 seconds.
#
#
# Test Case 26:
# ----------------------------------------------------------------
#
# [[0. 3. 1. 3. 3. 4. 1. 4.]
#  [3. 3. 1. 4. 4. 4. 1. 5.]
#  [1. 1. 4. 0. 3. 5. 4. 5.]
#  [3. 4. 0. 0. 2. 2. 4. 4.]
#  [3. 4. 3. 2. 1. 4. 5. 2.]
#  [4. 4. 5. 2. 4. 3. 5. 3.]
#  [1. 1. 4. 4. 5. 5. 1. 0.]
#  [4. 5. 5. 4. 2. 3. 0. 4.]]
#
# 	Brute Force
# 		Solution = 11100010 [00011101].
# 		Maxcut = 58.0.
# 		Time: 0.04282019700622186 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01000111 [10111000].
# 		Maxcut = -55.86899250295889.
# 		Optimizer Time: 7.190231084823608 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.190231084823608 seconds.
#
#
# Test Case 27:
# ------------------------------------------------------------------
#
# [[4. 4. 1. 2. 3. 1. 2. 5.]
#  [4. 2. 2. 5. 5. 1. 3. 1.]
#  [1. 2. 3. 2. 5. 3. 2. 3.]
#  [2. 5. 2. 1. 4. 2. 3. 3.]
#  [3. 5. 5. 4. 3. 2. 5. 4.]
#  [1. 1. 3. 2. 2. 3. 4. 4.]
#  [2. 3. 2. 3. 5. 4. 2. 5.]
#  [5. 1. 3. 3. 4. 4. 5. 3.]]
#
# 	Brute Force
# 		Solution = 10110010 [01001101].
# 		Maxcut = 57.0.
# 		Time: 0.01864964299602434 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110010 [01001101].
# 		Maxcut = -56.88363124410192.
# 		Optimizer Time: 6.808229446411133 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.808229446411133 seconds.
#
#
# Test Case 28:
# --------------------------------------------------------------------
#
# [[5. 4. 5. 2. 3. 4. 4. 4.]
#  [4. 0. 3. 5. 4. 3. 5. 3.]
#  [5. 3. 1. 2. 1. 2. 4. 2.]
#  [2. 5. 2. 3. 5. 5. 2. 1.]
#  [3. 4. 1. 5. 1. 3. 4. 4.]
#  [4. 3. 2. 5. 3. 2. 4. 2.]
#  [4. 5. 4. 2. 4. 4. 3. 4.]
#  [4. 3. 2. 1. 4. 2. 4. 3.]]
#
# 	Brute Force
# 		Solution = 01101100 [10010011].
# 		Maxcut = 61.0.
# 		Time: 0.034965388011187315 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00110101 [11001010].
# 		Maxcut = -56.13809992611421.
# 		Optimizer Time: 7.456023216247559 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.456023216247559 seconds.
#
#
# Test Case 29:
# ----------------------------------------------------------------------
#
# [[3. 5. 4. 2. 1. 5. 1. 2.]
#  [5. 5. 2. 5. 3. 2. 2. 3.]
#  [4. 2. 3. 5. 1. 2. 5. 1.]
#  [2. 5. 5. 0. 2. 4. 3. 1.]
#  [1. 3. 1. 2. 0. 4. 1. 3.]
#  [5. 2. 2. 4. 4. 1. 5. 1.]
#  [1. 2. 5. 3. 1. 5. 1. 3.]
#  [2. 3. 1. 1. 3. 1. 3. 0.]]
#
# 	Brute Force
# 		Solution = 10011010 [01100101].
# 		Maxcut = 57.0.
# 		Time: 0.01781968801515177 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10011010 [01100101].
# 		Maxcut = -56.65513230017345.
# 		Optimizer Time: 9.018033742904663 seconds.
# 		Compmute Minimum Eigenvalue Time: 9.018033742904663 seconds.
#
#
# Test Case 30:
# ------------------------------------------------------------------------
#
# [[1. 4. 4. 4. 3. 4. 1. 4.]
#  [4. 4. 2. 5. 3. 2. 0. 2.]
#  [4. 2. 3. 3. 0. 3. 5. 1.]
#  [4. 5. 3. 5. 2. 5. 3. 5.]
#  [3. 3. 0. 2. 5. 4. 4. 2.]
#  [4. 2. 3. 5. 4. 3. 1. 2.]
#  [1. 0. 5. 3. 4. 1. 4. 2.]
#  [4. 2. 1. 5. 2. 2. 2. 4.]]
#
# 	Brute Force
# 		Solution = 10111000 [01000111].
# 		Maxcut = 55.0.
# 		Time: 0.018467255984432995 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01101001 [10010110].
# 		Maxcut = -51.73596572489821.
# 		Optimizer Time: 8.098172903060913 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.098172903060913 seconds.
#
#
# Test Case 31:
# --------------------------------------------------------------------------
#
# [[3. 1. 2. 5. 1. 3. 4. 4.]
#  [1. 1. 2. 0. 3. 5. 5. 3.]
#  [2. 2. 1. 1. 4. 2. 4. 1.]
#  [5. 0. 1. 2. 3. 4. 1. 2.]
#  [1. 3. 4. 3. 2. 4. 5. 4.]
#  [3. 5. 2. 4. 4. 0. 3. 2.]
#  [4. 5. 4. 1. 5. 3. 5. 5.]
#  [4. 3. 1. 2. 4. 2. 5. 4.]]
#
# 	Brute Force
# 		Solution = 10001110 [01110001].
# 		Maxcut = 54.0.
# 		Time: 0.022043256991310045 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001000 [00110111].
# 		Maxcut = -52.75731893431332.
# 		Optimizer Time: 8.063439846038818 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.063439846038818 seconds.
#
#
# Test Case 32:
# ----------------------------------------------------------------------------
#
# [[1. 4. 1. 0. 5. 5. 5. 4.]
#  [4. 0. 3. 4. 1. 1. 3. 5.]
#  [1. 3. 4. 2. 5. 5. 5. 2.]
#  [0. 4. 2. 5. 1. 4. 3. 5.]
#  [5. 1. 5. 1. 1. 3. 2. 5.]
#  [5. 1. 5. 4. 3. 1. 4. 5.]
#  [5. 3. 5. 3. 2. 4. 4. 5.]
#  [4. 5. 2. 5. 5. 5. 5. 3.]]
#
# 	Brute Force
# 		Solution = 01001110 [10110001].
# 		Maxcut = 69.0.
# 		Time: 0.017380669014528394 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10011010 [01100101].
# 		Maxcut = -60.06256620756848.
# 		Optimizer Time: 7.978389501571655 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.978389501571655 seconds.
#
#
# Test Case 33:
# ------------------------------------------------------------------------------
#
# [[2. 4. 1. 3. 3. 2. 4. 3.]
#  [4. 4. 5. 4. 3. 5. 0. 5.]
#  [1. 5. 1. 2. 1. 1. 2. 3.]
#  [3. 4. 2. 4. 1. 2. 5. 5.]
#  [3. 3. 1. 1. 0. 3. 3. 4.]
#  [2. 5. 1. 2. 3. 2. 1. 4.]
#  [4. 0. 2. 5. 3. 1. 3. 4.]
#  [3. 5. 3. 5. 4. 4. 4. 3.]]
#
# 	Brute Force
# 		Solution = 10111100 [01000011].
# 		Maxcut = 55.0.
# 		Time: 0.017661566991591826 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100101 [01011010].
# 		Maxcut = -52.957759862681556.
# 		Optimizer Time: 6.8639068603515625 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.8639068603515625 seconds.
#
#
# Test Case 34:
# --------------------------------------------------------------------------------
#
# [[4. 5. 0. 5. 1. 3. 2. 1.]
#  [5. 5. 4. 3. 3. 1. 1. 4.]
#  [0. 4. 1. 1. 3. 2. 3. 5.]
#  [5. 3. 1. 0. 5. 2. 4. 3.]
#  [1. 3. 3. 5. 4. 5. 4. 1.]
#  [3. 1. 2. 2. 5. 1. 0. 5.]
#  [2. 1. 3. 4. 4. 0. 5. 2.]
#  [1. 4. 5. 3. 1. 5. 2. 1.]]
#
# 	Brute Force
# 		Solution = 01010110 [10101001].
# 		Maxcut = 56.0.
# 		Time: 0.019716968992725015 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010110 [10101001].
# 		Maxcut = -54.85548223057083.
# 		Optimizer Time: 8.279384851455688 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.279384851455688 seconds.
#
#
# Test Case 35:
# ----------------------------------------------------------------------------------
#
# [[3. 5. 3. 2. 5. 1. 5. 2.]
#  [5. 5. 1. 4. 1. 1. 4. 4.]
#  [3. 1. 2. 0. 3. 2. 4. 3.]
#  [2. 4. 0. 4. 3. 3. 3. 2.]
#  [5. 1. 3. 3. 5. 3. 4. 3.]
#  [1. 1. 2. 3. 3. 3. 1. 0.]
#  [5. 4. 4. 3. 4. 1. 4. 2.]
#  [2. 4. 3. 2. 3. 0. 2. 1.]]
#
# 	Brute Force
# 		Solution = 01111000 [10000111].
# 		Maxcut = 51.0.
# 		Time: 0.018189694004831836 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -46.916459752671784.
# 		Optimizer Time: 7.540016412734985 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.540016412734985 seconds.
#
#
# Test Case 36:
# ------------------------------------------------------------------------------------
#
# [[2. 2. 1. 2. 1. 2. 5. 5.]
#  [2. 5. 5. 5. 2. 1. 1. 4.]
#  [1. 5. 5. 4. 5. 5. 4. 3.]
#  [2. 5. 4. 2. 3. 4. 5. 3.]
#  [1. 2. 5. 3. 3. 2. 4. 4.]
#  [2. 1. 5. 4. 2. 3. 4. 5.]
#  [5. 1. 4. 5. 4. 4. 4. 4.]
#  [5. 4. 3. 3. 4. 5. 4. 2.]]
#
# 	Brute Force
# 		Solution = 01001110 [10110001].
# 		Maxcut = 63.0.
# 		Time: 0.021133835980435833 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00110011 [11001100].
# 		Maxcut = -61.88584818767328.
# 		Optimizer Time: 7.254878997802734 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.254878997802734 seconds.
#
#
# Test Case 37:
# --------------------------------------------------------------------------------------
#
# [[5. 4. 3. 4. 5. 4. 1. 5.]
#  [4. 3. 5. 3. 4. 4. 2. 1.]
#  [3. 5. 4. 4. 4. 3. 3. 2.]
#  [4. 3. 4. 0. 5. 1. 2. 1.]
#  [5. 4. 4. 5. 2. 0. 3. 2.]
#  [4. 4. 3. 1. 0. 0. 4. 3.]
#  [1. 2. 3. 2. 3. 4. 3. 1.]
#  [5. 1. 2. 1. 2. 3. 1. 5.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 54.0.
# 		Time: 0.018458767008269206 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00101101 [11010010].
# 		Maxcut = -52.83015579379426.
# 		Optimizer Time: 6.470560789108276 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.470560789108276 seconds.
#
#
# Test Case 38:
# ----------------------------------------------------------------------------------------
#
# [[3. 4. 1. 1. 3. 3. 2. 5.]
#  [4. 2. 4. 5. 1. 3. 3. 1.]
#  [1. 4. 0. 4. 4. 4. 1. 1.]
#  [1. 5. 4. 2. 4. 4. 4. 5.]
#  [3. 1. 4. 4. 2. 1. 4. 5.]
#  [3. 3. 4. 4. 1. 3. 2. 2.]
#  [2. 3. 1. 4. 4. 2. 0. 5.]
#  [5. 1. 1. 5. 5. 2. 5. 0.]]
#
# 	Brute Force
# 		Solution = 10110010 [01001101].
# 		Maxcut = 60.0.
# 		Time: 0.025868371012620628 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01101001 [10010110].
# 		Maxcut = -53.88860060901304.
# 		Optimizer Time: 7.994989633560181 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.994989633560181 seconds.
#
#
# Test Case 39:
# ------------------------------------------------------------------------------------------
#
# [[4. 1. 5. 2. 4. 2. 4. 4.]
#  [1. 0. 5. 4. 5. 5. 4. 2.]
#  [5. 5. 1. 5. 5. 0. 3. 3.]
#  [2. 4. 5. 1. 5. 1. 2. 3.]
#  [4. 5. 5. 5. 4. 2. 5. 4.]
#  [2. 5. 0. 1. 2. 4. 5. 3.]
#  [4. 4. 3. 2. 5. 5. 5. 1.]
#  [4. 2. 3. 3. 4. 3. 1. 4.]]
#
# 	Brute Force
# 		Solution = 00101100 [11010011].
# 		Maxcut = 60.0.
# 		Time: 0.018007591977948323 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00101100 [11010011].
# 		Maxcut = -59.922172081896704.
# 		Optimizer Time: 7.085209369659424 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.085209369659424 seconds.
#
#
# Test Case 40:
# --------------------------------------------------------------------------------------------
#
# [[4. 4. 2. 1. 3. 2. 3. 4.]
#  [4. 3. 2. 5. 5. 3. 0. 2.]
#  [2. 2. 3. 4. 1. 3. 1. 5.]
#  [1. 5. 4. 1. 1. 3. 3. 4.]
#  [3. 5. 1. 1. 4. 2. 4. 4.]
#  [2. 3. 3. 3. 2. 1. 4. 2.]
#  [3. 0. 1. 3. 4. 4. 2. 4.]
#  [4. 2. 5. 4. 4. 2. 4. 1.]]
#
# 	Brute Force
# 		Solution = 10011100 [01100011].
# 		Maxcut = 55.0.
# 		Time: 0.018773203977616504 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100011 [10011100].
# 		Maxcut = -54.755320588216954.
# 		Optimizer Time: 7.168487310409546 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.168487310409546 seconds.
#
#
# Test Case 41:
# ----------------------------------------------------------------------------------------------
#
# [[0. 5. 4. 1. 3. 4. 2. 4.]
#  [5. 2. 4. 5. 0. 2. 5. 3.]
#  [4. 4. 0. 3. 5. 5. 2. 4.]
#  [1. 5. 3. 1. 2. 3. 3. 3.]
#  [3. 0. 5. 2. 1. 3. 5. 4.]
#  [4. 2. 5. 3. 3. 1. 2. 2.]
#  [2. 5. 2. 3. 5. 2. 3. 1.]
#  [4. 3. 4. 3. 4. 2. 1. 0.]]
#
# 	Brute Force
# 		Solution = 10110010 [01001101].
# 		Maxcut = 60.0.
# 		Time: 0.026345196005422622 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010011 [01101100].
# 		Maxcut = -56.44489695933926.
# 		Optimizer Time: 7.8036675453186035 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.8036675453186035 seconds.
#
#
# Test Case 42:
# ------------------------------------------------------------------------------------------------
#
# [[5. 2. 5. 1. 1. 1. 4. 3.]
#  [2. 1. 2. 3. 5. 1. 3. 3.]
#  [5. 2. 3. 4. 1. 3. 3. 5.]
#  [1. 3. 4. 3. 4. 2. 4. 4.]
#  [1. 5. 1. 4. 0. 2. 0. 4.]
#  [1. 1. 3. 2. 2. 2. 5. 5.]
#  [4. 3. 3. 4. 0. 5. 5. 2.]
#  [3. 3. 5. 4. 4. 5. 2. 4.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 57.0.
# 		Time: 0.04057313399971463 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00101011 [11010100].
# 		Maxcut = -56.92783715472058.
# 		Optimizer Time: 7.387521028518677 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.387521028518677 seconds.
#
#
# Test Case 43:
# --------------------------------------------------------------------------------------------------
#
# [[1. 5. 4. 5. 1. 1. 2. 3.]
#  [5. 1. 5. 1. 3. 2. 5. 3.]
#  [4. 5. 4. 1. 1. 2. 4. 1.]
#  [5. 1. 1. 0. 4. 1. 4. 4.]
#  [1. 3. 1. 4. 2. 4. 1. 1.]
#  [1. 2. 2. 1. 4. 1. 1. 4.]
#  [2. 5. 4. 4. 1. 1. 1. 1.]
#  [3. 3. 1. 4. 1. 4. 1. 5.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 53.0.
# 		Time: 0.024156984000001103 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010100 [10101011].
# 		Maxcut = -51.26354718575798.
# 		Optimizer Time: 7.902358293533325 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.902358293533325 seconds.
#
#
# Test Case 44:
# ----------------------------------------------------------------------------------------------------
#
# [[4. 1. 1. 5. 5. 1. 1. 1.]
#  [1. 4. 0. 4. 4. 1. 2. 3.]
#  [1. 0. 4. 2. 3. 3. 3. 1.]
#  [5. 4. 2. 0. 1. 2. 4. 5.]
#  [5. 4. 3. 1. 4. 5. 2. 4.]
#  [1. 1. 3. 2. 5. 5. 2. 2.]
#  [1. 2. 3. 4. 2. 2. 3. 1.]
#  [1. 3. 1. 5. 4. 2. 1. 3.]]
#
# 	Brute Force
# 		Solution = 00111000 [11000111].
# 		Maxcut = 48.0.
# 		Time: 0.016526415973203257 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01111000 [10000111].
# 		Maxcut = -46.80723615773994.
# 		Optimizer Time: 6.958660364151001 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.958660364151001 seconds.
#
#
# Test Case 45:
# ------------------------------------------------------------------------------------------------------
#
# [[1. 4. 2. 2. 3. 2. 5. 2.]
#  [4. 3. 2. 1. 5. 3. 3. 5.]
#  [2. 2. 0. 5. 5. 2. 2. 1.]
#  [2. 1. 5. 3. 5. 2. 1. 1.]
#  [3. 5. 5. 5. 0. 2. 4. 5.]
#  [2. 3. 2. 2. 2. 3. 5. 3.]
#  [5. 3. 2. 1. 4. 5. 3. 5.]
#  [2. 5. 1. 1. 5. 3. 5. 1.]]
#
# 	Brute Force
# 		Solution = 01110010 [10001101].
# 		Maxcut = 56.0.
# 		Time: 0.017234440019819885 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010010 [10101101].
# 		Maxcut = -54.82328319416819.
# 		Optimizer Time: 7.021245718002319 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.021245718002319 seconds.
#
#
# Test Case 46:
# --------------------------------------------------------------------------------------------------------
#
# [[2. 2. 5. 3. 3. 1. 2. 2.]
#  [2. 5. 4. 1. 4. 1. 2. 2.]
#  [5. 4. 1. 4. 3. 1. 2. 4.]
#  [3. 1. 4. 5. 5. 1. 1. 1.]
#  [3. 4. 3. 5. 2. 5. 5. 2.]
#  [1. 1. 1. 1. 5. 1. 5. 3.]
#  [2. 2. 2. 1. 5. 5. 5. 5.]
#  [2. 2. 4. 1. 2. 3. 5. 5.]]
#
# 	Brute Force
# 		Solution = 00101010 [11010101].
# 		Maxcut = 52.0.
# 		Time: 0.01644954297807999 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11010101 [00101010].
# 		Maxcut = -51.520482239911715.
# 		Optimizer Time: 7.272073268890381 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.272073268890381 seconds.
#
#
# Test Case 47:
# ----------------------------------------------------------------------------------------------------------
#
# [[1. 5. 4. 3. 2. 2. 1. 1.]
#  [5. 4. 3. 4. 3. 4. 0. 4.]
#  [4. 3. 5. 5. 3. 4. 4. 3.]
#  [3. 4. 5. 2. 3. 2. 4. 2.]
#  [2. 3. 3. 3. 3. 2. 5. 5.]
#  [2. 4. 4. 2. 2. 0. 4. 3.]
#  [1. 0. 4. 4. 5. 4. 2. 3.]
#  [1. 4. 3. 2. 5. 3. 3. 4.]]
#
# 	Brute Force
# 		Solution = 10011100 [01100011].
# 		Maxcut = 57.0.
# 		Time: 0.017190440004924312 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -56.838761653178565.
# 		Optimizer Time: 7.311186790466309 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.311186790466309 seconds.
#
#
# Test Case 48:
# ------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 4. 1. 1. 1. 3. 5.]
#  [1. 3. 1. 1. 1. 1. 3. 3.]
#  [4. 1. 4. 1. 2. 2. 5. 1.]
#  [1. 1. 1. 3. 2. 3. 5. 4.]
#  [1. 1. 2. 2. 5. 1. 1. 5.]
#  [1. 1. 2. 3. 1. 5. 3. 1.]
#  [3. 3. 5. 5. 1. 3. 5. 2.]
#  [5. 3. 1. 4. 5. 1. 2. 4.]]
#
# 	Brute Force
# 		Solution = 11011000 [00100111].
# 		Maxcut = 43.0.
# 		Time: 0.016789517976576462 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10011010 [01100101].
# 		Maxcut = -41.84209867485703.
# 		Optimizer Time: 7.5242486000061035 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.5242486000061035 seconds.
#
#
# Test Case 49:
# --------------------------------------------------------------------------------------------------------------
#
# [[4. 2. 3. 3. 3. 2. 5. 2.]
#  [2. 2. 3. 3. 1. 1. 3. 3.]
#  [3. 3. 5. 5. 2. 1. 3. 4.]
#  [3. 3. 5. 2. 4. 1. 3. 4.]
#  [3. 1. 2. 4. 0. 2. 2. 2.]
#  [2. 1. 1. 1. 2. 0. 4. 5.]
#  [5. 3. 3. 3. 2. 4. 0. 5.]
#  [2. 3. 4. 4. 2. 5. 5. 0.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 51.0.
# 		Time: 0.018548738007666543 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -49.929149430306495.
# 		Optimizer Time: 7.638551712036133 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.638551712036133 seconds.
#
#
# Test Case 50:
# ----------------------------------------------------------------------------------------------------------------
#
# [[0. 1. 5. 1. 1. 5. 1. 3.]
#  [1. 2. 1. 1. 5. 1. 1. 4.]
#  [5. 1. 2. 1. 3. 3. 2. 1.]
#  [1. 1. 1. 1. 3. 3. 3. 4.]
#  [1. 5. 3. 3. 4. 3. 1. 1.]
#  [5. 1. 3. 3. 3. 5. 5. 3.]
#  [1. 1. 2. 3. 1. 5. 1. 1.]
#  [3. 4. 1. 4. 1. 3. 1. 0.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 49.0.
# 		Time: 0.017554542020661756 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11010100 [00101011].
# 		Maxcut = -45.93951176194762.
# 		Optimizer Time: 8.562495231628418 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.562495231628418 seconds.
#
#
# Test Case 51:
# ------------------------------------------------------------------------------------------------------------------
#
# [[3. 5. 3. 2. 3. 1. 2. 3.]
#  [5. 2. 1. 1. 5. 1. 3. 2.]
#  [3. 1. 1. 4. 3. 1. 3. 5.]
#  [2. 1. 4. 0. 5. 4. 5. 2.]
#  [3. 5. 3. 5. 4. 4. 5. 2.]
#  [1. 1. 1. 4. 4. 0. 2. 3.]
#  [2. 3. 3. 5. 5. 2. 0. 4.]
#  [3. 2. 5. 2. 2. 3. 4. 5.]]
#
# 	Brute Force
# 		Solution = 01100110 [10011001].
# 		Maxcut = 56.0.
# 		Time: 0.017537854000693187 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010101 [10101010].
# 		Maxcut = -51.96621319494966.
# 		Optimizer Time: 8.624057531356812 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.624057531356812 seconds.
#
#
# Test Case 52:
# --------------------------------------------------------------------------------------------------------------------
#
# [[2. 4. 3. 5. 2. 0. 5. 1.]
#  [4. 3. 5. 5. 1. 5. 2. 3.]
#  [3. 5. 2. 3. 2. 5. 2. 5.]
#  [5. 5. 3. 0. 5. 3. 3. 2.]
#  [2. 1. 2. 5. 1. 5. 4. 4.]
#  [0. 5. 5. 3. 5. 2. 1. 2.]
#  [5. 2. 2. 3. 4. 1. 0. 0.]
#  [1. 3. 5. 2. 4. 2. 0. 1.]]
#
# 	Brute Force
# 		Solution = 11101000 [00010111].
# 		Maxcut = 59.0.
# 		Time: 0.01662298198789358 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -57.613472118430984.
# 		Optimizer Time: 7.581459999084473 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.581459999084473 seconds.
#
#
# Test Case 53:
# ----------------------------------------------------------------------------------------------------------------------
#
# [[1. 1. 5. 1. 4. 3. 4. 1.]
#  [1. 4. 0. 2. 5. 4. 5. 1.]
#  [5. 0. 0. 2. 2. 0. 2. 4.]
#  [1. 2. 2. 2. 4. 2. 2. 5.]
#  [4. 5. 2. 4. 4. 3. 5. 1.]
#  [3. 4. 0. 2. 3. 1. 3. 4.]
#  [4. 5. 2. 2. 5. 3. 2. 3.]
#  [1. 1. 4. 5. 1. 4. 3. 3.]]
#
# 	Brute Force
# 		Solution = 00110110 [11001001].
# 		Maxcut = 54.0.
# 		Time: 0.019071026996243745 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001001 [00110110].
# 		Maxcut = -53.96857649354695.
# 		Optimizer Time: 7.6943628787994385 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.6943628787994385 seconds.
#
#
# Test Case 54:
# ------------------------------------------------------------------------------------------------------------------------
#
# [[4. 4. 1. 1. 5. 5. 4. 2.]
#  [4. 5. 4. 3. 5. 1. 5. 5.]
#  [1. 4. 3. 5. 5. 2. 2. 3.]
#  [1. 3. 5. 1. 4. 5. 2. 5.]
#  [5. 5. 5. 4. 0. 5. 4. 1.]
#  [5. 1. 2. 5. 5. 0. 4. 3.]
#  [4. 5. 2. 2. 4. 4. 0. 3.]
#  [2. 5. 3. 5. 1. 3. 3. 4.]]
#
# 	Brute Force
# 		Solution = 10110010 [01001101].
# 		Maxcut = 63.0.
# 		Time: 0.018811715999618173 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010110 [10101001].
# 		Maxcut = -60.846389106882214.
# 		Optimizer Time: 6.7207417488098145 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.7207417488098145 seconds.
#
#
# Test Case 55:
# --------------------------------------------------------------------------------------------------------------------------
#
# [[5. 1. 2. 3. 1. 1. 3. 4.]
#  [1. 0. 3. 3. 5. 1. 1. 2.]
#  [2. 3. 5. 3. 4. 4. 3. 5.]
#  [3. 3. 3. 1. 1. 5. 3. 2.]
#  [1. 5. 4. 1. 2. 4. 5. 5.]
#  [1. 1. 4. 5. 4. 0. 5. 5.]
#  [3. 1. 3. 3. 5. 5. 4. 1.]
#  [4. 2. 5. 2. 5. 5. 1. 3.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 57.0.
# 		Time: 0.016723028995329514 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000110 [00111001].
# 		Maxcut = -52.82162707467011.
# 		Optimizer Time: 6.805561304092407 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.805561304092407 seconds.
#
#
# Test Case 56:
# ----------------------------------------------------------------------------------------------------------------------------
#
# [[1. 5. 1. 2. 5. 3. 2. 4.]
#  [5. 0. 3. 5. 4. 3. 2. 1.]
#  [1. 3. 3. 1. 5. 3. 1. 1.]
#  [2. 5. 1. 0. 2. 3. 4. 4.]
#  [5. 4. 5. 2. 2. 3. 5. 3.]
#  [3. 3. 3. 3. 3. 2. 1. 5.]
#  [2. 2. 1. 4. 5. 1. 0. 3.]
#  [4. 1. 1. 4. 3. 5. 3. 3.]]
#
# 	Brute Force
# 		Solution = 10011100 [01100011].
# 		Maxcut = 55.0.
# 		Time: 0.01986954899621196 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001001 [10110110].
# 		Maxcut = -54.5663970769396.
# 		Optimizer Time: 7.357659578323364 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.357659578323364 seconds.
#
#
# Test Case 57:
# ------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 4. 4. 3. 1. 4. 5. 4.]
#  [4. 1. 5. 5. 1. 3. 4. 4.]
#  [4. 5. 2. 4. 5. 5. 3. 3.]
#  [3. 5. 4. 0. 1. 4. 3. 4.]
#  [1. 1. 5. 1. 5. 5. 0. 1.]
#  [4. 3. 5. 4. 5. 3. 1. 2.]
#  [5. 4. 3. 3. 0. 1. 3. 3.]
#  [4. 4. 3. 4. 1. 2. 3. 4.]]
#
# 	Brute Force
# 		Solution = 11011000 [00100111].
# 		Maxcut = 59.0.
# 		Time: 0.024778917024377733 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10011001 [01100110].
# 		Maxcut = -55.821148991947005.
# 		Optimizer Time: 7.959972620010376 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.959972620010376 seconds.
#
#
# Test Case 58:
# --------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 2. 2. 3. 4. 2. 2. 0.]
#  [2. 0. 1. 2. 4. 3. 4. 4.]
#  [2. 1. 2. 1. 5. 2. 4. 5.]
#  [3. 2. 1. 2. 2. 2. 4. 4.]
#  [4. 4. 5. 2. 0. 2. 3. 2.]
#  [2. 3. 2. 2. 2. 0. 5. 3.]
#  [2. 4. 4. 4. 3. 5. 5. 1.]
#  [0. 4. 5. 4. 2. 3. 1. 1.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 55.0.
# 		Time: 0.01715546500054188 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01110100 [10001011].
# 		Maxcut = -54.857015260943136.
# 		Optimizer Time: 7.232647895812988 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.232647895812988 seconds.
#
#
# Test Case 59:
# ----------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 2. 1. 1. 1. 4. 4. 4.]
#  [2. 0. 1. 3. 3. 1. 3. 1.]
#  [1. 1. 4. 1. 3. 2. 3. 4.]
#  [1. 3. 1. 1. 2. 2. 2. 5.]
#  [1. 3. 3. 2. 0. 3. 3. 3.]
#  [4. 1. 2. 2. 3. 2. 3. 2.]
#  [4. 3. 3. 2. 3. 3. 0. 1.]
#  [4. 1. 4. 5. 3. 2. 1. 0.]]
#
# 	Brute Force
# 		Solution = 10111000 [01000111].
# 		Maxcut = 48.0.
# 		Time: 0.016697106009814888 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01000111 [10111000].
# 		Maxcut = -47.770239955694024.
# 		Optimizer Time: 6.424010753631592 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.424010753631592 seconds.
#
#
# Test Case 60:
# ------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 5. 2. 1. 2. 2. 2. 5.]
#  [5. 0. 5. 5. 5. 1. 5. 2.]
#  [2. 5. 5. 5. 4. 3. 1. 4.]
#  [1. 5. 5. 1. 3. 2. 5. 2.]
#  [2. 5. 4. 3. 0. 1. 1. 1.]
#  [2. 1. 3. 2. 1. 1. 4. 5.]
#  [2. 5. 1. 5. 1. 4. 5. 5.]
#  [5. 2. 4. 2. 1. 5. 5. 3.]]
#
# 	Brute Force
# 		Solution = 10101010 [01010101].
# 		Maxcut = 59.0.
# 		Time: 0.017097639007261023 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010101 [10101010].
# 		Maxcut = -58.5580746950565.
# 		Optimizer Time: 9.754551410675049 seconds.
# 		Compmute Minimum Eigenvalue Time: 9.754551410675049 seconds.
#
#
# Test Case 61:
# --------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 2. 4. 2. 5. 2. 4. 2.]
#  [2. 4. 4. 1. 3. 3. 4. 5.]
#  [4. 4. 4. 1. 3. 1. 1. 5.]
#  [2. 1. 1. 1. 4. 5. 3. 5.]
#  [5. 3. 3. 4. 1. 4. 3. 4.]
#  [2. 3. 1. 5. 4. 1. 1. 3.]
#  [4. 4. 1. 3. 3. 1. 0. 5.]
#  [2. 5. 5. 5. 4. 3. 5. 2.]]
#
# 	Brute Force
# 		Solution = 00101110 [11010001].
# 		Maxcut = 59.0.
# 		Time: 0.031908434990327805 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10001101 [01110010].
# 		Maxcut = -54.920027869637664.
# 		Optimizer Time: 7.821565628051758 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.821565628051758 seconds.
#
#
# Test Case 62:
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 1. 1. 3. 3. 4. 1. 1.]
#  [1. 2. 3. 1. 2. 5. 4. 2.]
#  [1. 3. 5. 1. 3. 2. 1. 4.]
#  [3. 1. 1. 3. 5. 1. 5. 1.]
#  [3. 2. 3. 5. 4. 4. 4. 3.]
#  [4. 5. 2. 1. 4. 1. 1. 1.]
#  [1. 4. 1. 5. 4. 1. 2. 2.]
#  [1. 2. 4. 1. 3. 1. 2. 5.]]
#
# 	Brute Force
# 		Solution = 00110110 [11001001].
# 		Maxcut = 46.0.
# 		Time: 0.020594718982465565 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00110110 [11001001].
# 		Maxcut = -45.91772770542948.
# 		Optimizer Time: 6.775485277175903 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.775485277175903 seconds.
#
#
# Test Case 63:
# ------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 5. 1. 5. 4. 3. 4. 3.]
#  [5. 1. 0. 2. 3. 4. 3. 3.]
#  [1. 0. 4. 2. 0. 5. 1. 5.]
#  [5. 2. 2. 4. 1. 3. 3. 0.]
#  [4. 3. 0. 1. 3. 3. 1. 3.]
#  [3. 4. 5. 3. 3. 0. 2. 2.]
#  [4. 3. 1. 3. 1. 2. 2. 1.]
#  [3. 3. 5. 0. 3. 2. 1. 1.]]
#
# 	Brute Force
# 		Solution = 01111000 [10000111].
# 		Maxcut = 49.0.
# 		Time: 0.017592746997252107 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101010 [01010101].
# 		Maxcut = -47.198178368951815.
# 		Optimizer Time: 8.418692111968994 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.418692111968994 seconds.
#
#
# Test Case 64:
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 4. 2. 4. 4. 3. 4. 1.]
#  [4. 3. 2. 2. 4. 2. 5. 5.]
#  [2. 2. 2. 5. 1. 3. 5. 4.]
#  [4. 2. 5. 0. 0. 2. 2. 5.]
#  [4. 4. 1. 0. 0. 3. 2. 5.]
#  [3. 2. 3. 2. 3. 4. 2. 2.]
#  [4. 5. 5. 2. 2. 2. 1. 3.]
#  [1. 5. 4. 5. 5. 2. 3. 2.]]
#
# 	Brute Force
# 		Solution = 01111000 [10000111].
# 		Maxcut = 57.0.
# 		Time: 0.01783850701758638 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100101 [01011010].
# 		Maxcut = -55.92250665883139.
# 		Optimizer Time: 7.548203706741333 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.548203706741333 seconds.
#
#
# Test Case 65:
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 4. 1. 1. 5. 5. 2. 3.]
#  [4. 5. 5. 5. 3. 4. 2. 1.]
#  [1. 5. 0. 5. 2. 3. 5. 1.]
#  [1. 5. 5. 0. 4. 4. 4. 1.]
#  [5. 3. 2. 4. 5. 4. 3. 5.]
#  [5. 4. 3. 4. 4. 2. 3. 1.]
#  [2. 2. 5. 4. 3. 3. 0. 5.]
#  [3. 1. 1. 1. 5. 1. 5. 5.]]
#
# 	Brute Force
# 		Solution = 01001110 [10110001].
# 		Maxcut = 60.0.
# 		Time: 0.01772487798007205 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110010 [01001101].
# 		Maxcut = -55.750254975611675.
# 		Optimizer Time: 8.020672798156738 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.020672798156738 seconds.
#
#
# Test Case 66:
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 4. 0. 1. 2. 1. 0. 2.]
#  [4. 0. 2. 5. 1. 5. 4. 1.]
#  [0. 2. 1. 4. 1. 3. 4. 2.]
#  [1. 5. 4. 3. 5. 2. 5. 2.]
#  [2. 1. 1. 5. 3. 3. 4. 1.]
#  [1. 5. 3. 2. 3. 3. 4. 2.]
#  [0. 4. 4. 5. 4. 4. 2. 1.]
#  [2. 1. 2. 2. 1. 2. 1. 5.]]
#
# 	Brute Force
# 		Solution = 10010110 [01101001].
# 		Maxcut = 50.0.
# 		Time: 0.017526690993690863 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001011 [10110100].
# 		Maxcut = -47.86110738442661.
# 		Optimizer Time: 6.707550287246704 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.707550287246704 seconds.
#
#
# Test Case 67:
# --------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 1. 5. 5. 1. 3. 1. 2.]
#  [1. 2. 1. 2. 1. 1. 4. 5.]
#  [5. 1. 1. 4. 5. 1. 1. 5.]
#  [5. 2. 4. 0. 3. 5. 0. 2.]
#  [1. 1. 5. 3. 5. 4. 2. 2.]
#  [3. 1. 1. 5. 4. 3. 1. 2.]
#  [1. 4. 1. 0. 2. 1. 5. 4.]
#  [2. 5. 5. 2. 2. 2. 4. 4.]]
#
# 	Brute Force
# 		Solution = 01100110 [10011001].
# 		Maxcut = 49.0.
# 		Time: 0.018325310986256227 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100110 [10011001].
# 		Maxcut = -48.90997874999022.
# 		Optimizer Time: 7.663817644119263 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.663817644119263 seconds.
#
#
# Test Case 68:
# ----------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 4. 1. 5. 1. 4. 1.]
#  [5. 0. 5. 4. 4. 2. 2. 2.]
#  [4. 5. 4. 4. 3. 5. 2. 4.]
#  [1. 4. 4. 1. 3. 3. 1. 4.]
#  [5. 4. 3. 3. 1. 5. 3. 3.]
#  [1. 2. 5. 3. 5. 3. 3. 1.]
#  [4. 2. 2. 1. 3. 3. 3. 4.]
#  [1. 2. 4. 4. 3. 1. 4. 3.]]
#
# 	Brute Force
# 		Solution = 00111010 [11000101].
# 		Maxcut = 60.0.
# 		Time: 0.018777232005959377 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000101 [00111010].
# 		Maxcut = -59.90471384624891.
# 		Optimizer Time: 7.925795555114746 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.925795555114746 seconds.
#
#
# Test Case 69:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 4. 3. 1. 4. 5. 0. 3.]
#  [4. 5. 3. 3. 4. 1. 2. 4.]
#  [3. 3. 4. 5. 5. 3. 3. 3.]
#  [1. 3. 5. 3. 5. 2. 1. 5.]
#  [4. 4. 5. 5. 3. 1. 5. 5.]
#  [5. 1. 3. 2. 1. 5. 3. 2.]
#  [0. 2. 3. 1. 5. 3. 1. 2.]
#  [3. 4. 3. 5. 5. 2. 2. 4.]]
#
# 	Brute Force
# 		Solution = 01101100 [10010011].
# 		Maxcut = 58.0.
# 		Time: 0.01771604298846796 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01100101 [10011010].
# 		Maxcut = -54.75542077857485.
# 		Optimizer Time: 7.112698793411255 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.112698793411255 seconds.
#
#
# Test Case 70:
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 5. 2. 5. 3. 2. 4. 4.]
#  [5. 4. 0. 2. 5. 3. 2. 3.]
#  [2. 0. 1. 2. 1. 2. 4. 5.]
#  [5. 2. 2. 3. 1. 3. 2. 4.]
#  [3. 5. 1. 1. 3. 3. 2. 4.]
#  [2. 3. 2. 3. 3. 2. 5. 3.]
#  [4. 2. 4. 2. 2. 5. 4. 3.]
#  [4. 3. 5. 4. 4. 3. 3. 5.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 55.0.
# 		Time: 0.018951844976982102 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01111010 [10000101].
# 		Maxcut = -53.91163882888169.
# 		Optimizer Time: 8.73288869857788 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.73288869857788 seconds.
#
#
# Test Case 71:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 2. 2. 5. 2. 1. 3.]
#  [2. 5. 0. 2. 4. 4. 3. 2.]
#  [2. 0. 5. 3. 1. 2. 1. 5.]
#  [2. 2. 3. 3. 2. 4. 5. 2.]
#  [5. 4. 1. 2. 4. 5. 1. 3.]
#  [2. 4. 2. 4. 5. 5. 1. 0.]
#  [1. 3. 1. 5. 1. 1. 1. 4.]
#  [3. 2. 5. 2. 3. 0. 4. 2.]]
#
# 	Brute Force
# 		Solution = 01111000 [10000111].
# 		Maxcut = 48.0.
# 		Time: 0.017419707000954077 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010101 [01101010].
# 		Maxcut = -47.86731155334998.
# 		Optimizer Time: 8.185609102249146 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.185609102249146 seconds.
#
#
# Test Case 72:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 5. 1. 1. 4. 5. 5. 1.]
#  [5. 3. 3. 4. 1. 1. 5. 5.]
#  [1. 3. 2. 5. 2. 5. 3. 3.]
#  [1. 4. 5. 4. 1. 0. 3. 1.]
#  [4. 1. 2. 1. 5. 4. 2. 1.]
#  [5. 1. 5. 0. 4. 0. 4. 5.]
#  [5. 5. 3. 3. 2. 4. 0. 5.]
#  [1. 5. 3. 1. 1. 5. 5. 5.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 56.0.
# 		Time: 0.022274026996456087 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101001 [01010110].
# 		Maxcut = -55.84952931749683.
# 		Optimizer Time: 7.22591757774353 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.22591757774353 seconds.
#
#
# Test Case 73:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 1. 4. 5. 3. 3. 2. 4.]
#  [1. 0. 1. 1. 1. 5. 2. 4.]
#  [4. 1. 1. 4. 3. 1. 3. 5.]
#  [5. 1. 4. 3. 4. 2. 1. 3.]
#  [3. 1. 3. 4. 2. 1. 2. 5.]
#  [3. 5. 1. 2. 1. 2. 4. 4.]
#  [2. 2. 3. 1. 2. 4. 4. 1.]
#  [4. 4. 5. 3. 5. 4. 1. 5.]]
#
# 	Brute Force
# 		Solution = 10101100 [01010011].
# 		Maxcut = 52.0.
# 		Time: 0.018549553002230823 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01010011 [10101100].
# 		Maxcut = -51.3254530310505.
# 		Optimizer Time: 8.12970781326294 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.12970781326294 seconds.
#
#
# Test Case 74:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 1. 4. 4. 3. 1. 2. 2.]
#  [1. 4. 1. 3. 0. 5. 1. 3.]
#  [4. 1. 0. 5. 2. 5. 2. 1.]
#  [4. 3. 5. 4. 2. 5. 5. 4.]
#  [3. 0. 2. 2. 5. 4. 3. 2.]
#  [1. 5. 5. 5. 4. 4. 0. 5.]
#  [2. 1. 2. 5. 3. 0. 3. 1.]
#  [2. 3. 1. 4. 2. 5. 1. 1.]]
#
# 	Brute Force
# 		Solution = 01111000 [10000111].
# 		Maxcut = 52.0.
# 		Time: 0.018112713005393744 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00110001 [11001110].
# 		Maxcut = -45.54938444428443.
# 		Optimizer Time: 6.478302240371704 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.478302240371704 seconds.
#
#
# Test Case 75:
# ...
#  [4. 5. 1. 2. 3. 2. 1. 4.]
#  [5. 2. 2. 3. 5. 1. 5. 5.]
#  [5. 2. 1. 2. 1. 0. 3. 1.]
#  [4. 5. 5. 1. 5. 3. 2. 4.]
#  [3. 2. 3. 4. 5. 1. 4. 2.]]
#
# 	Brute Force
# 		Solution = 01101100 [10010011].
# 		Maxcut = 56.0.
# 		Time: 0.028200082015246153 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110010 [01001101].
# 		Maxcut = -55.90155590394133.
# 		Optimizer Time: 6.74913477897644 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.74913477897644 seconds.
#
#
# Test Case 79:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 2. 5. 0. 1. 4. 3. 2.]
#  [2. 1. 5. 4. 2. 1. 1. 4.]
#  [5. 5. 1. 2. 4. 1. 4. 1.]
#  [0. 4. 2. 2. 3. 2. 5. 2.]
#  [1. 2. 4. 3. 2. 4. 1. 3.]
#  [4. 1. 1. 2. 4. 2. 3. 2.]
#  [3. 1. 4. 5. 1. 3. 3. 4.]
#  [2. 4. 1. 2. 3. 2. 4. 5.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 55.0.
# 		Time: 0.016700306994607672 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001010 [00110101].
# 		Maxcut = -54.91793526402075.
# 		Optimizer Time: 7.897055387496948 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.897055387496948 seconds.
#
#
# Test Case 80:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 3. 4. 5. 5. 3. 3. 2.]
#  [3. 5. 5. 2. 2. 4. 0. 1.]
#  [4. 5. 4. 1. 5. 3. 3. 2.]
#  [5. 2. 1. 2. 2. 2. 5. 5.]
#  [5. 2. 5. 2. 0. 2. 2. 3.]
#  [3. 4. 3. 2. 2. 1. 1. 4.]
#  [3. 0. 3. 5. 2. 1. 2. 5.]
#  [2. 1. 2. 5. 3. 4. 5. 4.]]
#
# 	Brute Force
# 		Solution = 00111100 [11000011].
# 		Maxcut = 55.0.
# 		Time: 0.016925965988775715 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000110 [00111001].
# 		Maxcut = -52.031642051392325.
# 		Optimizer Time: 8.892058849334717 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.892058849334717 seconds.
#
#
# Test Case 81:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 3. 1. 3. 1. 3. 4. 3.]
#  [3. 3. 3. 3. 1. 5. 3. 1.]
#  [1. 3. 5. 5. 5. 3. 2. 4.]
#  [3. 3. 5. 0. 2. 2. 3. 4.]
#  [1. 1. 5. 2. 1. 1. 5. 3.]
#  [3. 5. 3. 2. 1. 0. 3. 2.]
#  [4. 3. 2. 3. 5. 3. 3. 5.]
#  [3. 1. 4. 4. 3. 2. 5. 3.]]
#
# 	Brute Force
# 		Solution = 10011100 [01100011].
# 		Maxcut = 53.0.
# 		Time: 0.017645022977376357 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10100110 [01011001].
# 		Maxcut = -52.86416590942829.
# 		Optimizer Time: 7.551576614379883 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.551576614379883 seconds.
#
#
# Test Case 82:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 3. 1. 4. 4. 5. 3. 5.]
#  [3. 1. 0. 2. 3. 4. 3. 2.]
#  [1. 0. 1. 1. 1. 2. 4. 1.]
#  [4. 2. 1. 5. 3. 5. 3. 1.]
#  [4. 3. 1. 3. 3. 5. 4. 2.]
#  [5. 4. 2. 5. 5. 3. 2. 5.]
#  [3. 3. 4. 3. 4. 2. 0. 3.]
#  [5. 2. 1. 1. 2. 5. 3. 5.]]
#
# 	Brute Force
# 		Solution = 10000110 [01111001].
# 		Maxcut = 55.0.
# 		Time: 0.03286300000036135 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10000110 [01111001].
# 		Maxcut = -54.897808339123436.
# 		Optimizer Time: 7.613083362579346 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.613083362579346 seconds.
#
#
# Test Case 83:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 3. 1. 2. 4. 1. 2. 5.]
#  [3. 2. 5. 4. 4. 2. 4. 4.]
#  [1. 5. 5. 5. 4. 5. 4. 1.]
#  [2. 4. 5. 5. 5. 3. 3. 3.]
#  [4. 4. 4. 5. 0. 4. 1. 1.]
#  [1. 2. 5. 3. 4. 5. 1. 5.]
#  [2. 4. 4. 3. 1. 1. 2. 4.]
#  [5. 4. 1. 3. 1. 5. 4. 0.]]
#
# 	Brute Force
# 		Solution = 11010100 [00101011].
# 		Maxcut = 60.0.
# 		Time: 0.016629669000394642 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110001 [01001110].
# 		Maxcut = -56.93056122646202.
# 		Optimizer Time: 8.595648288726807 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.595648288726807 seconds.
#
#
# Test Case 84:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 3. 2. 5. 4. 3. 1. 5.]
#  [3. 4. 5. 4. 2. 2. 1. 3.]
#  [2. 5. 0. 5. 2. 5. 5. 1.]
#  [5. 4. 5. 3. 4. 1. 2. 3.]
#  [4. 2. 2. 4. 2. 4. 0. 2.]
#  [3. 2. 5. 1. 4. 5. 1. 2.]
#  [1. 1. 5. 2. 0. 1. 3. 1.]
#  [5. 3. 1. 3. 2. 2. 1. 2.]]
#
# 	Brute Force
# 		Solution = 01010110 [10101001].
# 		Maxcut = 51.0.
# 		Time: 0.017592554999282584 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101001 [01010110].
# 		Maxcut = -50.94123865581123.
# 		Optimizer Time: 7.974964380264282 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.974964380264282 seconds.
#
#
# Test Case 85:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 5. 3. 3. 4. 2. 2. 5.]
#  [5. 2. 4. 2. 4. 4. 4. 1.]
#  [3. 4. 0. 2. 5. 5. 5. 1.]
#  [3. 2. 2. 1. 2. 5. 4. 5.]
#  [4. 4. 5. 2. 3. 1. 2. 1.]
#  [2. 4. 5. 5. 1. 2. 2. 5.]
#  [2. 4. 5. 4. 2. 2. 0. 5.]
#  [5. 1. 1. 5. 1. 5. 5. 5.]]
#
# 	Brute Force
# 		Solution = 10001110 [01110001].
# 		Maxcut = 65.0.
# 		Time: 0.016467987996293232 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10001110 [01110001].
# 		Maxcut = -64.59426033826185.
# 		Optimizer Time: 5.817726373672485 seconds.
# 		Compmute Minimum Eigenvalue Time: 5.817726373672485 seconds.
#
#
# Test Case 86:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 5. 4. 1. 5. 4. 1. 2.]
#  [5. 4. 2. 4. 2. 2. 5. 3.]
#  [4. 2. 5. 4. 4. 2. 3. 4.]
#  [1. 4. 4. 0. 3. 5. 3. 1.]
#  [5. 2. 4. 3. 0. 1. 2. 3.]
#  [4. 2. 2. 5. 1. 4. 3. 4.]
#  [1. 5. 3. 3. 2. 3. 0. 1.]
#  [2. 3. 4. 1. 3. 4. 1. 2.]]
#
# 	Brute Force
# 		Solution = 01101100 [10010011].
# 		Maxcut = 61.0.
# 		Time: 0.018259562988532707 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10010011 [01101100].
# 		Maxcut = -60.87106619021854.
# 		Optimizer Time: 5.267033815383911 seconds.
# 		Compmute Minimum Eigenvalue Time: 5.267033815383911 seconds.
#
#
# Test Case 87:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 2. 5. 3. 1. 3. 5. 4.]
#  [2. 4. 5. 4. 5. 3. 2. 5.]
#  [5. 5. 2. 1. 1. 3. 5. 4.]
#  [3. 4. 1. 1. 1. 4. 2. 3.]
#  [1. 5. 1. 1. 1. 2. 4. 4.]
#  [3. 3. 3. 4. 2. 3. 2. 2.]
#  [5. 2. 5. 2. 4. 2. 2. 4.]
#  [4. 5. 4. 3. 4. 2. 4. 3.]]
#
# 	Brute Force
# 		Solution = 10111000 [01000111].
# 		Maxcut = 59.0.
# 		Time: 0.034221557987621054 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10111001 [01000110].
# 		Maxcut = -54.43902816310861.
# 		Optimizer Time: 7.935166835784912 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.935166835784912 seconds.
#
#
# Test Case 88:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 1. 1. 3. 3. 3. 1. 4.]
#  [1. 3. 4. 2. 3. 3. 4. 1.]
#  [1. 4. 5. 3. 2. 2. 4. 3.]
#  [3. 2. 3. 1. 2. 1. 5. 1.]
#  [3. 3. 2. 2. 3. 3. 1. 1.]
#  [3. 3. 2. 1. 3. 2. 5. 5.]
#  [1. 4. 4. 5. 1. 5. 1. 1.]
#  [4. 1. 3. 1. 1. 5. 1. 5.]]
#
# 	Brute Force
# 		Solution = 10110100 [01001011].
# 		Maxcut = 48.0.
# 		Time: 0.01976786900195293 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001011 [10110100].
# 		Maxcut = -47.70150400067608.
# 		Optimizer Time: 7.304424047470093 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.304424047470093 seconds.
#
#
# Test Case 89:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 3. 2. 4. 2. 4. 1.]
#  [5. 5. 4. 5. 4. 1. 1. 1.]
#  [3. 4. 0. 0. 2. 4. 3. 5.]
#  [2. 5. 0. 3. 4. 4. 5. 4.]
#  [4. 4. 2. 4. 2. 1. 5. 5.]
#  [2. 1. 4. 4. 1. 0. 2. 3.]
#  [4. 1. 3. 5. 5. 2. 5. 3.]
#  [1. 1. 5. 4. 5. 3. 3. 1.]]
#
# 	Brute Force
# 		Solution = 10111000 [01000111].
# 		Maxcut = 61.0.
# 		Time: 0.038089131005108356 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01001110 [10110001].
# 		Maxcut = -56.85582674870143.
# 		Optimizer Time: 7.7161407470703125 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.7161407470703125 seconds.
#
#
# Test Case 90:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 3. 2. 5. 4. 5. 4. 2.]
#  [3. 4. 3. 4. 4. 5. 1. 2.]
#  [2. 3. 2. 4. 4. 2. 1. 3.]
#  [5. 4. 4. 2. 2. 2. 1. 4.]
#  [4. 4. 4. 2. 4. 5. 4. 5.]
#  [5. 5. 2. 2. 5. 2. 1. 5.]
#  [4. 1. 1. 1. 4. 1. 1. 1.]
#  [2. 2. 3. 4. 5. 5. 1. 5.]]
#
# 	Brute Force
# 		Solution = 00011110 [11100001].
# 		Maxcut = 58.0.
# 		Time: 0.017104742000810802 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11100001 [00011110].
# 		Maxcut = -57.91549876835404.
# 		Optimizer Time: 8.409106969833374 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.409106969833374 seconds.
#
#
# Test Case 91:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[4. 5. 1. 5. 2. 4. 1. 3.]
#  [5. 3. 4. 1. 3. 2. 2. 1.]
#  [1. 4. 2. 1. 2. 2. 5. 4.]
#  [5. 1. 1. 4. 2. 1. 2. 4.]
#  [2. 3. 2. 2. 2. 3. 4. 1.]
#  [4. 2. 2. 1. 3. 0. 3. 4.]
#  [1. 2. 5. 2. 4. 3. 5. 1.]
#  [3. 1. 4. 4. 1. 4. 1. 5.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 50.0.
# 		Time: 0.021012726007029414 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10101001 [01010110].
# 		Maxcut = -48.76354022059709.
# 		Optimizer Time: 8.281752347946167 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.281752347946167 seconds.
#
#
# Test Case 92:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[0. 1. 2. 1. 1. 1. 4. 2.]
#  [1. 0. 2. 5. 5. 5. 3. 4.]
#  [2. 2. 1. 1. 1. 4. 2. 1.]
#  [1. 5. 1. 3. 5. 3. 1. 2.]
#  [1. 5. 1. 5. 1. 2. 4. 1.]
#  [1. 5. 4. 3. 2. 0. 3. 1.]
#  [4. 3. 2. 1. 4. 3. 2. 5.]
#  [2. 4. 1. 2. 1. 1. 5. 5.]]
#
# 	Brute Force
# 		Solution = 01110010 [10001101].
# 		Maxcut = 50.0.
# 		Time: 0.01711790999979712 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000101 [00111010].
# 		Maxcut = -44.34086951672309.
# 		Optimizer Time: 6.334462404251099 seconds.
# 		Compmute Minimum Eigenvalue Time: 6.334462404251099 seconds.
#
#
# Test Case 93:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 0. 3. 5. 1. 0. 1. 1.]
#  [0. 2. 1. 2. 3. 2. 4. 4.]
#  [3. 1. 3. 3. 2. 2. 2. 2.]
#  [5. 2. 3. 2. 1. 2. 1. 4.]
#  [1. 3. 2. 1. 5. 5. 2. 5.]
#  [0. 2. 2. 2. 5. 1. 3. 5.]
#  [1. 4. 2. 1. 2. 3. 5. 2.]
#  [1. 4. 2. 4. 5. 5. 2. 0.]]
#
# 	Brute Force
# 		Solution = 11100100 [00011011].
# 		Maxcut = 45.0.
# 		Time: 0.017735424014972523 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11000101 [00111010].
# 		Maxcut = -44.954913717524036.
# 		Optimizer Time: 7.867553472518921 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.867553472518921 seconds.
#
#
# Test Case 94:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 5. 2. 4. 1. 4. 3. 0.]
#  [5. 1. 4. 2. 2. 3. 3. 2.]
#  [2. 4. 2. 1. 5. 1. 1. 3.]
#  [4. 2. 1. 1. 2. 3. 5. 2.]
#  [1. 2. 5. 2. 2. 3. 5. 4.]
#  [4. 3. 1. 3. 3. 3. 3. 4.]
#  [3. 3. 1. 5. 5. 3. 4. 4.]
#  [0. 2. 3. 2. 4. 4. 4. 1.]]
#
# 	Brute Force
# 		Solution = 01011100 [10100011].
# 		Maxcut = 53.0.
# 		Time: 0.016869623999809846 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 11001001 [00110110].
# 		Maxcut = -52.747879935832195.
# 		Optimizer Time: 7.463699579238892 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.463699579238892 seconds.
#
#
# Test Case 95:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 5. 4. 1. 5. 3. 1. 5.]
#  [5. 5. 4. 4. 1. 5. 0. 5.]
#  [4. 4. 5. 3. 3. 2. 3. 1.]
#  [1. 4. 3. 0. 1. 1. 2. 4.]
#  [5. 1. 3. 1. 5. 2. 0. 5.]
#  [3. 5. 2. 1. 2. 3. 4. 4.]
#  [1. 0. 3. 2. 0. 4. 5. 3.]
#  [5. 5. 1. 4. 5. 4. 3. 4.]]
#
# 	Brute Force
# 		Solution = 11001010 [00110101].
# 		Maxcut = 54.0.
# 		Time: 0.024129056982928887 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01101010 [10010101].
# 		Maxcut = -51.37673408933615.
# 		Optimizer Time: 7.6064887046813965 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.6064887046813965 seconds.
#
#
# Test Case 96:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[2. 5. 2. 2. 2. 1. 0. 3.]
#  [5. 1. 2. 5. 4. 5. 1. 1.]
#  [2. 2. 0. 3. 2. 5. 5. 4.]
#  [2. 5. 3. 3. 3. 2. 4. 1.]
#  [2. 4. 2. 3. 1. 0. 2. 1.]
#  [1. 5. 5. 2. 0. 3. 3. 4.]
#  [0. 1. 5. 4. 2. 3. 1. 4.]
#  [3. 1. 4. 1. 1. 4. 4. 3.]]
#
# 	Brute Force
# 		Solution = 10001110 [01110001].
# 		Maxcut = 52.0.
# 		Time: 0.020923802978359163 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 01110001 [10001110].
# 		Maxcut = -50.88594243110276.
# 		Optimizer Time: 7.872844696044922 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.872844696044922 seconds.
#
#
# Test Case 97:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[1. 2. 4. 1. 1. 4. 5. 1.]
#  [2. 4. 5. 1. 4. 2. 2. 4.]
#  [4. 5. 2. 2. 3. 4. 4. 1.]
#  [1. 1. 2. 5. 5. 1. 4. 5.]
#  [1. 4. 3. 5. 2. 3. 4. 4.]
#  [4. 2. 4. 1. 3. 5. 4. 5.]
#  [5. 2. 4. 4. 4. 4. 2. 2.]
#  [1. 4. 1. 5. 4. 5. 2. 0.]]
#
# 	Brute Force
# 		Solution = 01010110 [10101001].
# 		Maxcut = 59.0.
# 		Time: 0.017744871991453692 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 00101011 [11010100].
# 		Maxcut = -57.940673988464866.
# 		Optimizer Time: 7.141587734222412 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.141587734222412 seconds.
#
#
# Test Case 98:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[5. 1. 1. 0. 4. 1. 5. 4.]
#  [1. 0. 3. 5. 1. 0. 2. 1.]
#  [1. 3. 5. 2. 1. 2. 5. 2.]
#  [0. 5. 2. 0. 5. 3. 1. 5.]
#  [4. 1. 1. 5. 3. 1. 3. 4.]
#  [1. 0. 2. 3. 1. 4. 4. 4.]
#  [5. 2. 5. 1. 3. 4. 4. 4.]
#  [4. 1. 2. 5. 4. 4. 4. 4.]]
#
# 	Brute Force
# 		Solution = 10110100 [01001011].
# 		Maxcut = 50.0.
# 		Time: 0.016543435980565846 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10110100 [01001011].
# 		Maxcut = -49.509777883381595.
# 		Optimizer Time: 8.446183919906616 seconds.
# 		Compmute Minimum Eigenvalue Time: 8.446183919906616 seconds.
#
#
# Test Case 99:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# [[3. 2. 5. 2. 1. 3. 1. 2.]
#  [2. 4. 1. 3. 5. 2. 5. 4.]
#  [5. 1. 1. 1. 5. 4. 3. 4.]
#  [2. 3. 1. 2. 1. 1. 2. 2.]
#  [1. 5. 5. 1. 1. 1. 3. 4.]
#  [3. 2. 4. 1. 1. 5. 2. 2.]
#  [1. 5. 3. 2. 3. 2. 4. 1.]
#  [2. 4. 4. 2. 4. 2. 1. 1.]]
#
# 	Brute Force
# 		Solution = 01110100 [10001011].
# 		Maxcut = 48.0.
# 		Time: 0.018314377026399598 seconds.
#
# 	Variation Quantum Eignsolver (VQE):
# 		Solution = 10011110 [01100001].
# 		Maxcut = -45.89406134709305.
# 		Optimizer Time: 7.632246494293213 seconds.
# 		Compmute Minimum Eigenvalue Time: 7.632246494293213 seconds.

# %%
print(f'Success: {success} / {num_tests} = {(success/num_tests) * 100} %')
print(f'Fail: {failure} / {num_tests} = {(failure/num_tests) * 100} %')
# Out:
# Success: 40 / 100 = 40.0 %
# Fail: 60 / 100 = 60.0 %
